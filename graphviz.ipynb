# %%
import matplotlib.pyplot as plt

G = nx.DiGraph()

G.add_edge("0", "6", weight=0)  
G.add_edge("0", "7", weight=0)  
G.add_edge("0", "9", weight=0)  
G.add_edge("0", "11", weight=0)  
G.add_edge("0", "14", weight=0)  
G.add_edge("0", "15", weight=0)  
G.add_edge("0", "16", weight=0)  
G.add_edge("0", "17", weight=0)  
G.add_edge("0", "20", weight=0)  
G.add_edge("0", "21", weight=0)  
G.add_edge("0", "22", weight=0)  
G.add_edge("0", "23", weight=0)  
G.add_edge("0", "24", weight=0)  
G.add_edge("0", "27", weight=0)  
G.add_edge("0", "28", weight=0)  
G.add_edge("0", "29", weight=0)  
G.add_edge("0", "30", weight=0)  
G.add_edge("0", "33", weight=0)  
G.add_edge("0", "35", weight=0)  
G.add_edge("0", "42", weight=0)  
G.add_edge("0", "43", weight=0)  
G.add_edge("0", "44", weight=0)  
G.add_edge("0", "46", weight=0)  
G.add_edge("0", "47", weight=0)  
G.add_edge("0", "50", weight=0)  
G.add_edge("0", "51", weight=0)  
G.add_edge("0", "52", weight=0)  
G.add_edge("0", "62", weight=0)  
G.add_edge("0", "65", weight=0)  
G.add_edge("0", "67", weight=0)  
G.add_edge("0", "68", weight=0)  
G.add_edge("0", "69", weight=0)  
G.add_edge("0", "74", weight=0)  
G.add_edge("0", "79", weight=0)  
G.add_edge("0", "82", weight=0)  
G.add_edge("0", "86", weight=0)  
G.add_edge("0", "86", weight=0)  
G.add_edge("0", "91", weight=0)  
G.add_edge("0", "96", weight=0)  
G.add_edge("0", "100", weight=0)  
G.add_edge("0", "109", weight=0)  
G.add_edge("0", "115", weight=0)  
G.add_edge("0", "135", weight=0)  
G.add_edge("0", "141", weight=0)  
G.add_edge("0", "150", weight=0)  
G.add_edge("0", "151", weight=0)  
G.add_edge("0", "155", weight=0)  
G.add_edge("0", "159", weight=0)  
G.add_edge("0", "161", weight=0)  
G.add_edge("0", "162", weight=0)  
G.add_edge("0", "174", weight=1)  
G.add_edge("1", "4", weight=1000)  
G.add_edge("1", "4", weight=1000)  
G.add_edge("1", "6", weight=1000)  
G.add_edge("1", "10", weight=1000)  
G.add_edge("1", "10", weight=1000)  
G.add_edge("1", "10", weight=1000)  
G.add_edge("1", "10", weight=1000)  
G.add_edge("1", "11", weight=1000)  
G.add_edge("1", "12", weight=1000)  
G.add_edge("1", "13", weight=1000)  
G.add_edge("1", "13", weight=1000)  
G.add_edge("1", "15", weight=1000)  
G.add_edge("1", "16", weight=1000)  
G.add_edge("1", "16", weight=1000)  
G.add_edge("1", "18", weight=1000)  
G.add_edge("1", "19", weight=1000)  
G.add_edge("1", "19", weight=1000)  
G.add_edge("1", "20", weight=1000)  
G.add_edge("1", "21", weight=1000)  
G.add_edge("1", "22", weight=1000)  
G.add_edge("1", "23", weight=1000)  
G.add_edge("1", "23", weight=1000)  
G.add_edge("1", "23", weight=1000)  
G.add_edge("1", "24", weight=1000)  
G.add_edge("1", "25", weight=1000)  
G.add_edge("1", "26", weight=1000)  
G.add_edge("1", "26", weight=1000)  
G.add_edge("1", "27", weight=1000)  
G.add_edge("1", "28", weight=1000)  
G.add_edge("1", "29", weight=1000)  
G.add_edge("1", "30", weight=1000)  
G.add_edge("1", "32", weight=1000)  
G.add_edge("1", "32", weight=1000)  
G.add_edge("1", "33", weight=1000)  
G.add_edge("1", "39", weight=1000)  
G.add_edge("1", "41", weight=1000)  
G.add_edge("1", "43", weight=1000)  
G.add_edge("1", "49", weight=1000)  
G.add_edge("1", "49", weight=1000)  
G.add_edge("1", "50", weight=1000)  
G.add_edge("1", "50", weight=1000)  
G.add_edge("1", "51", weight=1000)  
G.add_edge("1", "52", weight=1000)  
G.add_edge("1", "52", weight=1000)  
G.add_edge("1", "53", weight=1000)  
G.add_edge("1", "53", weight=1000)  
G.add_edge("1", "53", weight=1000)  
G.add_edge("1", "55", weight=1000)  
G.add_edge("1", "62", weight=1000)  
G.add_edge("1", "63", weight=1000)  
G.add_edge("1", "64", weight=1000)  
G.add_edge("1", "65", weight=1000)  
G.add_edge("1", "68", weight=1000)  
G.add_edge("1", "69", weight=1000)  
G.add_edge("1", "70", weight=1000)  
G.add_edge("1", "71", weight=1000)  
G.add_edge("1", "72", weight=1000)  
G.add_edge("1", "74", weight=1000)  
G.add_edge("1", "78", weight=1000)  
G.add_edge("1", "83", weight=1000)  
G.add_edge("1", "84", weight=1000)  
G.add_edge("1", "87", weight=1000)  
G.add_edge("1", "92", weight=1000)  
G.add_edge("1", "95", weight=1000)  
G.add_edge("1", "100", weight=1000)  
G.add_edge("1", "102", weight=1000)  
G.add_edge("1", "103", weight=1000)  
G.add_edge("1", "107", weight=1000)  
G.add_edge("1", "108", weight=1000)  
G.add_edge("1", "108", weight=1000)  
G.add_edge("1", "108", weight=1000)  
G.add_edge("1", "108", weight=1000)  
G.add_edge("1", "109", weight=1000)  
G.add_edge("1", "110", weight=1000)  
G.add_edge("1", "113", weight=1000)  
G.add_edge("1", "114", weight=1000)  
G.add_edge("1", "116", weight=1000)  
G.add_edge("1", "118", weight=1000)  
G.add_edge("1", "123", weight=1000)  
G.add_edge("1", "125", weight=1000)  
G.add_edge("1", "126", weight=1000)  
G.add_edge("1", "127", weight=1000)  
G.add_edge("1", "128", weight=1000)  
G.add_edge("1", "129", weight=1000)  
G.add_edge("1", "130", weight=1000)  
G.add_edge("1", "131", weight=1000)  
G.add_edge("1", "132", weight=1000)  
G.add_edge("1", "134", weight=1000)  
G.add_edge("1", "136", weight=1000)  
G.add_edge("1", "137", weight=1000)  
G.add_edge("1", "138", weight=1000)  
G.add_edge("1", "139", weight=1000)  
G.add_edge("1", "140", weight=1000)  
G.add_edge("1", "142", weight=1000)  
G.add_edge("1", "145", weight=1000)  
G.add_edge("1", "146", weight=1000)  
G.add_edge("1", "147", weight=1000)  
G.add_edge("1", "152", weight=1000)  
G.add_edge("1", "154", weight=1000)  
G.add_edge("1", "155", weight=1000)  
G.add_edge("1", "157", weight=1000)  
G.add_edge("1", "161", weight=1000)  
G.add_edge("1", "163", weight=1000)  
G.add_edge("1", "164", weight=1000)  
G.add_edge("1", "165", weight=1000)  
G.add_edge("1", "165", weight=1000)  
G.add_edge("1", "166", weight=1000)  
G.add_edge("1", "168", weight=1000)  
G.add_edge("1", "171", weight=1000)  
G.add_edge("1", "173", weight=1000)  
G.add_edge("1", "174", weight=1000)  
G.add_edge("1", "175", weight=1000)  
G.add_edge("2", "3", weight=1000)  
G.add_edge("2", "4", weight=1000)  
G.add_edge("2", "5", weight=1000)  
G.add_edge("2", "7", weight=1000)  
G.add_edge("2", "9", weight=1000)  
G.add_edge("2", "11", weight=1000)  
G.add_edge("2", "18", weight=1000)  
G.add_edge("2", "38", weight=1000)  
G.add_edge("2", "39", weight=1000)  
G.add_edge("2", "43", weight=1000)  
G.add_edge("2", "43", weight=1000)  
G.add_edge("2", "44", weight=1000)  
G.add_edge("2", "58", weight=1000)  
G.add_edge("2", "60", weight=1000)  
G.add_edge("2", "60", weight=1000)  
G.add_edge("2", "63", weight=1000)  
G.add_edge("2", "67", weight=1000)  
G.add_edge("2", "74", weight=1000)  
G.add_edge("2", "82", weight=1000)  
G.add_edge("2", "85", weight=1000)  
G.add_edge("2", "97", weight=1000)  
G.add_edge("2", "114", weight=1000)  
G.add_edge("2", "126", weight=1000)  
G.add_edge("2", "127", weight=1000)  
G.add_edge("2", "128", weight=1000)  
G.add_edge("2", "131", weight=1000)  
G.add_edge("2", "132", weight=1000)  
G.add_edge("2", "134", weight=1000)  
G.add_edge("2", "137", weight=1000)  
G.add_edge("2", "138", weight=1000)  
G.add_edge("2", "161", weight=1000)  
G.add_edge("2", "163", weight=1000)  
G.add_edge("2", "164", weight=1000)  
G.add_edge("2", "166", weight=1000)  
G.add_edge("2", "175", weight=1000)  
G.add_edge("3", "2", weight=1000)  
G.add_edge("3", "5", weight=1000)  
G.add_edge("3", "34", weight=1000)  
G.add_edge("3", "34", weight=1000)  
G.add_edge("3", "34", weight=1000)  
G.add_edge("3", "39", weight=1000)  
G.add_edge("3", "43", weight=1000)  
G.add_edge("3", "43", weight=1000)  
G.add_edge("3", "57", weight=1000)  
G.add_edge("3", "65", weight=1000)  
G.add_edge("3", "71", weight=1000)  
G.add_edge("3", "72", weight=1000)  
G.add_edge("3", "88", weight=1000)  
G.add_edge("3", "92", weight=1000)  
G.add_edge("3", "101", weight=1000)  
G.add_edge("3", "115", weight=1000)  
G.add_edge("3", "124", weight=1000)  
G.add_edge("3", "141", weight=1000)  
G.add_edge("3", "150", weight=1000)  
G.add_edge("3", "151", weight=1000)  
G.add_edge("3", "159", weight=1000)  
G.add_edge("3", "162", weight=1000)  
G.add_edge("3", "167", weight=1000)  
G.add_edge("3", "169", weight=1000)  
G.add_edge("3", "173", weight=1000)  
G.add_edge("4", "1", weight=0)  
G.add_edge("4", "1", weight=0)  
G.add_edge("4", "2", weight=0)  
G.add_edge("4", "6", weight=0)  
G.add_edge("4", "6", weight=0)  
G.add_edge("4", "7", weight=0)  
G.add_edge("4", "9", weight=0)  
G.add_edge("4", "9", weight=0)  
G.add_edge("4", "10", weight=0)  
G.add_edge("4", "11", weight=0)  
G.add_edge("4", "12", weight=0)  
G.add_edge("4", "14", weight=0)  
G.add_edge("4", "15", weight=0)  
G.add_edge("4", "16", weight=0)  
G.add_edge("4", "17", weight=0)  
G.add_edge("4", "20", weight=0)  
G.add_edge("4", "23", weight=0)  
G.add_edge("4", "26", weight=0)  
G.add_edge("4", "27", weight=0)  
G.add_edge("4", "28", weight=0)  
G.add_edge("4", "31", weight=0)  
G.add_edge("4", "33", weight=0)  
G.add_edge("4", "40", weight=0)  
G.add_edge("4", "41", weight=0)  
G.add_edge("4", "43", weight=0)  
G.add_edge("4", "44", weight=0)  
G.add_edge("4", "48", weight=0)  
G.add_edge("4", "52", weight=0)  
G.add_edge("4", "59", weight=0)  
G.add_edge("4", "64", weight=0)  
G.add_edge("4", "65", weight=0)  
G.add_edge("4", "67", weight=0)  
G.add_edge("4", "79", weight=0)  
G.add_edge("4", "82", weight=0)  
G.add_edge("4", "85", weight=0)  
G.add_edge("4", "100", weight=0)  
G.add_edge("4", "100", weight=0)  
G.add_edge("4", "103", weight=0)  
G.add_edge("4", "103", weight=0)  
G.add_edge("4", "107", weight=0)  
G.add_edge("4", "108", weight=0)  
G.add_edge("4", "108", weight=0)  
G.add_edge("4", "111", weight=0)  
G.add_edge("4", "124", weight=0)  
G.add_edge("4", "125", weight=0)  
G.add_edge("4", "127", weight=0)  
G.add_edge("4", "132", weight=99)  
G.add_edge("4", "137", weight=0)  
G.add_edge("4", "139", weight=0)  
G.add_edge("4", "142", weight=0)  
G.add_edge("4", "144", weight=0)  
G.add_edge("4", "146", weight=0)  
G.add_edge("4", "147", weight=0)  
G.add_edge("4", "153", weight=0)  
G.add_edge("4", "154", weight=0)  
G.add_edge("4", "156", weight=0)  
G.add_edge("4", "163", weight=0)  
G.add_edge("4", "166", weight=0)  
G.add_edge("4", "168", weight=0)  
G.add_edge("4", "174", weight=0)  
G.add_edge("4", "175", weight=0)  
G.add_edge("5", "2", weight=0)  
G.add_edge("5", "3", weight=0)  
G.add_edge("5", "12", weight=0)  
G.add_edge("5", "26", weight=0)  
G.add_edge("5", "29", weight=0)  
G.add_edge("5", "30", weight=0)  
G.add_edge("5", "31", weight=0)  
G.add_edge("5", "41", weight=0)  
G.add_edge("5", "43", weight=0)  
G.add_edge("5", "44", weight=490)  
G.add_edge("5", "47", weight=0)  
G.add_edge("5", "55", weight=0)  
G.add_edge("5", "60", weight=0)  
G.add_edge("5", "62", weight=490)  
G.add_edge("5", "76", weight=0)  
G.add_edge("5", "87", weight=0)  
G.add_edge("5", "93", weight=0)  
G.add_edge("5", "94", weight=0)  
G.add_edge("5", "99", weight=0)  
G.add_edge("5", "100", weight=0)  
G.add_edge("5", "103", weight=0)  
G.add_edge("5", "127", weight=0)  
G.add_edge("5", "146", weight=490)  
G.add_edge("5", "147", weight=0)  
G.add_edge("5", "161", weight=490)  
G.add_edge("5", "165", weight=490)  
G.add_edge("5", "174", weight=0)  
G.add_edge("5", "175", weight=0)  
G.add_edge("6", "0", weight=1000)  
G.add_edge("6", "1", weight=1000)  
G.add_edge("6", "2", weight=1000)  
G.add_edge("6", "4", weight=1000)  
G.add_edge("6", "4", weight=1000)  
G.add_edge("6", "7", weight=1000)  
G.add_edge("6", "8", weight=1000)  
G.add_edge("6", "9", weight=1000)  
G.add_edge("6", "13", weight=1000)  
G.add_edge("6", "17", weight=1000)  
G.add_edge("6", "18", weight=1000)  
G.add_edge("6", "23", weight=1000)  
G.add_edge("6", "25", weight=1000)  
G.add_edge("6", "31", weight=1000)  
G.add_edge("6", "31", weight=1000)  
G.add_edge("6", "31", weight=1000)  
G.add_edge("6", "34", weight=1000)  
G.add_edge("6", "37", weight=1000)  
G.add_edge("6", "38", weight=1000)  
G.add_edge("6", "38", weight=1000)  
G.add_edge("6", "39", weight=1000)  
G.add_edge("6", "40", weight=1000)  
G.add_edge("6", "41", weight=1000)  
G.add_edge("6", "41", weight=1000)  
G.add_edge("6", "41", weight=1000)  
G.add_edge("6", "42", weight=1000)  
G.add_edge("6", "43", weight=1000)  
G.add_edge("6", "44", weight=1000)  
G.add_edge("6", "45", weight=1000)  
G.add_edge("6", "46", weight=1000)  
G.add_edge("6", "47", weight=1000)  
G.add_edge("6", "48", weight=1000)  
G.add_edge("6", "48", weight=1000)  
G.add_edge("6", "55", weight=1000)  
G.add_edge("6", "58", weight=1000)  
G.add_edge("6", "59", weight=1000)  
G.add_edge("6", "59", weight=1000)  
G.add_edge("6", "60", weight=1000)  
G.add_edge("6", "60", weight=1000)  
G.add_edge("6", "61", weight=1000)  
G.add_edge("6", "61", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "62", weight=1000)  
G.add_edge("6", "63", weight=1000)  
G.add_edge("6", "64", weight=1000)  
G.add_edge("6", "65", weight=1000)  
G.add_edge("6", "65", weight=1000)  
G.add_edge("6", "65", weight=1000)  
G.add_edge("6", "66", weight=1000)  
G.add_edge("6", "66", weight=1000)  
G.add_edge("6", "66", weight=1000)  
G.add_edge("6", "66", weight=1000)  
G.add_edge("6", "67", weight=1000)  
G.add_edge("6", "68", weight=1000)  
G.add_edge("6", "70", weight=1000)  
G.add_edge("6", "70", weight=1000)  
G.add_edge("6", "70", weight=1000)  
G.add_edge("6", "70", weight=1000)  
G.add_edge("6", "70", weight=1000)  
G.add_edge("6", "70", weight=1000)  
G.add_edge("6", "72", weight=1000)  
G.add_edge("6", "72", weight=1000)  
G.add_edge("6", "73", weight=1000)  
G.add_edge("6", "73", weight=1000)  
G.add_edge("6", "73", weight=1000)  
G.add_edge("6", "73", weight=1000)  
G.add_edge("6", "74", weight=1000)  
G.add_edge("6", "75", weight=1000)  
G.add_edge("6", "78", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "79", weight=1000)  
G.add_edge("6", "80", weight=1000)  
G.add_edge("6", "81", weight=1000)  
G.add_edge("6", "82", weight=1000)  
G.add_edge("6", "83", weight=1000)  
G.add_edge("6", "84", weight=1000)  
G.add_edge("6", "85", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "86", weight=1000)  
G.add_edge("6", "87", weight=1000)  
G.add_edge("6", "88", weight=1000)  
G.add_edge("6", "90", weight=1000)  
G.add_edge("6", "94", weight=1000)  
G.add_edge("6", "95", weight=1000)  
G.add_edge("6", "98", weight=1000)  
G.add_edge("6", "99", weight=1000)  
G.add_edge("6", "100", weight=1000)  
G.add_edge("6", "101", weight=1000)  
G.add_edge("6", "101", weight=1000)  
G.add_edge("6", "104", weight=1000)  
G.add_edge("6", "104", weight=1000)  
G.add_edge("6", "105", weight=1000)  
G.add_edge("6", "107", weight=1000)  
G.add_edge("6", "108", weight=1000)  
G.add_edge("6", "109", weight=1000)  
G.add_edge("6", "110", weight=1000)  
G.add_edge("6", "110", weight=1000)  
G.add_edge("6", "111", weight=1000)  
G.add_edge("6", "112", weight=1000)  
G.add_edge("6", "113", weight=1000)  
G.add_edge("6", "114", weight=1000)  
G.add_edge("6", "116", weight=1000)  
G.add_edge("6", "118", weight=1000)  
G.add_edge("6", "119", weight=1000)  
G.add_edge("6", "122", weight=1000)  
G.add_edge("6", "123", weight=1000)  
G.add_edge("6", "124", weight=1000)  
G.add_edge("6", "125", weight=1000)  
G.add_edge("6", "126", weight=1000)  
G.add_edge("6", "127", weight=1000)  
G.add_edge("6", "128", weight=1000)  
G.add_edge("6", "129", weight=1000)  
G.add_edge("6", "130", weight=1000)  
G.add_edge("6", "131", weight=1000)  
G.add_edge("6", "131", weight=1000)  
G.add_edge("6", "132", weight=1000)  
G.add_edge("6", "133", weight=1000)  
G.add_edge("6", "134", weight=1000)  
G.add_edge("6", "135", weight=1000)  
G.add_edge("6", "135", weight=1000)  
G.add_edge("6", "137", weight=1000)  
G.add_edge("6", "138", weight=1000)  
G.add_edge("6", "139", weight=1000)  
G.add_edge("6", "140", weight=1000)  
G.add_edge("6", "142", weight=1000)  
G.add_edge("6", "142", weight=1000)  
G.add_edge("6", "144", weight=1000)  
G.add_edge("6", "146", weight=1000)  
G.add_edge("6", "147", weight=1000)  
G.add_edge("6", "151", weight=1000)  
G.add_edge("6", "153", weight=1000)  
G.add_edge("6", "154", weight=1000)  
G.add_edge("6", "158", weight=1000)  
G.add_edge("6", "160", weight=1000)  
G.add_edge("6", "161", weight=1000)  
G.add_edge("6", "165", weight=1000)  
G.add_edge("6", "166", weight=1000)  
G.add_edge("6", "168", weight=1000)  
G.add_edge("6", "170", weight=1000)  
G.add_edge("6", "171", weight=1000)  
G.add_edge("6", "174", weight=1000)  
G.add_edge("6", "174", weight=1000)  
G.add_edge("6", "174", weight=1000)  
G.add_edge("6", "175", weight=1000)  
G.add_edge("7", "0", weight=0)  
G.add_edge("7", "2", weight=0)  
G.add_edge("7", "4", weight=0)  
G.add_edge("7", "6", weight=0)  
G.add_edge("7", "8", weight=0)  
G.add_edge("7", "9", weight=0)  
G.add_edge("7", "11", weight=0)  
G.add_edge("7", "22", weight=0)  
G.add_edge("7", "34", weight=0)  
G.add_edge("7", "35", weight=0)  
G.add_edge("7", "36", weight=0)  
G.add_edge("7", "37", weight=0)  
G.add_edge("7", "39", weight=0)  
G.add_edge("7", "42", weight=0)  
G.add_edge("7", "43", weight=0)  
G.add_edge("7", "56", weight=0)  
G.add_edge("7", "61", weight=0)  
G.add_edge("7", "61", weight=0)  
G.add_edge("7", "69", weight=0)  
G.add_edge("7", "72", weight=0)  
G.add_edge("7", "74", weight=0)  
G.add_edge("7", "77", weight=0)  
G.add_edge("7", "78", weight=0)  
G.add_edge("7", "79", weight=0)  
G.add_edge("7", "81", weight=0)  
G.add_edge("7", "83", weight=0)  
G.add_edge("7", "87", weight=0)  
G.add_edge("7", "90", weight=0)  
G.add_edge("7", "91", weight=0)  
G.add_edge("7", "92", weight=0)  
G.add_edge("7", "94", weight=0)  
G.add_edge("7", "95", weight=0)  
G.add_edge("7", "96", weight=0)  
G.add_edge("7", "100", weight=0)  
G.add_edge("7", "114", weight=0)  
G.add_edge("7", "115", weight=0)  
G.add_edge("7", "128", weight=0)  
G.add_edge("7", "131", weight=0)  
G.add_edge("7", "141", weight=0)  
G.add_edge("7", "150", weight=0)  
G.add_edge("7", "159", weight=0)  
G.add_edge("7", "161", weight=0)  
G.add_edge("7", "162", weight=0)  
G.add_edge("7", "165", weight=0)  
G.add_edge("7", "172", weight=0)  
G.add_edge("7", "175", weight=0)  
G.add_edge("8", "6", weight=120)  
G.add_edge("8", "7", weight=120)  
G.add_edge("8", "9", weight=120)  
G.add_edge("8", "10", weight=120)  
G.add_edge("8", "11", weight=120)  
G.add_edge("8", "12", weight=120)  
G.add_edge("8", "13", weight=120)  
G.add_edge("8", "15", weight=120)  
G.add_edge("8", "15", weight=120)  
G.add_edge("8", "16", weight=120)  
G.add_edge("8", "22", weight=120)  
G.add_edge("8", "31", weight=120)  
G.add_edge("8", "37", weight=120)  
G.add_edge("8", "44", weight=120)  
G.add_edge("8", "44", weight=42)  
G.add_edge("8", "45", weight=120)  
G.add_edge("8", "45", weight=120)  
G.add_edge("8", "48", weight=120)  
G.add_edge("8", "48", weight=120)  
G.add_edge("8", "49", weight=120)  
G.add_edge("8", "51", weight=120)  
G.add_edge("8", "56", weight=120)  
G.add_edge("8", "57", weight=120)  
G.add_edge("8", "59", weight=120)  
G.add_edge("8", "60", weight=120)  
G.add_edge("8", "61", weight=120)  
G.add_edge("8", "62", weight=120)  
G.add_edge("8", "62", weight=120)  
G.add_edge("8", "63", weight=120)  
G.add_edge("8", "64", weight=120)  
G.add_edge("8", "66", weight=120)  
G.add_edge("8", "68", weight=120)  
G.add_edge("8", "70", weight=120)  
G.add_edge("8", "74", weight=42)  
G.add_edge("8", "76", weight=120)  
G.add_edge("8", "78", weight=120)  
G.add_edge("8", "81", weight=120)  
G.add_edge("8", "84", weight=120)  
G.add_edge("8", "85", weight=120)  
G.add_edge("8", "87", weight=120)  
G.add_edge("8", "89", weight=120)  
G.add_edge("8", "94", weight=120)  
G.add_edge("8", "106", weight=120)  
G.add_edge("8", "113", weight=120)  
G.add_edge("8", "114", weight=42)  
G.add_edge("8", "122", weight=120)  
G.add_edge("8", "125", weight=120)  
G.add_edge("8", "127", weight=42)  
G.add_edge("8", "128", weight=120)  
G.add_edge("8", "142", weight=120)  
G.add_edge("8", "154", weight=120)  
G.add_edge("8", "157", weight=120)  
G.add_edge("8", "164", weight=120)  
G.add_edge("8", "170", weight=120)  
G.add_edge("8", "171", weight=120)  
G.add_edge("8", "175", weight=120)  
G.add_edge("9", "0", weight=0)  
G.add_edge("9", "2", weight=0)  
G.add_edge("9", "4", weight=0)  
G.add_edge("9", "4", weight=0)  
G.add_edge("9", "6", weight=0)  
G.add_edge("9", "7", weight=0)  
G.add_edge("9", "8", weight=0)  
G.add_edge("9", "10", weight=0)  
G.add_edge("9", "11", weight=0)  
G.add_edge("9", "12", weight=0)  
G.add_edge("9", "15", weight=0)  
G.add_edge("9", "18", weight=0)  
G.add_edge("9", "21", weight=0)  
G.add_edge("9", "29", weight=0)  
G.add_edge("9", "31", weight=0)  
G.add_edge("9", "35", weight=0)  
G.add_edge("9", "38", weight=0)  
G.add_edge("9", "39", weight=0)  
G.add_edge("9", "41", weight=0)  
G.add_edge("9", "43", weight=0)  
G.add_edge("9", "44", weight=0)  
G.add_edge("9", "47", weight=0)  
G.add_edge("9", "49", weight=0)  
G.add_edge("9", "51", weight=0)  
G.add_edge("9", "53", weight=0)  
G.add_edge("9", "55", weight=0)  
G.add_edge("9", "56", weight=0)  
G.add_edge("9", "58", weight=0)  
G.add_edge("9", "59", weight=0)  
G.add_edge("9", "60", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "62", weight=0)  
G.add_edge("9", "63", weight=0)  
G.add_edge("9", "64", weight=0)  
G.add_edge("9", "66", weight=0)  
G.add_edge("9", "67", weight=0)  
G.add_edge("9", "68", weight=0)  
G.add_edge("9", "69", weight=0)  
G.add_edge("9", "70", weight=0)  
G.add_edge("9", "70", weight=0)  
G.add_edge("9", "70", weight=0)  
G.add_edge("9", "70", weight=0)  
G.add_edge("9", "72", weight=0)  
G.add_edge("9", "73", weight=0)  
G.add_edge("9", "74", weight=0)  
G.add_edge("9", "75", weight=0)  
G.add_edge("9", "76", weight=0)  
G.add_edge("9", "78", weight=0)  
G.add_edge("9", "79", weight=0)  
G.add_edge("9", "79", weight=0)  
G.add_edge("9", "79", weight=0)  
G.add_edge("9", "79", weight=0)  
G.add_edge("9", "79", weight=0)  
G.add_edge("9", "79", weight=0)  
G.add_edge("9", "82", weight=0)  
G.add_edge("9", "83", weight=0)  
G.add_edge("9", "84", weight=0)  
G.add_edge("9", "84", weight=0)  
G.add_edge("9", "87", weight=0)  
G.add_edge("9", "88", weight=0)  
G.add_edge("9", "94", weight=0)  
G.add_edge("9", "95", weight=0)  
G.add_edge("9", "97", weight=0)  
G.add_edge("9", "98", weight=0)  
G.add_edge("9", "99", weight=0)  
G.add_edge("9", "100", weight=0)  
G.add_edge("9", "101", weight=0)  
G.add_edge("9", "101", weight=0)  
G.add_edge("9", "103", weight=0)  
G.add_edge("9", "104", weight=0)  
G.add_edge("9", "105", weight=0)  
G.add_edge("9", "107", weight=0)  
G.add_edge("9", "108", weight=0)  
G.add_edge("9", "110", weight=0)  
G.add_edge("9", "112", weight=0)  
G.add_edge("9", "113", weight=0)  
G.add_edge("9", "114", weight=0)  
G.add_edge("9", "116", weight=0)  
G.add_edge("9", "118", weight=0)  
G.add_edge("9", "119", weight=0)  
G.add_edge("9", "122", weight=0)  
G.add_edge("9", "123", weight=0)  
G.add_edge("9", "124", weight=0)  
G.add_edge("9", "125", weight=0)  
G.add_edge("9", "127", weight=0)  
G.add_edge("9", "128", weight=0)  
G.add_edge("9", "129", weight=0)  
G.add_edge("9", "130", weight=0)  
G.add_edge("9", "131", weight=0)  
G.add_edge("9", "132", weight=0)  
G.add_edge("9", "134", weight=0)  
G.add_edge("9", "136", weight=0)  
G.add_edge("9", "137", weight=0)  
G.add_edge("9", "138", weight=0)  
G.add_edge("9", "140", weight=0)  
G.add_edge("9", "142", weight=0)  
G.add_edge("9", "143", weight=0)  
G.add_edge("9", "144", weight=0)  
G.add_edge("9", "146", weight=0)  
G.add_edge("9", "148", weight=0)  
G.add_edge("9", "151", weight=0)  
G.add_edge("9", "157", weight=0)  
G.add_edge("9", "158", weight=0)  
G.add_edge("9", "161", weight=0)  
G.add_edge("9", "163", weight=0)  
G.add_edge("9", "164", weight=0)  
G.add_edge("9", "165", weight=0)  
G.add_edge("9", "166", weight=0)  
G.add_edge("9", "168", weight=0)  
G.add_edge("9", "171", weight=0)  
G.add_edge("9", "174", weight=0)  
G.add_edge("9", "175", weight=0)  
G.add_edge("9", "176", weight=0)  
G.add_edge("10", "1", weight=2250)  
G.add_edge("10", "1", weight=2250)  
G.add_edge("10", "1", weight=2250)  
G.add_edge("10", "1", weight=2250)  
G.add_edge("10", "2", weight=9000)  
G.add_edge("10", "4", weight=2250)  
G.add_edge("10", "8", weight=2250)  
G.add_edge("10", "9", weight=2250)  
G.add_edge("10", "11", weight=2250)  
G.add_edge("10", "15", weight=0)  
G.add_edge("10", "16", weight=0)  
G.add_edge("10", "23", weight=0)  
G.add_edge("10", "26", weight=0)  
G.add_edge("10", "37", weight=2250)  
G.add_edge("10", "39", weight=2250)  
G.add_edge("10", "43", weight=2250)  
G.add_edge("10", "43", weight=2250)  
G.add_edge("10", "49", weight=0)  
G.add_edge("10", "51", weight=0)  
G.add_edge("10", "53", weight=0)  
G.add_edge("10", "57", weight=2250)  
G.add_edge("10", "58", weight=2250)  
G.add_edge("10", "65", weight=2250)  
G.add_edge("10", "65", weight=2250)  
G.add_edge("10", "69", weight=2250)  
G.add_edge("10", "72", weight=2250)  
G.add_edge("10", "75", weight=2250)  
G.add_edge("10", "76", weight=2250)  
G.add_edge("10", "76", weight=2250)  
G.add_edge("10", "76", weight=2250)  
G.add_edge("10", "76", weight=2250)  
G.add_edge("10", "80", weight=2250)  
G.add_edge("10", "83", weight=2250)  
G.add_edge("10", "94", weight=2250)  
G.add_edge("10", "101", weight=2250)  
G.add_edge("10", "127", weight=9000)  
G.add_edge("10", "138", weight=9000)  
G.add_edge("10", "142", weight=2250)  
G.add_edge("10", "157", weight=2250)  
G.add_edge("10", "161", weight=9000)  
G.add_edge("10", "165", weight=2250)  
G.add_edge("10", "168", weight=2250)  
G.add_edge("11", "0", weight=10000)  
G.add_edge("11", "1", weight=10000)  
G.add_edge("11", "2", weight=10000)  
G.add_edge("11", "4", weight=10000)  
G.add_edge("11", "7", weight=10000)  
G.add_edge("11", "8", weight=10000)  
G.add_edge("11", "9", weight=10000)  
G.add_edge("11", "10", weight=10000)  
G.add_edge("11", "12", weight=10000)  
G.add_edge("11", "12", weight=10000)  
G.add_edge("11", "13", weight=10000)  
G.add_edge("11", "16", weight=10000)  
G.add_edge("11", "17", weight=10000)  
G.add_edge("11", "21", weight=10000)  
G.add_edge("11", "26", weight=10000)  
G.add_edge("11", "27", weight=10000)  
G.add_edge("11", "28", weight=10000)  
G.add_edge("11", "29", weight=10000)  
G.add_edge("11", "30", weight=10000)  
G.add_edge("11", "31", weight=10000)  
G.add_edge("11", "32", weight=10000)  
G.add_edge("11", "33", weight=10000)  
G.add_edge("11", "38", weight=10000)  
G.add_edge("11", "43", weight=10000)  
G.add_edge("11", "43", weight=10000)  
G.add_edge("11", "45", weight=10000)  
G.add_edge("11", "46", weight=10000)  
G.add_edge("11", "48", weight=10000)  
G.add_edge("11", "49", weight=10000)  
G.add_edge("11", "50", weight=10000)  
G.add_edge("11", "51", weight=10000)  
G.add_edge("11", "52", weight=10000)  
G.add_edge("11", "53", weight=10000)  
G.add_edge("11", "55", weight=10000)  
G.add_edge("11", "56", weight=10000)  
G.add_edge("11", "57", weight=10000)  
G.add_edge("11", "58", weight=10000)  
G.add_edge("11", "60", weight=10000)  
G.add_edge("11", "61", weight=10000)  
G.add_edge("11", "62", weight=10000)  
G.add_edge("11", "64", weight=10000)  
G.add_edge("11", "65", weight=10000)  
G.add_edge("11", "66", weight=10000)  
G.add_edge("11", "70", weight=10000)  
G.add_edge("11", "72", weight=10000)  
G.add_edge("11", "75", weight=10000)  
G.add_edge("11", "79", weight=10000)  
G.add_edge("11", "83", weight=10000)  
G.add_edge("11", "85", weight=10000)  
G.add_edge("11", "100", weight=10000)  
G.add_edge("11", "103", weight=10000)  
G.add_edge("11", "142", weight=10000)  
G.add_edge("12", "1", weight=2250)  
G.add_edge("12", "4", weight=2250)  
G.add_edge("12", "5", weight=2250)  
G.add_edge("12", "8", weight=2250)  
G.add_edge("12", "9", weight=2250)  
G.add_edge("12", "11", weight=2250)  
G.add_edge("12", "11", weight=2250)  
G.add_edge("12", "23", weight=0)  
G.add_edge("12", "26", weight=0)  
G.add_edge("12", "26", weight=0)  
G.add_edge("12", "29", weight=0)  
G.add_edge("12", "32", weight=0)  
G.add_edge("12", "37", weight=2250)  
G.add_edge("12", "38", weight=2250)  
G.add_edge("12", "43", weight=2250)  
G.add_edge("12", "45", weight=2250)  
G.add_edge("12", "49", weight=0)  
G.add_edge("12", "51", weight=0)  
G.add_edge("12", "53", weight=0)  
G.add_edge("12", "53", weight=0)  
G.add_edge("12", "65", weight=2250)  
G.add_edge("12", "72", weight=2250)  
G.add_edge("12", "75", weight=2250)  
G.add_edge("12", "76", weight=2250)  
G.add_edge("12", "76", weight=2250)  
G.add_edge("12", "82", weight=2250)  
G.add_edge("12", "87", weight=2250)  
G.add_edge("12", "94", weight=2250)  
G.add_edge("12", "105", weight=2250)  
G.add_edge("12", "107", weight=9000)  
G.add_edge("12", "116", weight=2250)  
G.add_edge("12", "166", weight=9000)  
G.add_edge("13", "1", weight=2250)  
G.add_edge("13", "1", weight=2250)  
G.add_edge("13", "6", weight=2250)  
G.add_edge("13", "8", weight=2250)  
G.add_edge("13", "11", weight=2250)  
G.add_edge("13", "20", weight=0)  
G.add_edge("13", "21", weight=0)  
G.add_edge("13", "22", weight=0)  
G.add_edge("13", "28", weight=0)  
G.add_edge("13", "31", weight=2250)  
G.add_edge("13", "31", weight=2250)  
G.add_edge("13", "31", weight=2250)  
G.add_edge("13", "33", weight=2250)  
G.add_edge("13", "37", weight=2250)  
G.add_edge("13", "38", weight=2250)  
G.add_edge("13", "39", weight=2250)  
G.add_edge("13", "43", weight=2250)  
G.add_edge("13", "46", weight=2250)  
G.add_edge("13", "48", weight=2250)  
G.add_edge("13", "49", weight=0)  
G.add_edge("13", "50", weight=0)  
G.add_edge("13", "51", weight=0)  
G.add_edge("13", "53", weight=0)  
G.add_edge("13", "57", weight=2250)  
G.add_edge("13", "65", weight=2250)  
G.add_edge("13", "72", weight=2250)  
G.add_edge("13", "74", weight=2250)  
G.add_edge("13", "75", weight=2250)  
G.add_edge("13", "75", weight=2250)  
G.add_edge("13", "76", weight=2250)  
G.add_edge("13", "76", weight=2250)  
G.add_edge("13", "81", weight=2250)  
G.add_edge("13", "87", weight=2250)  
G.add_edge("13", "142", weight=2250)  
G.add_edge("13", "175", weight=2250)  
G.add_edge("14", "0", weight=2250)  
G.add_edge("14", "4", weight=2250)  
G.add_edge("14", "17", weight=0)  
G.add_edge("14", "18", weight=2250)  
G.add_edge("14", "22", weight=0)  
G.add_edge("14", "30", weight=0)  
G.add_edge("14", "30", weight=0)  
G.add_edge("14", "31", weight=2250)  
G.add_edge("14", "31", weight=2250)  
G.add_edge("14", "31", weight=2250)  
G.add_edge("14", "31", weight=2250)  
G.add_edge("14", "37", weight=2250)  
G.add_edge("14", "38", weight=2250)  
G.add_edge("14", "43", weight=9000)  
G.add_edge("14", "46", weight=9000)  
G.add_edge("14", "48", weight=2250)  
G.add_edge("14", "49", weight=0)  
G.add_edge("14", "51", weight=0)  
G.add_edge("14", "53", weight=0)  
G.add_edge("14", "57", weight=2250)  
G.add_edge("14", "58", weight=2250)  
G.add_edge("14", "59", weight=18000)  
G.add_edge("14", "62", weight=9000)  
G.add_edge("14", "65", weight=2250)  
G.add_edge("14", "65", weight=2250)  
G.add_edge("14", "70", weight=9000)  
G.add_edge("14", "75", weight=2250)  
G.add_edge("14", "75", weight=2250)  
G.add_edge("14", "76", weight=2250)  
G.add_edge("14", "76", weight=2250)  
G.add_edge("14", "83", weight=2250)  
G.add_edge("14", "100", weight=2250)  
G.add_edge("14", "113", weight=2250)  
G.add_edge("14", "126", weight=9000)  
G.add_edge("14", "127", weight=9000)  
G.add_edge("14", "142", weight=2250)  
G.add_edge("14", "166", weight=2250)  
G.add_edge("14", "168", weight=9000)  
G.add_edge("14", "174", weight=18000)  
G.add_edge("15", "0", weight=2250)  
G.add_edge("15", "1", weight=2250)  
G.add_edge("15", "4", weight=2250)  
G.add_edge("15", "8", weight=2250)  
G.add_edge("15", "8", weight=2250)  
G.add_edge("15", "9", weight=2250)  
G.add_edge("15", "10", weight=0)  
G.add_edge("15", "18", weight=2250)  
G.add_edge("15", "20", weight=0)  
G.add_edge("15", "23", weight=0)  
G.add_edge("15", "31", weight=2250)  
G.add_edge("15", "34", weight=18000)  
G.add_edge("15", "37", weight=2250)  
G.add_edge("15", "38", weight=2250)  
G.add_edge("15", "42", weight=2250)  
G.add_edge("15", "43", weight=2250)  
G.add_edge("15", "48", weight=2250)  
G.add_edge("15", "48", weight=2250)  
G.add_edge("15", "49", weight=0)  
G.add_edge("15", "50", weight=0)  
G.add_edge("15", "51", weight=0)  
G.add_edge("15", "51", weight=0)  
G.add_edge("15", "53", weight=0)  
G.add_edge("15", "57", weight=2250)  
G.add_edge("15", "59", weight=18000)  
G.add_edge("15", "62", weight=9000)  
G.add_edge("15", "65", weight=2250)  
G.add_edge("15", "65", weight=2250)  
G.add_edge("15", "68", weight=2250)  
G.add_edge("15", "71", weight=2250)  
G.add_edge("15", "75", weight=2250)  
G.add_edge("15", "75", weight=2250)  
G.add_edge("15", "126", weight=9000)  
G.add_edge("15", "138", weight=9000)  
G.add_edge("15", "142", weight=2250)  
G.add_edge("15", "168", weight=12600)  
G.add_edge("16", "0", weight=2250)  
G.add_edge("16", "1", weight=2250)  
G.add_edge("16", "1", weight=2250)  
G.add_edge("16", "4", weight=2250)  
G.add_edge("16", "8", weight=2250)  
G.add_edge("16", "10", weight=0)  
G.add_edge("16", "11", weight=2250)  
G.add_edge("16", "18", weight=2250)  
G.add_edge("16", "22", weight=0)  
G.add_edge("16", "31", weight=2250)  
G.add_edge("16", "37", weight=2250)  
G.add_edge("16", "43", weight=2250)  
G.add_edge("16", "48", weight=2250)  
G.add_edge("16", "49", weight=0)  
G.add_edge("16", "51", weight=0)  
G.add_edge("16", "53", weight=0)  
G.add_edge("16", "57", weight=2250)  
G.add_edge("16", "62", weight=9000)  
G.add_edge("16", "63", weight=2250)  
G.add_edge("16", "65", weight=2250)  
G.add_edge("16", "76", weight=2250)  
G.add_edge("16", "76", weight=2250)  
G.add_edge("16", "84", weight=2250)  
G.add_edge("16", "87", weight=2250)  
G.add_edge("16", "90", weight=2250)  
G.add_edge("16", "94", weight=2250)  
G.add_edge("16", "104", weight=2250)  
G.add_edge("16", "122", weight=2250)  
G.add_edge("16", "128", weight=9000)  
G.add_edge("16", "138", weight=9000)  
G.add_edge("16", "138", weight=9000)  
G.add_edge("16", "142", weight=2250)  
G.add_edge("16", "146", weight=2250)  
G.add_edge("17", "0", weight=2250)  
G.add_edge("17", "4", weight=2250)  
G.add_edge("17", "6", weight=2250)  
G.add_edge("17", "11", weight=2250)  
G.add_edge("17", "14", weight=0)  
G.add_edge("17", "31", weight=2250)  
G.add_edge("17", "31", weight=2250)  
G.add_edge("17", "31", weight=2250)  
G.add_edge("17", "37", weight=2250)  
G.add_edge("17", "38", weight=2250)  
G.add_edge("17", "43", weight=2250)  
G.add_edge("17", "48", weight=2250)  
G.add_edge("17", "49", weight=0)  
G.add_edge("17", "50", weight=0)  
G.add_edge("17", "51", weight=0)  
G.add_edge("17", "53", weight=0)  
G.add_edge("17", "57", weight=2250)  
G.add_edge("17", "58", weight=2250)  
G.add_edge("17", "62", weight=18000)  
G.add_edge("17", "62", weight=2250)  
G.add_edge("17", "62", weight=2250)  
G.add_edge("17", "69", weight=2250)  
G.add_edge("17", "75", weight=2250)  
G.add_edge("17", "75", weight=2250)  
G.add_edge("17", "76", weight=2250)  
G.add_edge("17", "76", weight=2250)  
G.add_edge("17", "82", weight=2250)  
G.add_edge("17", "101", weight=2250)  
G.add_edge("17", "107", weight=9000)  
G.add_edge("17", "110", weight=9000)  
G.add_edge("17", "112", weight=2250)  
G.add_edge("17", "137", weight=9000)  
G.add_edge("17", "138", weight=9000)  
G.add_edge("17", "138", weight=2250)  
G.add_edge("17", "142", weight=2250)  
G.add_edge("17", "172", weight=9000)  
G.add_edge("18", "1", weight=2278)  
G.add_edge("18", "2", weight=10338)  
G.add_edge("18", "6", weight=28363)  
G.add_edge("18", "9", weight=18542)  
G.add_edge("18", "14", weight=56762)  
G.add_edge("18", "15", weight=55)  
G.add_edge("18", "16", weight=0)  
G.add_edge("18", "19", weight=0)  
G.add_edge("18", "47", weight=1175)  
G.add_edge("18", "57", weight=1577)  
G.add_edge("18", "62", weight=8802)  
G.add_edge("18", "68", weight=213)  
G.add_edge("18", "79", weight=5320)  
G.add_edge("18", "80", weight=0)  
G.add_edge("18", "85", weight=21833)  
G.add_edge("18", "87", weight=191)  
G.add_edge("18", "107", weight=0)  
G.add_edge("18", "112", weight=3916)  
G.add_edge("18", "122", weight=2425)  
G.add_edge("18", "123", weight=2883)  
G.add_edge("18", "127", weight=2)  
G.add_edge("18", "128", weight=1)  
G.add_edge("18", "131", weight=0)  
G.add_edge("18", "133", weight=0)  
G.add_edge("18", "139", weight=0)  
G.add_edge("18", "142", weight=241)  
G.add_edge("18", "145", weight=0)  
G.add_edge("18", "147", weight=64)  
G.add_edge("18", "152", weight=0)  
G.add_edge("18", "154", weight=3)  
G.add_edge("18", "160", weight=5)  
G.add_edge("18", "163", weight=0)  
G.add_edge("18", "164", weight=0)  
G.add_edge("18", "165", weight=249)  
G.add_edge("18", "166", weight=2339)  
G.add_edge("18", "168", weight=4106)  
G.add_edge("18", "170", weight=1)  
G.add_edge("18", "171", weight=0)  
G.add_edge("18", "172", weight=1558)  
G.add_edge("18", "173", weight=0)  
G.add_edge("19", "1", weight=2250)  
G.add_edge("19", "1", weight=2250)  
G.add_edge("19", "18", weight=2250)  
G.add_edge("19", "23", weight=0)  
G.add_edge("19", "28", weight=0)  
G.add_edge("19", "31", weight=2250)  
G.add_edge("19", "31", weight=2250)  
G.add_edge("19", "31", weight=2250)  
G.add_edge("19", "37", weight=2250)  
G.add_edge("19", "38", weight=2250)  
G.add_edge("19", "43", weight=2250)  
G.add_edge("19", "48", weight=2250)  
G.add_edge("19", "49", weight=0)  
G.add_edge("19", "51", weight=0)  
G.add_edge("19", "53", weight=0)  
G.add_edge("19", "58", weight=2250)  
G.add_edge("19", "59", weight=18000)  
G.add_edge("19", "62", weight=9000)  
G.add_edge("19", "65", weight=2250)  
G.add_edge("19", "65", weight=2250)  
G.add_edge("19", "66", weight=2250)  
G.add_edge("19", "66", weight=2250)  
G.add_edge("19", "76", weight=2250)  
G.add_edge("19", "76", weight=2250)  
G.add_edge("19", "87", weight=2250)  
G.add_edge("19", "101", weight=2250)  
G.add_edge("19", "142", weight=2250)  
G.add_edge("19", "168", weight=9000)  
G.add_edge("20", "0", weight=2250)  
G.add_edge("20", "1", weight=2250)  
G.add_edge("20", "4", weight=2250)  
G.add_edge("20", "13", weight=0)  
G.add_edge("20", "15", weight=0)  
G.add_edge("20", "22", weight=0)  
G.add_edge("20", "31", weight=2250)  
G.add_edge("20", "31", weight=2250)  
G.add_edge("20", "37", weight=2250)  
G.add_edge("20", "38", weight=2250)  
G.add_edge("20", "43", weight=2250)  
G.add_edge("20", "44", weight=2250)  
G.add_edge("20", "46", weight=2250)  
G.add_edge("20", "48", weight=2250)  
G.add_edge("20", "49", weight=0)  
G.add_edge("20", "51", weight=0)  
G.add_edge("20", "51", weight=0)  
G.add_edge("20", "51", weight=0)  
G.add_edge("20", "53", weight=0)  
G.add_edge("20", "57", weight=2250)  
G.add_edge("20", "62", weight=9000)  
G.add_edge("20", "65", weight=2250)  
G.add_edge("20", "70", weight=9000)  
G.add_edge("20", "70", weight=2250)  
G.add_edge("20", "76", weight=2250)  
G.add_edge("20", "100", weight=9000)  
G.add_edge("20", "125", weight=9000)  
G.add_edge("21", "0", weight=2250)  
G.add_edge("21", "1", weight=2250)  
G.add_edge("21", "9", weight=2250)  
G.add_edge("21", "11", weight=2250)  
G.add_edge("21", "13", weight=0)  
G.add_edge("21", "31", weight=2250)  
G.add_edge("21", "37", weight=2250)  
G.add_edge("21", "38", weight=2250)  
G.add_edge("21", "43", weight=2250)  
G.add_edge("21", "46", weight=2250)  
G.add_edge("21", "49", weight=0)  
G.add_edge("21", "51", weight=0)  
G.add_edge("21", "53", weight=0)  
G.add_edge("21", "59", weight=9000)  
G.add_edge("21", "62", weight=9000)  
G.add_edge("21", "62", weight=2250)  
G.add_edge("21", "65", weight=2250)  
G.add_edge("21", "65", weight=2250)  
G.add_edge("21", "76", weight=2250)  
G.add_edge("21", "91", weight=2250)  
G.add_edge("21", "95", weight=2250)  
G.add_edge("21", "114", weight=2250)  
G.add_edge("21", "115", weight=2250)  
G.add_edge("21", "122", weight=9000)  
G.add_edge("21", "125", weight=2250)  
G.add_edge("21", "149", weight=2250)  
G.add_edge("21", "174", weight=9000)  
G.add_edge("21", "175", weight=2250)  
G.add_edge("22", "0", weight=2250)  
G.add_edge("22", "1", weight=2250)  
G.add_edge("22", "7", weight=2250)  
G.add_edge("22", "8", weight=2250)  
G.add_edge("22", "13", weight=0)  
G.add_edge("22", "14", weight=0)  
G.add_edge("22", "16", weight=0)  
G.add_edge("22", "20", weight=0)  
G.add_edge("22", "23", weight=0)  
G.add_edge("22", "24", weight=0)  
G.add_edge("22", "31", weight=2250)  
G.add_edge("22", "31", weight=2250)  
G.add_edge("22", "33", weight=2250)  
G.add_edge("22", "37", weight=2250)  
G.add_edge("22", "38", weight=2250)  
G.add_edge("22", "40", weight=2250)  
G.add_edge("22", "43", weight=2250)  
G.add_edge("22", "48", weight=2250)  
G.add_edge("22", "49", weight=0)  
G.add_edge("22", "51", weight=0)  
G.add_edge("22", "53", weight=0)  
G.add_edge("22", "57", weight=2250)  
G.add_edge("22", "59", weight=18000)  
G.add_edge("22", "65", weight=2250)  
G.add_edge("22", "76", weight=2250)  
G.add_edge("22", "76", weight=2250)  
G.add_edge("22", "126", weight=9000)  
G.add_edge("22", "128", weight=2250)  
G.add_edge("22", "142", weight=2250)  
G.add_edge("22", "175", weight=2250)  
G.add_edge("23", "0", weight=2250)  
G.add_edge("23", "1", weight=2250)  
G.add_edge("23", "1", weight=2250)  
G.add_edge("23", "1", weight=2250)  
G.add_edge("23", "4", weight=2250)  
G.add_edge("23", "6", weight=2250)  
G.add_edge("23", "10", weight=0)  
G.add_edge("23", "12", weight=0)  
G.add_edge("23", "15", weight=0)  
G.add_edge("23", "19", weight=0)  
G.add_edge("23", "22", weight=0)  
G.add_edge("23", "31", weight=2250)  
G.add_edge("23", "31", weight=2250)  
G.add_edge("23", "37", weight=2250)  
G.add_edge("23", "38", weight=2250)  
G.add_edge("23", "43", weight=2250)  
G.add_edge("23", "49", weight=0)  
G.add_edge("23", "51", weight=0)  
G.add_edge("23", "53", weight=0)  
G.add_edge("23", "57", weight=2250)  
G.add_edge("23", "59", weight=2250)  
G.add_edge("23", "62", weight=9000)  
G.add_edge("23", "63", weight=2250)  
G.add_edge("23", "64", weight=2250)  
G.add_edge("23", "65", weight=2250)  
G.add_edge("23", "75", weight=2250)  
G.add_edge("23", "83", weight=2250)  
G.add_edge("23", "87", weight=2250)  
G.add_edge("23", "107", weight=9000)  
G.add_edge("24", "1", weight=2250)  
G.add_edge("24", "2", weight=2250)  
G.add_edge("24", "22", weight=0)  
G.add_edge("24", "31", weight=2250)  
G.add_edge("24", "31", weight=2250)  
G.add_edge("24", "32", weight=0)  
G.add_edge("24", "37", weight=2250)  
G.add_edge("24", "38", weight=2250)  
G.add_edge("24", "39", weight=2250)  
G.add_edge("24", "43", weight=2250)  
G.add_edge("24", "43", weight=2250)  
G.add_edge("24", "48", weight=2250)  
G.add_edge("24", "49", weight=0)  
G.add_edge("24", "51", weight=0)  
G.add_edge("24", "53", weight=0)  
G.add_edge("24", "57", weight=2250)  
G.add_edge("24", "59", weight=2250)  
G.add_edge("24", "62", weight=9000)  
G.add_edge("24", "65", weight=2250)  
G.add_edge("24", "75", weight=2250)  
G.add_edge("24", "76", weight=2250)  
G.add_edge("24", "76", weight=2250)  
G.add_edge("24", "78", weight=2250)  
G.add_edge("24", "109", weight=2250)  
G.add_edge("24", "138", weight=9000)  
G.add_edge("24", "142", weight=2250)  
G.add_edge("24", "166", weight=9000)  
G.add_edge("25", "1", weight=2250)  
G.add_edge("25", "6", weight=2250)  
G.add_edge("25", "31", weight=2250)  
G.add_edge("25", "31", weight=2250)  
G.add_edge("25", "37", weight=2250)  
G.add_edge("25", "43", weight=2250)  
G.add_edge("25", "43", weight=2250)  
G.add_edge("25", "49", weight=0)  
G.add_edge("25", "51", weight=0)  
G.add_edge("25", "53", weight=0)  
G.add_edge("25", "57", weight=2250)  
G.add_edge("25", "62", weight=12600)  
G.add_edge("25", "69", weight=2250)  
G.add_edge("25", "75", weight=2250)  
G.add_edge("25", "94", weight=2250)  
G.add_edge("25", "116", weight=9000)  
G.add_edge("25", "118", weight=9000)  
G.add_edge("25", "128", weight=2250)  
G.add_edge("25", "135", weight=2250)  
G.add_edge("25", "138", weight=9000)  
G.add_edge("25", "154", weight=2250)  
G.add_edge("25", "161", weight=9000)  
G.add_edge("25", "163", weight=2250)  
G.add_edge("25", "175", weight=2250)  
G.add_edge("26", "1", weight=2250)  
G.add_edge("26", "1", weight=2250)  
G.add_edge("26", "4", weight=2250)  
G.add_edge("26", "5", weight=2250)  
G.add_edge("26", "10", weight=0)  
G.add_edge("26", "11", weight=2250)  
G.add_edge("26", "12", weight=0)  
G.add_edge("26", "12", weight=0)  
G.add_edge("26", "31", weight=2250)  
G.add_edge("26", "37", weight=2250)  
G.add_edge("26", "43", weight=2250)  
G.add_edge("26", "43", weight=2250)  
G.add_edge("26", "46", weight=9000)  
G.add_edge("26", "49", weight=0)  
G.add_edge("26", "51", weight=0)  
G.add_edge("26", "53", weight=0)  
G.add_edge("26", "57", weight=2250)  
G.add_edge("26", "62", weight=18000)  
G.add_edge("26", "75", weight=2250)  
G.add_edge("26", "76", weight=2250)  
G.add_edge("26", "77", weight=2250)  
G.add_edge("26", "87", weight=9000)  
G.add_edge("26", "126", weight=9000)  
G.add_edge("26", "165", weight=2250)  
G.add_edge("26", "175", weight=2250)  
G.add_edge("27", "0", weight=9000)  
G.add_edge("27", "1", weight=2250)  
G.add_edge("27", "4", weight=2250)  
G.add_edge("27", "11", weight=2250)  
G.add_edge("27", "31", weight=2250)  
G.add_edge("27", "31", weight=2250)  
G.add_edge("27", "31", weight=2250)  
G.add_edge("27", "37", weight=2250)  
G.add_edge("27", "40", weight=2250)  
G.add_edge("27", "40", weight=2250)  
G.add_edge("27", "43", weight=2250)  
G.add_edge("27", "43", weight=2250)  
G.add_edge("27", "44", weight=2250)  
G.add_edge("27", "49", weight=0)  
G.add_edge("27", "51", weight=0)  
G.add_edge("27", "51", weight=0)  
G.add_edge("27", "51", weight=0)  
G.add_edge("27", "53", weight=0)  
G.add_edge("27", "57", weight=2250)  
G.add_edge("27", "62", weight=9000)  
G.add_edge("27", "81", weight=2250)  
G.add_edge("27", "81", weight=2250)  
G.add_edge("27", "85", weight=2250)  
G.add_edge("27", "97", weight=2250)  
G.add_edge("27", "98", weight=2250)  
G.add_edge("27", "100", weight=2250)  
G.add_edge("27", "109", weight=2250)  
G.add_edge("27", "142", weight=2250)  
G.add_edge("27", "145", weight=2250)  
G.add_edge("27", "146", weight=2250)  
G.add_edge("27", "150", weight=2250)  
G.add_edge("27", "159", weight=2250)  
G.add_edge("27", "162", weight=9000)  
G.add_edge("27", "168", weight=9000)  
G.add_edge("27", "174", weight=18000)  
G.add_edge("28", "0", weight=2250)  
G.add_edge("28", "1", weight=2250)  
G.add_edge("28", "4", weight=2250)  
G.add_edge("28", "11", weight=2250)  
G.add_edge("28", "13", weight=0)  
G.add_edge("28", "19", weight=0)  
G.add_edge("28", "31", weight=2250)  
G.add_edge("28", "31", weight=2250)  
G.add_edge("28", "31", weight=2250)  
G.add_edge("28", "31", weight=2250)  
G.add_edge("28", "37", weight=2250)  
G.add_edge("28", "38", weight=2250)  
G.add_edge("28", "40", weight=2250)  
G.add_edge("28", "43", weight=2250)  
G.add_edge("28", "49", weight=0)  
G.add_edge("28", "51", weight=0)  
G.add_edge("28", "53", weight=0)  
G.add_edge("28", "57", weight=2250)  
G.add_edge("28", "62", weight=9000)  
G.add_edge("28", "65", weight=2250)  
G.add_edge("28", "68", weight=2250)  
G.add_edge("28", "76", weight=2250)  
G.add_edge("28", "87", weight=2250)  
G.add_edge("28", "127", weight=9000)  
G.add_edge("28", "128", weight=9000)  
G.add_edge("28", "130", weight=9000)  
G.add_edge("28", "138", weight=9000)  
G.add_edge("29", "0", weight=2250)  
G.add_edge("29", "1", weight=2250)  
G.add_edge("29", "5", weight=2250)  
G.add_edge("29", "9", weight=2250)  
G.add_edge("29", "11", weight=2250)  
G.add_edge("29", "12", weight=0)  
G.add_edge("29", "31", weight=2250)  
G.add_edge("29", "36", weight=2250)  
G.add_edge("29", "37", weight=2250)  
G.add_edge("29", "38", weight=2250)  
G.add_edge("29", "39", weight=2250)  
G.add_edge("29", "43", weight=2250)  
G.add_edge("29", "46", weight=2250)  
G.add_edge("29", "48", weight=2250)  
G.add_edge("29", "49", weight=0)  
G.add_edge("29", "51", weight=0)  
G.add_edge("29", "52", weight=0)  
G.add_edge("29", "53", weight=0)  
G.add_edge("29", "57", weight=2250)  
G.add_edge("29", "59", weight=9000)  
G.add_edge("29", "62", weight=9000)  
G.add_edge("29", "62", weight=9000)  
G.add_edge("29", "65", weight=2250)  
G.add_edge("29", "75", weight=2250)  
G.add_edge("29", "107", weight=9000)  
G.add_edge("29", "119", weight=2250)  
G.add_edge("29", "140", weight=2250)  
G.add_edge("29", "141", weight=2250)  
G.add_edge("29", "142", weight=2250)  
G.add_edge("30", "1", weight=2250)  
G.add_edge("30", "5", weight=2250)  
G.add_edge("30", "11", weight=2250)  
G.add_edge("30", "14", weight=0)  
G.add_edge("30", "14", weight=0)  
G.add_edge("30", "31", weight=2250)  
G.add_edge("30", "31", weight=2250)  
G.add_edge("30", "31", weight=2250)  
G.add_edge("30", "37", weight=2250)  
G.add_edge("30", "38", weight=2250)  
G.add_edge("30", "43", weight=2250)  
G.add_edge("30", "48", weight=2250)  
G.add_edge("30", "49", weight=0)  
G.add_edge("30", "51", weight=0)  
G.add_edge("30", "53", weight=0)  
G.add_edge("30", "57", weight=2250)  
G.add_edge("30", "65", weight=2250)  
G.add_edge("30", "76", weight=2250)  
G.add_edge("30", "138", weight=9000)  
G.add_edge("30", "174", weight=2250)  
G.add_edge("30", "174", weight=18000)  
G.add_edge("31", "2", weight=1500)  
G.add_edge("31", "4", weight=1500)  
G.add_edge("31", "5", weight=1500)  
G.add_edge("31", "6", weight=1000)  
G.add_edge("31", "6", weight=1000)  
G.add_edge("31", "6", weight=1000)  
G.add_edge("31", "8", weight=1500)  
G.add_edge("31", "9", weight=1500)  
G.add_edge("31", "11", weight=1500)  
G.add_edge("31", "13", weight=1500)  
G.add_edge("31", "13", weight=1500)  
G.add_edge("31", "13", weight=1500)  
G.add_edge("31", "14", weight=1500)  
G.add_edge("31", "14", weight=1500)  
G.add_edge("31", "14", weight=1500)  
G.add_edge("31", "14", weight=1500)  
G.add_edge("31", "15", weight=1500)  
G.add_edge("31", "17", weight=1500)  
G.add_edge("31", "17", weight=1500)  
G.add_edge("31", "17", weight=1500)  
G.add_edge("31", "19", weight=1500)  
G.add_edge("31", "19", weight=1500)  
G.add_edge("31", "19", weight=1500)  
G.add_edge("31", "20", weight=1500)  
G.add_edge("31", "20", weight=1500)  
G.add_edge("31", "21", weight=1500)  
G.add_edge("31", "22", weight=1500)  
G.add_edge("31", "22", weight=1500)  
G.add_edge("31", "23", weight=1500)  
G.add_edge("31", "23", weight=1500)  
G.add_edge("31", "24", weight=1500)  
G.add_edge("31", "24", weight=1500)  
G.add_edge("31", "25", weight=1500)  
G.add_edge("31", "25", weight=1500)  
G.add_edge("31", "27", weight=1500)  
G.add_edge("31", "27", weight=1500)  
G.add_edge("31", "27", weight=1500)  
G.add_edge("31", "28", weight=1500)  
G.add_edge("31", "28", weight=1500)  
G.add_edge("31", "28", weight=1500)  
G.add_edge("31", "28", weight=1500)  
G.add_edge("31", "30", weight=1500)  
G.add_edge("31", "30", weight=1500)  
G.add_edge("31", "30", weight=1500)  
G.add_edge("31", "32", weight=1500)  
G.add_edge("31", "32", weight=1500)  
G.add_edge("31", "32", weight=1500)  
G.add_edge("31", "39", weight=1500)  
G.add_edge("31", "41", weight=1000)  
G.add_edge("31", "43", weight=1500)  
G.add_edge("31", "43", weight=1500)  
G.add_edge("31", "43", weight=1500)  
G.add_edge("31", "44", weight=1000)  
G.add_edge("31", "49", weight=1500)  
G.add_edge("31", "50", weight=1500)  
G.add_edge("31", "50", weight=1500)  
G.add_edge("31", "51", weight=1500)  
G.add_edge("31", "52", weight=1500)  
G.add_edge("31", "52", weight=1500)  
G.add_edge("31", "53", weight=1500)  
G.add_edge("31", "54", weight=1000)  
G.add_edge("31", "56", weight=1500)  
G.add_edge("31", "57", weight=1500)  
G.add_edge("31", "58", weight=1500)  
G.add_edge("31", "64", weight=1000)  
G.add_edge("31", "65", weight=1500)  
G.add_edge("31", "67", weight=1500)  
G.add_edge("31", "69", weight=1000)  
G.add_edge("31", "70", weight=1500)  
G.add_edge("31", "70", weight=1000)  
G.add_edge("31", "71", weight=1500)  
G.add_edge("31", "72", weight=1500)  
G.add_edge("31", "74", weight=1000)  
G.add_edge("31", "85", weight=1000)  
G.add_edge("31", "92", weight=1500)  
G.add_edge("31", "94", weight=1500)  
G.add_edge("31", "95", weight=1000)  
G.add_edge("31", "97", weight=1000)  
G.add_edge("31", "99", weight=1000)  
G.add_edge("31", "100", weight=1000)  
G.add_edge("31", "109", weight=1000)  
G.add_edge("31", "114", weight=1000)  
G.add_edge("31", "119", weight=1000)  
G.add_edge("31", "125", weight=1000)  
G.add_edge("31", "126", weight=1000)  
G.add_edge("31", "128", weight=1000)  
G.add_edge("31", "131", weight=1000)  
G.add_edge("31", "132", weight=1000)  
G.add_edge("31", "142", weight=1000)  
G.add_edge("31", "143", weight=1000)  
G.add_edge("31", "144", weight=1000)  
G.add_edge("31", "146", weight=1000)  
G.add_edge("31", "154", weight=1000)  
G.add_edge("31", "161", weight=1000)  
G.add_edge("31", "165", weight=1000)  
G.add_edge("31", "171", weight=1000)  
G.add_edge("31", "174", weight=1000)  
G.add_edge("31", "175", weight=1000)  
G.add_edge("32", "1", weight=2250)  
G.add_edge("32", "1", weight=2250)  
G.add_edge("32", "11", weight=2250)  
G.add_edge("32", "12", weight=0)  
G.add_edge("32", "24", weight=0)  
G.add_edge("32", "31", weight=2250)  
G.add_edge("32", "31", weight=2250)  
G.add_edge("32", "31", weight=2250)  
G.add_edge("32", "37", weight=2250)  
G.add_edge("32", "38", weight=2250)  
G.add_edge("32", "43", weight=2250)  
G.add_edge("32", "46", weight=9000)  
G.add_edge("32", "48", weight=2250)  
G.add_edge("32", "49", weight=0)  
G.add_edge("32", "51", weight=0)  
G.add_edge("32", "53", weight=0)  
G.add_edge("32", "53", weight=0)  
G.add_edge("32", "57", weight=2250)  
G.add_edge("32", "59", weight=18000)  
G.add_edge("32", "62", weight=18000)  
G.add_edge("32", "65", weight=2250)  
G.add_edge("32", "68", weight=2250)  
G.add_edge("32", "70", weight=9000)  
G.add_edge("32", "76", weight=2250)  
G.add_edge("32", "76", weight=2250)  
G.add_edge("32", "87", weight=2250)  
G.add_edge("32", "105", weight=2250)  
G.add_edge("32", "138", weight=9000)  
G.add_edge("32", "142", weight=2250)  
G.add_edge("32", "168", weight=9000)  
G.add_edge("33", "0", weight=0)  
G.add_edge("33", "1", weight=0)  
G.add_edge("33", "2", weight=0)  
G.add_edge("33", "4", weight=0)  
G.add_edge("33", "11", weight=0)  
G.add_edge("33", "13", weight=0)  
G.add_edge("33", "22", weight=0)  
G.add_edge("33", "46", weight=0)  
G.add_edge("33", "58", weight=0)  
G.add_edge("33", "62", weight=0)  
G.add_edge("33", "70", weight=0)  
G.add_edge("33", "116", weight=0)  
G.add_edge("33", "125", weight=0)  
G.add_edge("33", "130", weight=0)  
G.add_edge("33", "131", weight=0)  
G.add_edge("33", "147", weight=0)  
G.add_edge("33", "161", weight=0)  
G.add_edge("34", "3", weight=1000)  
G.add_edge("34", "3", weight=1000)  
G.add_edge("34", "3", weight=1000)  
G.add_edge("34", "6", weight=1000)  
G.add_edge("34", "7", weight=1000)  
G.add_edge("34", "15", weight=1000)  
G.add_edge("34", "51", weight=1000)  
G.add_edge("34", "58", weight=1000)  
G.add_edge("34", "59", weight=1000)  
G.add_edge("34", "69", weight=1000)  
G.add_edge("34", "72", weight=1000)  
G.add_edge("34", "83", weight=1000)  
G.add_edge("34", "87", weight=1000)  
G.add_edge("34", "97", weight=1000)  
G.add_edge("34", "100", weight=1000)  
G.add_edge("34", "107", weight=1000)  
G.add_edge("34", "118", weight=1000)  
G.add_edge("34", "127", weight=1000)  
G.add_edge("34", "128", weight=1000)  
G.add_edge("34", "130", weight=1000)  
G.add_edge("34", "131", weight=1000)  
G.add_edge("34", "132", weight=1000)  
G.add_edge("34", "139", weight=1000)  
G.add_edge("34", "140", weight=1000)  
G.add_edge("34", "144", weight=1000)  
G.add_edge("34", "156", weight=1000)  
G.add_edge("34", "166", weight=1000)  
G.add_edge("34", "175", weight=1000)  
G.add_edge("35", "0", weight=500)  
G.add_edge("35", "7", weight=500)  
G.add_edge("35", "9", weight=500)  
G.add_edge("35", "39", weight=500)  
G.add_edge("35", "41", weight=500)  
G.add_edge("35", "44", weight=500)  
G.add_edge("35", "47", weight=500)  
G.add_edge("35", "49", weight=500)  
G.add_edge("35", "58", weight=500)  
G.add_edge("35", "60", weight=500)  
G.add_edge("35", "60", weight=500)  
G.add_edge("35", "62", weight=500)  
G.add_edge("35", "63", weight=500)  
G.add_edge("35", "64", weight=500)  
G.add_edge("35", "65", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "70", weight=500)  
G.add_edge("35", "73", weight=500)  
G.add_edge("35", "73", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "85", weight=500)  
G.add_edge("35", "86", weight=500)  
G.add_edge("35", "86", weight=500)  
G.add_edge("35", "86", weight=500)  
G.add_edge("35", "95", weight=500)  
G.add_edge("35", "97", weight=500)  
G.add_edge("35", "98", weight=500)  
G.add_edge("35", "98", weight=500)  
G.add_edge("35", "98", weight=500)  
G.add_edge("35", "99", weight=500)  
G.add_edge("35", "100", weight=500)  
G.add_edge("35", "103", weight=500)  
G.add_edge("35", "104", weight=5000)  
G.add_edge("35", "108", weight=500)  
G.add_edge("35", "114", weight=500)  
G.add_edge("35", "128", weight=500)  
G.add_edge("35", "129", weight=500)  
G.add_edge("35", "130", weight=500)  
G.add_edge("35", "134", weight=500)  
G.add_edge("35", "135", weight=500)  
G.add_edge("35", "138", weight=500)  
G.add_edge("35", "142", weight=500)  
G.add_edge("35", "143", weight=500)  
G.add_edge("35", "144", weight=500)  
G.add_edge("35", "146", weight=500)  
G.add_edge("35", "147", weight=500)  
G.add_edge("35", "157", weight=500)  
G.add_edge("35", "163", weight=500)  
G.add_edge("35", "165", weight=500)  
G.add_edge("35", "166", weight=500)  
G.add_edge("35", "174", weight=500)  
G.add_edge("35", "174", weight=500)  
G.add_edge("35", "174", weight=500)  
G.add_edge("35", "175", weight=500)  
G.add_edge("35", "176", weight=500)  
G.add_edge("35", "176", weight=500)  
G.add_edge("36", "7", weight=1000)  
G.add_edge("36", "29", weight=1000)  
G.add_edge("36", "39", weight=1000)  
G.add_edge("36", "43", weight=1000)  
G.add_edge("36", "44", weight=1000)  
G.add_edge("36", "69", weight=1000)  
G.add_edge("36", "146", weight=1000)  
G.add_edge("36", "155", weight=1000)  
G.add_edge("36", "168", weight=1000)  
G.add_edge("37", "6", weight=4000)  
G.add_edge("37", "7", weight=200)  
G.add_edge("37", "8", weight=4000)  
G.add_edge("37", "10", weight=100)  
G.add_edge("37", "12", weight=100)  
G.add_edge("37", "13", weight=100)  
G.add_edge("37", "14", weight=200)  
G.add_edge("37", "15", weight=100)  
G.add_edge("37", "16", weight=200)  
G.add_edge("37", "17", weight=200)  
G.add_edge("37", "19", weight=200)  
G.add_edge("37", "20", weight=100)  
G.add_edge("37", "21", weight=200)  
G.add_edge("37", "22", weight=100)  
G.add_edge("37", "23", weight=200)  
G.add_edge("37", "24", weight=100)  
G.add_edge("37", "25", weight=100)  
G.add_edge("37", "26", weight=200)  
G.add_edge("37", "27", weight=100)  
G.add_edge("37", "28", weight=100)  
G.add_edge("37", "29", weight=100)  
G.add_edge("37", "30", weight=200)  
G.add_edge("37", "32", weight=100)  
G.add_edge("37", "39", weight=100)  
G.add_edge("37", "45", weight=100)  
G.add_edge("37", "46", weight=200)  
G.add_edge("37", "49", weight=100)  
G.add_edge("37", "50", weight=100)  
G.add_edge("37", "51", weight=100)  
G.add_edge("37", "52", weight=200)  
G.add_edge("37", "53", weight=200)  
G.add_edge("37", "55", weight=100)  
G.add_edge("37", "59", weight=200)  
G.add_edge("37", "61", weight=4000)  
G.add_edge("37", "62", weight=200)  
G.add_edge("37", "64", weight=200)  
G.add_edge("37", "69", weight=100)  
G.add_edge("37", "70", weight=100)  
G.add_edge("37", "74", weight=100)  
G.add_edge("37", "79", weight=200)  
G.add_edge("37", "81", weight=395)  
G.add_edge("37", "83", weight=100)  
G.add_edge("37", "94", weight=100)  
G.add_edge("37", "99", weight=200)  
G.add_edge("37", "100", weight=200)  
G.add_edge("37", "107", weight=100)  
G.add_edge("37", "116", weight=200)  
G.add_edge("37", "125", weight=100)  
G.add_edge("37", "130", weight=200)  
G.add_edge("37", "136", weight=100)  
G.add_edge("37", "142", weight=200)  
G.add_edge("37", "144", weight=200)  
G.add_edge("38", "2", weight=0)  
G.add_edge("38", "6", weight=0)  
G.add_edge("38", "6", weight=0)  
G.add_edge("38", "9", weight=0)  
G.add_edge("38", "11", weight=0)  
G.add_edge("38", "12", weight=0)  
G.add_edge("38", "13", weight=0)  
G.add_edge("38", "14", weight=0)  
G.add_edge("38", "15", weight=0)  
G.add_edge("38", "17", weight=0)  
G.add_edge("38", "19", weight=0)  
G.add_edge("38", "20", weight=0)  
G.add_edge("38", "21", weight=0)  
G.add_edge("38", "22", weight=0)  
G.add_edge("38", "23", weight=0)  
G.add_edge("38", "24", weight=0)  
G.add_edge("38", "28", weight=0)  
G.add_edge("38", "29", weight=0)  
G.add_edge("38", "30", weight=0)  
G.add_edge("38", "32", weight=0)  
G.add_edge("38", "39", weight=0)  
G.add_edge("38", "46", weight=0)  
G.add_edge("38", "49", weight=0)  
G.add_edge("38", "51", weight=0)  
G.add_edge("38", "52", weight=0)  
G.add_edge("38", "53", weight=0)  
G.add_edge("38", "65", weight=0)  
G.add_edge("38", "74", weight=0)  
G.add_edge("38", "77", weight=0)  
G.add_edge("38", "79", weight=0)  
G.add_edge("38", "94", weight=0)  
G.add_edge("38", "97", weight=0)  
G.add_edge("38", "114", weight=0)  
G.add_edge("38", "142", weight=0)  
G.add_edge("38", "150", weight=0)  
G.add_edge("38", "166", weight=0)  
G.add_edge("38", "174", weight=0)  
G.add_edge("38", "174", weight=0)  
G.add_edge("39", "1", weight=0)  
G.add_edge("39", "2", weight=0)  
G.add_edge("39", "3", weight=0)  
G.add_edge("39", "6", weight=0)  
G.add_edge("39", "7", weight=0)  
G.add_edge("39", "9", weight=0)  
G.add_edge("39", "10", weight=0)  
G.add_edge("39", "13", weight=0)  
G.add_edge("39", "24", weight=0)  
G.add_edge("39", "29", weight=0)  
G.add_edge("39", "31", weight=0)  
G.add_edge("39", "35", weight=0)  
G.add_edge("39", "36", weight=0)  
G.add_edge("39", "37", weight=0)  
G.add_edge("39", "38", weight=0)  
G.add_edge("39", "40", weight=0)  
G.add_edge("39", "42", weight=0)  
G.add_edge("39", "44", weight=0)  
G.add_edge("39", "45", weight=0)  
G.add_edge("39", "46", weight=0)  
G.add_edge("39", "47", weight=0)  
G.add_edge("39", "48", weight=0)  
G.add_edge("39", "53", weight=0)  
G.add_edge("39", "54", weight=0)  
G.add_edge("39", "55", weight=0)  
G.add_edge("39", "57", weight=0)  
G.add_edge("39", "58", weight=0)  
G.add_edge("39", "61", weight=0)  
G.add_edge("39", "62", weight=0)  
G.add_edge("39", "65", weight=0)  
G.add_edge("39", "66", weight=0)  
G.add_edge("39", "69", weight=0)  
G.add_edge("39", "70", weight=0)  
G.add_edge("39", "71", weight=0)  
G.add_edge("39", "74", weight=0)  
G.add_edge("39", "76", weight=0)  
G.add_edge("39", "77", weight=0)  
G.add_edge("39", "79", weight=0)  
G.add_edge("39", "81", weight=0)  
G.add_edge("39", "85", weight=0)  
G.add_edge("39", "87", weight=0)  
G.add_edge("39", "89", weight=0)  
G.add_edge("39", "90", weight=0)  
G.add_edge("39", "91", weight=0)  
G.add_edge("39", "92", weight=0)  
G.add_edge("39", "94", weight=0)  
G.add_edge("39", "95", weight=0)  
G.add_edge("39", "96", weight=0)  
G.add_edge("39", "100", weight=0)  
G.add_edge("39", "104", weight=0)  
G.add_edge("39", "110", weight=0)  
G.add_edge("39", "113", weight=0)  
G.add_edge("39", "115", weight=0)  
G.add_edge("39", "117", weight=0)  
G.add_edge("39", "125", weight=0)  
G.add_edge("39", "127", weight=0)  
G.add_edge("39", "128", weight=0)  
G.add_edge("39", "137", weight=0)  
G.add_edge("39", "138", weight=0)  
G.add_edge("39", "142", weight=0)  
G.add_edge("39", "144", weight=0)  
G.add_edge("39", "147", weight=0)  
G.add_edge("39", "150", weight=0)  
G.add_edge("39", "156", weight=0)  
G.add_edge("39", "159", weight=0)  
G.add_edge("39", "162", weight=0)  
G.add_edge("39", "167", weight=0)  
G.add_edge("39", "168", weight=0)  
G.add_edge("39", "169", weight=0)  
G.add_edge("39", "170", weight=0)  
G.add_edge("39", "174", weight=0)  
G.add_edge("39", "175", weight=0)  
G.add_edge("40", "4", weight=1000)  
G.add_edge("40", "6", weight=2000)  
G.add_edge("40", "22", weight=1000)  
G.add_edge("40", "27", weight=1000)  
G.add_edge("40", "27", weight=1000)  
G.add_edge("40", "28", weight=1000)  
G.add_edge("40", "39", weight=1000)  
G.add_edge("40", "41", weight=1000)  
G.add_edge("40", "44", weight=1000)  
G.add_edge("40", "56", weight=1000)  
G.add_edge("40", "57", weight=1000)  
G.add_edge("40", "60", weight=1000)  
G.add_edge("40", "62", weight=2000)  
G.add_edge("40", "63", weight=1000)  
G.add_edge("40", "64", weight=1000)  
G.add_edge("40", "69", weight=1000)  
G.add_edge("40", "71", weight=1000)  
G.add_edge("40", "74", weight=1000)  
G.add_edge("40", "83", weight=1000)  
G.add_edge("40", "84", weight=2000)  
G.add_edge("40", "84", weight=2000)  
G.add_edge("40", "85", weight=2000)  
G.add_edge("40", "85", weight=2000)  
G.add_edge("40", "92", weight=1000)  
G.add_edge("40", "95", weight=1000)  
G.add_edge("40", "97", weight=1000)  
G.add_edge("40", "100", weight=1000)  
G.add_edge("40", "104", weight=2000)  
G.add_edge("40", "106", weight=1000)  
G.add_edge("40", "107", weight=1000)  
G.add_edge("40", "108", weight=1000)  
G.add_edge("40", "108", weight=1000)  
G.add_edge("40", "109", weight=1000)  
G.add_edge("40", "110", weight=1000)  
G.add_edge("40", "111", weight=2000)  
G.add_edge("40", "113", weight=1000)  
G.add_edge("40", "114", weight=1000)  
G.add_edge("40", "124", weight=1000)  
G.add_edge("40", "125", weight=1000)  
G.add_edge("40", "128", weight=1000)  
G.add_edge("40", "129", weight=1000)  
G.add_edge("40", "130", weight=1000)  
G.add_edge("40", "131", weight=1000)  
G.add_edge("40", "132", weight=1000)  
G.add_edge("40", "134", weight=1000)  
G.add_edge("40", "135", weight=1000)  
G.add_edge("40", "137", weight=1000)  
G.add_edge("40", "143", weight=1000)  
G.add_edge("40", "146", weight=1000)  
G.add_edge("40", "147", weight=1000)  
G.add_edge("40", "163", weight=1000)  
G.add_edge("40", "165", weight=1000)  
G.add_edge("40", "166", weight=1000)  
G.add_edge("40", "168", weight=1000)  
G.add_edge("40", "170", weight=1000)  
G.add_edge("40", "171", weight=1000)  
G.add_edge("40", "174", weight=1000)  
G.add_edge("40", "175", weight=1000)  
G.add_edge("41", "1", weight=100)  
G.add_edge("41", "4", weight=100)  
G.add_edge("41", "5", weight=100)  
G.add_edge("41", "6", weight=100)  
G.add_edge("41", "6", weight=100)  
G.add_edge("41", "6", weight=100)  
G.add_edge("41", "9", weight=100)  
G.add_edge("41", "31", weight=0)  
G.add_edge("41", "35", weight=0)  
G.add_edge("41", "40", weight=0)  
G.add_edge("41", "44", weight=100)  
G.add_edge("41", "47", weight=100)  
G.add_edge("41", "48", weight=100)  
G.add_edge("41", "49", weight=100)  
G.add_edge("41", "49", weight=100)  
G.add_edge("41", "51", weight=100)  
G.add_edge("41", "51", weight=100)  
G.add_edge("41", "51", weight=100)  
G.add_edge("41", "51", weight=100)  
G.add_edge("41", "53", weight=100)  
G.add_edge("41", "53", weight=100)  
G.add_edge("41", "53", weight=100)  
G.add_edge("41", "55", weight=100)  
G.add_edge("41", "57", weight=100)  
G.add_edge("41", "59", weight=100)  
G.add_edge("41", "60", weight=100)  
G.add_edge("41", "62", weight=100)  
G.add_edge("41", "62", weight=100)  
G.add_edge("41", "62", weight=100)  
G.add_edge("41", "64", weight=100)  
G.add_edge("41", "66", weight=100)  
G.add_edge("41", "67", weight=100)  
G.add_edge("41", "69", weight=100)  
G.add_edge("41", "70", weight=100)  
G.add_edge("41", "70", weight=100)  
G.add_edge("41", "70", weight=100)  
G.add_edge("41", "79", weight=100)  
G.add_edge("41", "79", weight=100)  
G.add_edge("41", "79", weight=100)  
G.add_edge("41", "79", weight=100)  
G.add_edge("41", "79", weight=100)  
G.add_edge("41", "83", weight=100)  
G.add_edge("41", "84", weight=100)  
G.add_edge("41", "85", weight=100)  
G.add_edge("41", "85", weight=100)  
G.add_edge("41", "87", weight=100)  
G.add_edge("41", "94", weight=100)  
G.add_edge("41", "95", weight=0)  
G.add_edge("41", "98", weight=100)  
G.add_edge("41", "98", weight=100)  
G.add_edge("41", "99", weight=100)  
G.add_edge("41", "100", weight=100)  
G.add_edge("41", "101", weight=100)  
G.add_edge("41", "103", weight=100)  
G.add_edge("41", "104", weight=0)  
G.add_edge("41", "104", weight=0)  
G.add_edge("41", "106", weight=100)  
G.add_edge("41", "106", weight=100)  
G.add_edge("41", "107", weight=100)  
G.add_edge("41", "108", weight=100)  
G.add_edge("41", "108", weight=100)  
G.add_edge("41", "111", weight=0)  
G.add_edge("41", "113", weight=100)  
G.add_edge("41", "114", weight=100)  
G.add_edge("41", "122", weight=100)  
G.add_edge("41", "125", weight=100)  
G.add_edge("41", "126", weight=100)  
G.add_edge("41", "128", weight=100)  
G.add_edge("41", "130", weight=100)  
G.add_edge("41", "131", weight=100)  
G.add_edge("41", "138", weight=100)  
G.add_edge("41", "139", weight=100)  
G.add_edge("41", "142", weight=100)  
G.add_edge("41", "147", weight=100)  
G.add_edge("41", "154", weight=100)  
G.add_edge("41", "164", weight=100)  
G.add_edge("41", "166", weight=100)  
G.add_edge("41", "168", weight=100)  
G.add_edge("41", "171", weight=100)  
G.add_edge("41", "175", weight=0)  
G.add_edge("42", "0", weight=849)  
G.add_edge("42", "6", weight=849)  
G.add_edge("42", "7", weight=849)  
G.add_edge("42", "15", weight=849)  
G.add_edge("42", "39", weight=849)  
G.add_edge("42", "44", weight=849)  
G.add_edge("42", "57", weight=849)  
G.add_edge("42", "58", weight=849)  
G.add_edge("42", "69", weight=849)  
G.add_edge("42", "83", weight=849)  
G.add_edge("42", "85", weight=849)  
G.add_edge("42", "92", weight=849)  
G.add_edge("42", "97", weight=849)  
G.add_edge("42", "100", weight=849)  
G.add_edge("42", "103", weight=849)  
G.add_edge("42", "128", weight=849)  
G.add_edge("42", "129", weight=849)  
G.add_edge("42", "130", weight=849)  
G.add_edge("42", "131", weight=849)  
G.add_edge("42", "143", weight=849)  
G.add_edge("42", "157", weight=849)  
G.add_edge("42", "164", weight=849)  
G.add_edge("42", "165", weight=849)  
G.add_edge("42", "166", weight=849)  
G.add_edge("42", "174", weight=849)  
G.add_edge("43", "0", weight=80)  
G.add_edge("43", "2", weight=80)  
G.add_edge("43", "2", weight=80)  
G.add_edge("43", "3", weight=80)  
G.add_edge("43", "3", weight=80)  
G.add_edge("43", "4", weight=80)  
G.add_edge("43", "5", weight=80)  
G.add_edge("43", "6", weight=80)  
G.add_edge("43", "7", weight=80)  
G.add_edge("43", "9", weight=80)  
G.add_edge("43", "10", weight=80)  
G.add_edge("43", "10", weight=80)  
G.add_edge("43", "11", weight=80)  
G.add_edge("43", "11", weight=80)  
G.add_edge("43", "12", weight=80)  
G.add_edge("43", "13", weight=80)  
G.add_edge("43", "14", weight=80)  
G.add_edge("43", "15", weight=80)  
G.add_edge("43", "16", weight=80)  
G.add_edge("43", "17", weight=80)  
G.add_edge("43", "19", weight=80)  
G.add_edge("43", "20", weight=80)  
G.add_edge("43", "21", weight=80)  
G.add_edge("43", "22", weight=80)  
G.add_edge("43", "23", weight=80)  
G.add_edge("43", "24", weight=80)  
G.add_edge("43", "24", weight=80)  
G.add_edge("43", "25", weight=80)  
G.add_edge("43", "25", weight=80)  
G.add_edge("43", "26", weight=80)  
G.add_edge("43", "26", weight=80)  
G.add_edge("43", "27", weight=80)  
G.add_edge("43", "27", weight=80)  
G.add_edge("43", "28", weight=80)  
G.add_edge("43", "29", weight=80)  
G.add_edge("43", "30", weight=80)  
G.add_edge("43", "31", weight=80)  
G.add_edge("43", "31", weight=80)  
G.add_edge("43", "31", weight=80)  
G.add_edge("43", "32", weight=80)  
G.add_edge("43", "36", weight=80)  
G.add_edge("43", "44", weight=80)  
G.add_edge("43", "45", weight=80)  
G.add_edge("43", "46", weight=80)  
G.add_edge("43", "47", weight=80)  
G.add_edge("43", "48", weight=80)  
G.add_edge("43", "49", weight=80)  
G.add_edge("43", "50", weight=80)  
G.add_edge("43", "50", weight=80)  
G.add_edge("43", "50", weight=80)  
G.add_edge("43", "51", weight=80)  
G.add_edge("43", "52", weight=80)  
G.add_edge("43", "53", weight=80)  
G.add_edge("43", "53", weight=80)  
G.add_edge("43", "53", weight=80)  
G.add_edge("43", "55", weight=80)  
G.add_edge("43", "56", weight=80)  
G.add_edge("43", "57", weight=80)  
G.add_edge("43", "61", weight=80)  
G.add_edge("43", "62", weight=80)  
G.add_edge("43", "64", weight=80)  
G.add_edge("43", "66", weight=80)  
G.add_edge("43", "67", weight=80)  
G.add_edge("43", "68", weight=80)  
G.add_edge("43", "70", weight=80)  
G.add_edge("43", "71", weight=80)  
G.add_edge("43", "72", weight=80)  
G.add_edge("43", "72", weight=80)  
G.add_edge("43", "75", weight=80)  
G.add_edge("43", "76", weight=80)  
G.add_edge("43", "76", weight=80)  
G.add_edge("43", "79", weight=80)  
G.add_edge("43", "83", weight=80)  
G.add_edge("43", "85", weight=80)  
G.add_edge("43", "92", weight=80)  
G.add_edge("43", "95", weight=80)  
G.add_edge("43", "111", weight=80)  
G.add_edge("44", "2", weight=1000)  
G.add_edge("44", "4", weight=1000)  
G.add_edge("44", "5", weight=1000)  
G.add_edge("44", "6", weight=1000)  
G.add_edge("44", "8", weight=1000)  
G.add_edge("44", "8", weight=1000)  
G.add_edge("44", "9", weight=1000)  
G.add_edge("44", "20", weight=1000)  
G.add_edge("44", "27", weight=1000)  
G.add_edge("44", "31", weight=1000)  
G.add_edge("44", "35", weight=1000)  
G.add_edge("44", "36", weight=1000)  
G.add_edge("44", "39", weight=1000)  
G.add_edge("44", "40", weight=1000)  
G.add_edge("44", "41", weight=1000)  
G.add_edge("44", "42", weight=1000)  
G.add_edge("44", "43", weight=1000)  
G.add_edge("44", "46", weight=1000)  
G.add_edge("44", "48", weight=1000)  
G.add_edge("44", "53", weight=1000)  
G.add_edge("44", "55", weight=1000)  
G.add_edge("44", "56", weight=1000)  
G.add_edge("44", "57", weight=1000)  
G.add_edge("44", "59", weight=1000)  
G.add_edge("44", "60", weight=1000)  
G.add_edge("44", "60", weight=1000)  
G.add_edge("44", "61", weight=1000)  
G.add_edge("44", "62", weight=1000)  
G.add_edge("44", "63", weight=1000)  
G.add_edge("44", "64", weight=1000)  
G.add_edge("44", "66", weight=1000)  
G.add_edge("44", "67", weight=1000)  
G.add_edge("44", "68", weight=1000)  
G.add_edge("44", "69", weight=1000)  
G.add_edge("44", "70", weight=1000)  
G.add_edge("44", "70", weight=1000)  
G.add_edge("44", "71", weight=1000)  
G.add_edge("44", "74", weight=1000)  
G.add_edge("44", "75", weight=1000)  
G.add_edge("44", "78", weight=1000)  
G.add_edge("44", "79", weight=1000)  
G.add_edge("44", "80", weight=1000)  
G.add_edge("44", "82", weight=1000)  
G.add_edge("44", "83", weight=1000)  
G.add_edge("44", "85", weight=1000)  
G.add_edge("44", "87", weight=1000)  
G.add_edge("44", "94", weight=1000)  
G.add_edge("44", "95", weight=1000)  
G.add_edge("44", "97", weight=1000)  
G.add_edge("44", "100", weight=1000)  
G.add_edge("44", "102", weight=1000)  
G.add_edge("44", "103", weight=1000)  
G.add_edge("44", "104", weight=1000)  
G.add_edge("44", "107", weight=1000)  
G.add_edge("44", "110", weight=1000)  
G.add_edge("44", "111", weight=1000)  
G.add_edge("44", "113", weight=1000)  
G.add_edge("44", "114", weight=1000)  
G.add_edge("44", "116", weight=1000)  
G.add_edge("44", "118", weight=1000)  
G.add_edge("44", "122", weight=1000)  
G.add_edge("44", "123", weight=1000)  
G.add_edge("44", "123", weight=1000)  
G.add_edge("44", "125", weight=1000)  
G.add_edge("44", "126", weight=1000)  
G.add_edge("44", "127", weight=1000)  
G.add_edge("44", "128", weight=1000)  
G.add_edge("44", "129", weight=1000)  
G.add_edge("44", "130", weight=1000)  
G.add_edge("44", "131", weight=1000)  
G.add_edge("44", "132", weight=1000)  
G.add_edge("44", "135", weight=1000)  
G.add_edge("44", "137", weight=1000)  
G.add_edge("44", "138", weight=1000)  
G.add_edge("44", "142", weight=1000)  
G.add_edge("44", "146", weight=1000)  
G.add_edge("44", "147", weight=1000)  
G.add_edge("44", "154", weight=1000)  
G.add_edge("44", "161", weight=1000)  
G.add_edge("44", "163", weight=1000)  
G.add_edge("44", "164", weight=1000)  
G.add_edge("44", "166", weight=1000)  
G.add_edge("44", "168", weight=1000)  
G.add_edge("44", "170", weight=1000)  
G.add_edge("44", "171", weight=1000)  
G.add_edge("44", "173", weight=1000)  
G.add_edge("44", "174", weight=1000)  
G.add_edge("44", "175", weight=1000)  
G.add_edge("44", "176", weight=1000)  
G.add_edge("45", "6", weight=1)  
G.add_edge("45", "8", weight=1)  
G.add_edge("45", "8", weight=1)  
G.add_edge("45", "11", weight=1)  
G.add_edge("45", "12", weight=1)  
G.add_edge("45", "37", weight=1)  
G.add_edge("45", "39", weight=1)  
G.add_edge("45", "43", weight=1)  
G.add_edge("45", "51", weight=1)  
G.add_edge("45", "52", weight=1)  
G.add_edge("45", "53", weight=1)  
G.add_edge("45", "57", weight=1)  
G.add_edge("45", "65", weight=1)  
G.add_edge("45", "69", weight=1)  
G.add_edge("45", "74", weight=1)  
G.add_edge("45", "83", weight=1)  
G.add_edge("45", "85", weight=1)  
G.add_edge("45", "94", weight=1)  
G.add_edge("45", "100", weight=1)  
G.add_edge("45", "103", weight=1000)  
G.add_edge("45", "108", weight=1)  
G.add_edge("45", "108", weight=1)  
G.add_edge("45", "128", weight=1)  
G.add_edge("45", "130", weight=1)  
G.add_edge("45", "132", weight=1000)  
G.add_edge("45", "142", weight=1)  
G.add_edge("45", "143", weight=1)  
G.add_edge("45", "144", weight=1000)  
G.add_edge("45", "146", weight=1)  
G.add_edge("45", "155", weight=1)  
G.add_edge("45", "156", weight=1)  
G.add_edge("45", "161", weight=1)  
G.add_edge("45", "166", weight=1)  
G.add_edge("45", "168", weight=1)  
G.add_edge("45", "171", weight=1)  
G.add_edge("46", "0", weight=1000)  
G.add_edge("46", "2", weight=1000)  
G.add_edge("46", "6", weight=1000)  
G.add_edge("46", "11", weight=1000)  
G.add_edge("46", "13", weight=1000)  
G.add_edge("46", "14", weight=1000)  
G.add_edge("46", "20", weight=1000)  
G.add_edge("46", "21", weight=1000)  
G.add_edge("46", "26", weight=1000)  
G.add_edge("46", "29", weight=1000)  
G.add_edge("46", "32", weight=1000)  
G.add_edge("46", "33", weight=1000)  
G.add_edge("46", "37", weight=1000)  
G.add_edge("46", "38", weight=1000)  
G.add_edge("46", "39", weight=1000)  
G.add_edge("46", "43", weight=1000)  
G.add_edge("46", "44", weight=1000)  
G.add_edge("46", "49", weight=1000)  
G.add_edge("46", "50", weight=1000)  
G.add_edge("46", "52", weight=1000)  
G.add_edge("46", "53", weight=1000)  
G.add_edge("46", "56", weight=1000)  
G.add_edge("46", "58", weight=1000)  
G.add_edge("46", "61", weight=1000)  
G.add_edge("46", "69", weight=1000)  
G.add_edge("46", "71", weight=1000)  
G.add_edge("46", "72", weight=1000)  
G.add_edge("46", "76", weight=1000)  
G.add_edge("46", "79", weight=1000)  
G.add_edge("46", "83", weight=1000)  
G.add_edge("46", "85", weight=1000)  
G.add_edge("46", "87", weight=1000)  
G.add_edge("46", "92", weight=1000)  
G.add_edge("46", "100", weight=1000)  
G.add_edge("46", "102", weight=1000)  
G.add_edge("46", "107", weight=1000)  
G.add_edge("46", "108", weight=1000)  
G.add_edge("46", "108", weight=1000)  
G.add_edge("46", "113", weight=1000)  
G.add_edge("46", "115", weight=1000)  
G.add_edge("46", "126", weight=1000)  
G.add_edge("46", "127", weight=1000)  
G.add_edge("46", "128", weight=1000)  
G.add_edge("46", "132", weight=1000)  
G.add_edge("46", "136", weight=1000)  
G.add_edge("46", "138", weight=1000)  
G.add_edge("46", "142", weight=1000)  
G.add_edge("46", "146", weight=1000)  
G.add_edge("46", "147", weight=1000)  
G.add_edge("46", "155", weight=1000)  
G.add_edge("46", "155", weight=1000)  
G.add_edge("46", "166", weight=1000)  
G.add_edge("46", "168", weight=1000)  
G.add_edge("46", "170", weight=1000)  
G.add_edge("46", "171", weight=1000)  
G.add_edge("46", "175", weight=1000)  
G.add_edge("47", "0", weight=1000)  
G.add_edge("47", "5", weight=1000)  
G.add_edge("47", "6", weight=1000)  
G.add_edge("47", "9", weight=1000)  
G.add_edge("47", "18", weight=1000)  
G.add_edge("47", "35", weight=1000)  
G.add_edge("47", "39", weight=1000)  
G.add_edge("47", "41", weight=1000)  
G.add_edge("47", "43", weight=1000)  
G.add_edge("47", "58", weight=1000)  
G.add_edge("47", "79", weight=1000)  
G.add_edge("47", "83", weight=1000)  
G.add_edge("47", "98", weight=1000)  
G.add_edge("47", "103", weight=1000)  
G.add_edge("47", "104", weight=1000)  
G.add_edge("47", "108", weight=1000)  
G.add_edge("47", "125", weight=1000)  
G.add_edge("47", "126", weight=1000)  
G.add_edge("47", "127", weight=1000)  
G.add_edge("47", "128", weight=1000)  
G.add_edge("47", "130", weight=1000)  
G.add_edge("47", "132", weight=1000)  
G.add_edge("47", "142", weight=1000)  
G.add_edge("47", "166", weight=1000)  
G.add_edge("47", "168", weight=1000)  
G.add_edge("47", "174", weight=1000)  
G.add_edge("47", "175", weight=1000)  
G.add_edge("48", "4", weight=0)  
G.add_edge("48", "6", weight=0)  
G.add_edge("48", "6", weight=0)  
G.add_edge("48", "8", weight=0)  
G.add_edge("48", "8", weight=0)  
G.add_edge("48", "11", weight=0)  
G.add_edge("48", "13", weight=0)  
G.add_edge("48", "14", weight=0)  
G.add_edge("48", "15", weight=0)  
G.add_edge("48", "15", weight=0)  
G.add_edge("48", "16", weight=0)  
G.add_edge("48", "17", weight=0)  
G.add_edge("48", "19", weight=0)  
G.add_edge("48", "20", weight=0)  
G.add_edge("48", "22", weight=0)  
G.add_edge("48", "24", weight=0)  
G.add_edge("48", "29", weight=0)  
G.add_edge("48", "30", weight=0)  
G.add_edge("48", "32", weight=0)  
G.add_edge("48", "39", weight=0)  
G.add_edge("48", "41", weight=0)  
G.add_edge("48", "43", weight=0)  
G.add_edge("48", "44", weight=1000)  
G.add_edge("48", "49", weight=0)  
G.add_edge("48", "50", weight=0)  
G.add_edge("48", "52", weight=0)  
G.add_edge("48", "53", weight=0)  
G.add_edge("48", "55", weight=0)  
G.add_edge("48", "56", weight=0)  
G.add_edge("48", "59", weight=0)  
G.add_edge("48", "62", weight=0)  
G.add_edge("48", "63", weight=0)  
G.add_edge("48", "64", weight=0)  
G.add_edge("48", "74", weight=0)  
G.add_edge("48", "84", weight=0)  
G.add_edge("48", "87", weight=0)  
G.add_edge("48", "94", weight=0)  
G.add_edge("48", "97", weight=0)  
G.add_edge("48", "100", weight=0)  
G.add_edge("48", "102", weight=0)  
G.add_edge("48", "103", weight=0)  
G.add_edge("48", "105", weight=0)  
G.add_edge("48", "107", weight=0)  
G.add_edge("48", "108", weight=0)  
G.add_edge("48", "110", weight=0)  
G.add_edge("48", "113", weight=0)  
G.add_edge("48", "116", weight=0)  
G.add_edge("48", "118", weight=0)  
G.add_edge("48", "119", weight=0)  
G.add_edge("48", "123", weight=0)  
G.add_edge("48", "124", weight=0)  
G.add_edge("48", "125", weight=0)  
G.add_edge("48", "126", weight=0)  
G.add_edge("48", "127", weight=0)  
G.add_edge("48", "128", weight=0)  
G.add_edge("48", "129", weight=0)  
G.add_edge("48", "130", weight=0)  
G.add_edge("48", "132", weight=1000)  
G.add_edge("48", "134", weight=0)  
G.add_edge("48", "137", weight=0)  
G.add_edge("48", "138", weight=0)  
G.add_edge("48", "139", weight=0)  
G.add_edge("48", "142", weight=0)  
G.add_edge("48", "146", weight=0)  
G.add_edge("48", "147", weight=0)  
G.add_edge("48", "156", weight=0)  
G.add_edge("48", "161", weight=0)  
G.add_edge("48", "163", weight=0)  
G.add_edge("48", "164", weight=0)  
G.add_edge("48", "166", weight=0)  
G.add_edge("48", "168", weight=0)  
G.add_edge("48", "170", weight=0)  
G.add_edge("48", "171", weight=0)  
G.add_edge("48", "172", weight=0)  
G.add_edge("48", "175", weight=1000)  
G.add_edge("49", "1", weight=2250)  
G.add_edge("49", "1", weight=2250)  
G.add_edge("49", "8", weight=2250)  
G.add_edge("49", "9", weight=2250)  
G.add_edge("49", "10", weight=0)  
G.add_edge("49", "11", weight=2250)  
G.add_edge("49", "12", weight=0)  
G.add_edge("49", "13", weight=0)  
G.add_edge("49", "14", weight=0)  
G.add_edge("49", "15", weight=0)  
G.add_edge("49", "16", weight=0)  
G.add_edge("49", "17", weight=0)  
G.add_edge("49", "19", weight=0)  
G.add_edge("49", "20", weight=0)  
G.add_edge("49", "21", weight=0)  
G.add_edge("49", "22", weight=0)  
G.add_edge("49", "23", weight=0)  
G.add_edge("49", "24", weight=0)  
G.add_edge("49", "25", weight=0)  
G.add_edge("49", "26", weight=0)  
G.add_edge("49", "27", weight=0)  
G.add_edge("49", "28", weight=0)  
G.add_edge("49", "29", weight=0)  
G.add_edge("49", "30", weight=0)  
G.add_edge("49", "31", weight=2250)  
G.add_edge("49", "32", weight=0)  
G.add_edge("49", "35", weight=2250)  
G.add_edge("49", "37", weight=2250)  
G.add_edge("49", "38", weight=2250)  
G.add_edge("49", "41", weight=2250)  
G.add_edge("49", "41", weight=18000)  
G.add_edge("49", "43", weight=2250)  
G.add_edge("49", "46", weight=2250)  
G.add_edge("49", "48", weight=2250)  
G.add_edge("49", "50", weight=0)  
G.add_edge("49", "50", weight=0)  
G.add_edge("49", "51", weight=0)  
G.add_edge("49", "52", weight=0)  
G.add_edge("49", "53", weight=0)  
G.add_edge("49", "57", weight=2250)  
G.add_edge("49", "59", weight=18000)  
G.add_edge("49", "62", weight=9000)  
G.add_edge("49", "65", weight=2250)  
G.add_edge("49", "65", weight=2250)  
G.add_edge("49", "70", weight=2250)  
G.add_edge("49", "70", weight=12600)  
G.add_edge("49", "87", weight=2250)  
G.add_edge("49", "100", weight=9000)  
G.add_edge("49", "100", weight=9000)  
G.add_edge("49", "102", weight=2250)  
G.add_edge("49", "111", weight=2250)  
G.add_edge("49", "118", weight=9000)  
G.add_edge("49", "124", weight=2250)  
G.add_edge("49", "125", weight=9000)  
G.add_edge("49", "127", weight=2250)  
G.add_edge("49", "133", weight=2250)  
G.add_edge("49", "138", weight=9000)  
G.add_edge("49", "142", weight=2250)  
G.add_edge("49", "146", weight=2250)  
G.add_edge("49", "147", weight=9000)  
G.add_edge("49", "161", weight=9000)  
G.add_edge("49", "166", weight=9000)  
G.add_edge("49", "168", weight=9000)  
G.add_edge("49", "172", weight=18000)  
G.add_edge("49", "175", weight=2250)  
G.add_edge("50", "0", weight=2250)  
G.add_edge("50", "1", weight=2250)  
G.add_edge("50", "1", weight=2250)  
G.add_edge("50", "11", weight=2250)  
G.add_edge("50", "13", weight=0)  
G.add_edge("50", "15", weight=0)  
G.add_edge("50", "17", weight=0)  
G.add_edge("50", "31", weight=2250)  
G.add_edge("50", "31", weight=2250)  
G.add_edge("50", "37", weight=2250)  
G.add_edge("50", "43", weight=2250)  
G.add_edge("50", "43", weight=2250)  
G.add_edge("50", "43", weight=2250)  
G.add_edge("50", "46", weight=9000)  
G.add_edge("50", "48", weight=2250)  
G.add_edge("50", "49", weight=0)  
G.add_edge("50", "49", weight=0)  
G.add_edge("50", "51", weight=0)  
G.add_edge("50", "53", weight=0)  
G.add_edge("50", "53", weight=0)  
G.add_edge("50", "59", weight=9000)  
G.add_edge("50", "62", weight=9000)  
G.add_edge("50", "64", weight=2250)  
G.add_edge("50", "65", weight=2250)  
G.add_edge("50", "82", weight=2250)  
G.add_edge("50", "87", weight=2250)  
G.add_edge("50", "100", weight=9000)  
G.add_edge("50", "107", weight=9000)  
G.add_edge("50", "110", weight=2250)  
G.add_edge("50", "110", weight=2250)  
G.add_edge("50", "110", weight=9000)  
G.add_edge("50", "137", weight=9000)  
G.add_edge("50", "142", weight=2250)  
G.add_edge("50", "172", weight=18000)  
G.add_edge("50", "174", weight=2250)  
G.add_edge("50", "174", weight=18000)  
G.add_edge("51", "0", weight=2250)  
G.add_edge("51", "1", weight=2250)  
G.add_edge("51", "8", weight=2250)  
G.add_edge("51", "9", weight=2250)  
G.add_edge("51", "10", weight=0)  
G.add_edge("51", "11", weight=2250)  
G.add_edge("51", "12", weight=0)  
G.add_edge("51", "13", weight=0)  
G.add_edge("51", "14", weight=0)  
G.add_edge("51", "15", weight=0)  
G.add_edge("51", "15", weight=0)  
G.add_edge("51", "16", weight=0)  
G.add_edge("51", "17", weight=0)  
G.add_edge("51", "19", weight=0)  
G.add_edge("51", "20", weight=0)  
G.add_edge("51", "20", weight=0)  
G.add_edge("51", "20", weight=0)  
G.add_edge("51", "21", weight=0)  
G.add_edge("51", "22", weight=0)  
G.add_edge("51", "23", weight=0)  
G.add_edge("51", "24", weight=0)  
G.add_edge("51", "25", weight=0)  
G.add_edge("51", "26", weight=0)  
G.add_edge("51", "27", weight=0)  
G.add_edge("51", "27", weight=0)  
G.add_edge("51", "27", weight=0)  
G.add_edge("51", "28", weight=0)  
G.add_edge("51", "29", weight=0)  
G.add_edge("51", "30", weight=0)  
G.add_edge("51", "31", weight=2250)  
G.add_edge("51", "32", weight=0)  
G.add_edge("51", "34", weight=18000)  
G.add_edge("51", "37", weight=2250)  
G.add_edge("51", "38", weight=2250)  
G.add_edge("51", "41", weight=2250)  
G.add_edge("51", "41", weight=2250)  
G.add_edge("51", "41", weight=2250)  
G.add_edge("51", "41", weight=9000)  
G.add_edge("51", "43", weight=2250)  
G.add_edge("51", "45", weight=2250)  
G.add_edge("51", "49", weight=0)  
G.add_edge("51", "50", weight=0)  
G.add_edge("51", "52", weight=0)  
G.add_edge("51", "53", weight=0)  
G.add_edge("51", "59", weight=9000)  
G.add_edge("51", "62", weight=18000)  
G.add_edge("51", "62", weight=18000)  
G.add_edge("51", "62", weight=18000)  
G.add_edge("51", "65", weight=2250)  
G.add_edge("51", "85", weight=2250)  
G.add_edge("51", "86", weight=9000)  
G.add_edge("51", "87", weight=2250)  
G.add_edge("51", "95", weight=2250)  
G.add_edge("51", "101", weight=2250)  
G.add_edge("51", "101", weight=18000)  
G.add_edge("51", "103", weight=2250)  
G.add_edge("51", "110", weight=2250)  
G.add_edge("51", "116", weight=2250)  
G.add_edge("51", "122", weight=2250)  
G.add_edge("51", "123", weight=9000)  
G.add_edge("51", "127", weight=9000)  
G.add_edge("51", "128", weight=2250)  
G.add_edge("51", "130", weight=9000)  
G.add_edge("51", "134", weight=2250)  
G.add_edge("51", "138", weight=9000)  
G.add_edge("51", "142", weight=2250)  
G.add_edge("51", "146", weight=2250)  
G.add_edge("51", "147", weight=9000)  
G.add_edge("51", "161", weight=9000)  
G.add_edge("51", "168", weight=18000)  
G.add_edge("51", "174", weight=9000)  
G.add_edge("51", "175", weight=2250)  
G.add_edge("52", "0", weight=2250)  
G.add_edge("52", "1", weight=2250)  
G.add_edge("52", "1", weight=2250)  
G.add_edge("52", "4", weight=2250)  
G.add_edge("52", "11", weight=2250)  
G.add_edge("52", "29", weight=0)  
G.add_edge("52", "31", weight=2250)  
G.add_edge("52", "31", weight=2250)  
G.add_edge("52", "37", weight=2250)  
G.add_edge("52", "38", weight=2250)  
G.add_edge("52", "43", weight=2250)  
G.add_edge("52", "45", weight=2250)  
G.add_edge("52", "46", weight=2250)  
G.add_edge("52", "48", weight=2250)  
G.add_edge("52", "49", weight=0)  
G.add_edge("52", "51", weight=0)  
G.add_edge("52", "53", weight=0)  
G.add_edge("52", "55", weight=2250)  
G.add_edge("52", "62", weight=12600)  
G.add_edge("52", "65", weight=2250)  
G.add_edge("52", "68", weight=2250)  
G.add_edge("52", "75", weight=2250)  
G.add_edge("52", "76", weight=2250)  
G.add_edge("52", "87", weight=2250)  
G.add_edge("52", "94", weight=2250)  
G.add_edge("52", "110", weight=2250)  
G.add_edge("52", "110", weight=9000)  
G.add_edge("52", "116", weight=2250)  
G.add_edge("52", "127", weight=18000)  
G.add_edge("52", "131", weight=2250)  
G.add_edge("52", "132", weight=2250)  
G.add_edge("52", "142", weight=2250)  
G.add_edge("52", "144", weight=2250)  
G.add_edge("52", "147", weight=9000)  
G.add_edge("52", "170", weight=2250)  
G.add_edge("52", "174", weight=2250)  
G.add_edge("53", "1", weight=2250)  
G.add_edge("53", "1", weight=2250)  
G.add_edge("53", "1", weight=2250)  
G.add_edge("53", "9", weight=2250)  
G.add_edge("53", "10", weight=0)  
G.add_edge("53", "11", weight=2250)  
G.add_edge("53", "12", weight=0)  
G.add_edge("53", "12", weight=0)  
G.add_edge("53", "13", weight=0)  
G.add_edge("53", "14", weight=0)  
G.add_edge("53", "15", weight=0)  
G.add_edge("53", "16", weight=0)  
G.add_edge("53", "17", weight=0)  
G.add_edge("53", "19", weight=0)  
G.add_edge("53", "20", weight=0)  
G.add_edge("53", "21", weight=0)  
G.add_edge("53", "22", weight=0)  
G.add_edge("53", "23", weight=0)  
G.add_edge("53", "24", weight=0)  
G.add_edge("53", "25", weight=0)  
G.add_edge("53", "26", weight=0)  
G.add_edge("53", "27", weight=0)  
G.add_edge("53", "28", weight=0)  
G.add_edge("53", "29", weight=0)  
G.add_edge("53", "30", weight=0)  
G.add_edge("53", "31", weight=2250)  
G.add_edge("53", "32", weight=0)  
G.add_edge("53", "32", weight=0)  
G.add_edge("53", "37", weight=2250)  
G.add_edge("53", "38", weight=2250)  
G.add_edge("53", "39", weight=2250)  
G.add_edge("53", "41", weight=2250)  
G.add_edge("53", "41", weight=2250)  
G.add_edge("53", "41", weight=9000)  
G.add_edge("53", "43", weight=2250)  
G.add_edge("53", "43", weight=2250)  
G.add_edge("53", "43", weight=2250)  
G.add_edge("53", "44", weight=2250)  
G.add_edge("53", "45", weight=2250)  
G.add_edge("53", "46", weight=9000)  
G.add_edge("53", "48", weight=2250)  
G.add_edge("53", "49", weight=0)  
G.add_edge("53", "50", weight=0)  
G.add_edge("53", "50", weight=0)  
G.add_edge("53", "51", weight=0)  
G.add_edge("53", "52", weight=0)  
G.add_edge("53", "57", weight=2250)  
G.add_edge("53", "59", weight=9000)  
G.add_edge("53", "62", weight=18000)  
G.add_edge("53", "62", weight=18000)  
G.add_edge("53", "62", weight=2250)  
G.add_edge("53", "62", weight=2250)  
G.add_edge("53", "65", weight=2250)  
G.add_edge("53", "70", weight=18000)  
G.add_edge("53", "70", weight=18000)  
G.add_edge("53", "75", weight=2250)  
G.add_edge("53", "84", weight=2250)  
G.add_edge("53", "86", weight=9000)  
G.add_edge("53", "88", weight=2250)  
G.add_edge("53", "99", weight=2250)  
G.add_edge("53", "103", weight=2250)  
G.add_edge("53", "109", weight=2250)  
G.add_edge("53", "109", weight=2250)  
G.add_edge("53", "110", weight=2250)  
G.add_edge("53", "110", weight=2250)  
G.add_edge("53", "110", weight=2250)  
G.add_edge("53", "110", weight=2250)  
G.add_edge("53", "120", weight=2250)  
G.add_edge("53", "127", weight=12600)  
G.add_edge("53", "128", weight=2250)  
G.add_edge("53", "129", weight=2250)  
G.add_edge("53", "130", weight=9000)  
G.add_edge("53", "138", weight=9000)  
G.add_edge("53", "142", weight=2250)  
G.add_edge("53", "145", weight=2250)  
G.add_edge("53", "145", weight=2250)  
G.add_edge("53", "147", weight=2250)  
G.add_edge("53", "164", weight=2250)  
G.add_edge("53", "168", weight=18000)  
G.add_edge("53", "168", weight=9000)  
G.add_edge("53", "174", weight=2250)  
G.add_edge("53", "175", weight=2250)  
G.add_edge("54", "2", weight=420)  
G.add_edge("54", "31", weight=420)  
G.add_edge("54", "39", weight=420)  
G.add_edge("54", "69", weight=420)  
G.add_edge("54", "87", weight=420)  
G.add_edge("54", "88", weight=420)  
G.add_edge("54", "103", weight=420)  
G.add_edge("54", "106", weight=420)  
G.add_edge("54", "120", weight=420)  
G.add_edge("54", "142", weight=420)  
G.add_edge("54", "143", weight=420)  
G.add_edge("54", "164", weight=420)  
G.add_edge("54", "170", weight=420)  
G.add_edge("55", "1", weight=30)  
G.add_edge("55", "2", weight=9998)  
G.add_edge("55", "2", weight=9998)  
G.add_edge("55", "5", weight=9998)  
G.add_edge("55", "6", weight=9998)  
G.add_edge("55", "9", weight=9998)  
G.add_edge("55", "11", weight=30)  
G.add_edge("55", "37", weight=9998)  
G.add_edge("55", "39", weight=0)  
G.add_edge("55", "41", weight=9998)  
G.add_edge("55", "43", weight=30)  
G.add_edge("55", "44", weight=50000)  
G.add_edge("55", "48", weight=30)  
G.add_edge("55", "52", weight=50000)  
G.add_edge("55", "56", weight=10000)  
G.add_edge("55", "60", weight=9998)  
G.add_edge("55", "62", weight=9998)  
G.add_edge("55", "64", weight=9998)  
G.add_edge("55", "65", weight=9998)  
G.add_edge("55", "72", weight=30)  
G.add_edge("55", "85", weight=9998)  
G.add_edge("55", "87", weight=50000)  
G.add_edge("55", "94", weight=9998)  
G.add_edge("55", "97", weight=50000)  
G.add_edge("55", "100", weight=9998)  
G.add_edge("55", "107", weight=50000)  
G.add_edge("55", "108", weight=10000)  
G.add_edge("55", "113", weight=9998)  
G.add_edge("55", "125", weight=9998)  
G.add_edge("55", "128", weight=50000)  
G.add_edge("55", "130", weight=50000)  
G.add_edge("55", "137", weight=50000)  
G.add_edge("55", "140", weight=50000)  
G.add_edge("55", "142", weight=50000)  
G.add_edge("55", "146", weight=50000)  
G.add_edge("55", "155", weight=50000)  
G.add_edge("55", "156", weight=50000)  
G.add_edge("55", "161", weight=50000)  
G.add_edge("55", "163", weight=50000)  
G.add_edge("55", "164", weight=50000)  
G.add_edge("55", "175", weight=50000)  
G.add_edge("56", "7", weight=0)  
G.add_edge("56", "8", weight=0)  
G.add_edge("56", "9", weight=0)  
G.add_edge("56", "11", weight=0)  
G.add_edge("56", "31", weight=0)  
G.add_edge("56", "40", weight=0)  
G.add_edge("56", "43", weight=0)  
G.add_edge("56", "44", weight=0)  
G.add_edge("56", "46", weight=0)  
G.add_edge("56", "48", weight=0)  
G.add_edge("56", "55", weight=0)  
G.add_edge("56", "57", weight=0)  
G.add_edge("56", "58", weight=0)  
G.add_edge("56", "69", weight=0)  
G.add_edge("56", "72", weight=0)  
G.add_edge("56", "87", weight=0)  
G.add_edge("56", "94", weight=0)  
G.add_edge("56", "100", weight=0)  
G.add_edge("56", "125", weight=0)  
G.add_edge("56", "128", weight=0)  
G.add_edge("56", "132", weight=0)  
G.add_edge("56", "134", weight=0)  
G.add_edge("56", "136", weight=0)  
G.add_edge("56", "142", weight=0)  
G.add_edge("56", "143", weight=0)  
G.add_edge("56", "146", weight=0)  
G.add_edge("56", "163", weight=0)  
G.add_edge("56", "166", weight=0)  
G.add_edge("56", "168", weight=0)  
G.add_edge("56", "171", weight=0)  
G.add_edge("57", "3", weight=9850)  
G.add_edge("57", "8", weight=0)  
G.add_edge("57", "10", weight=0)  
G.add_edge("57", "11", weight=0)  
G.add_edge("57", "13", weight=0)  
G.add_edge("57", "14", weight=0)  
G.add_edge("57", "15", weight=0)  
G.add_edge("57", "16", weight=0)  
G.add_edge("57", "17", weight=45678)  
G.add_edge("57", "18", weight=35194)  
G.add_edge("57", "20", weight=0)  
G.add_edge("57", "22", weight=0)  
G.add_edge("57", "23", weight=45803)  
G.add_edge("57", "24", weight=0)  
G.add_edge("57", "25", weight=0)  
G.add_edge("57", "26", weight=47076)  
G.add_edge("57", "27", weight=0)  
G.add_edge("57", "28", weight=0)  
G.add_edge("57", "29", weight=0)  
G.add_edge("57", "30", weight=0)  
G.add_edge("57", "31", weight=0)  
G.add_edge("57", "32", weight=0)  
G.add_edge("57", "39", weight=23345)  
G.add_edge("57", "40", weight=0)  
G.add_edge("57", "41", weight=0)  
G.add_edge("57", "42", weight=9590)  
G.add_edge("57", "43", weight=0)  
G.add_edge("57", "44", weight=0)  
G.add_edge("57", "45", weight=20092)  
G.add_edge("57", "49", weight=0)  
G.add_edge("57", "53", weight=0)  
G.add_edge("57", "56", weight=40498)  
G.add_edge("57", "59", weight=0)  
G.add_edge("57", "63", weight=36207)  
G.add_edge("57", "64", weight=32539)  
G.add_edge("57", "65", weight=45290)  
G.add_edge("57", "68", weight=19703)  
G.add_edge("57", "70", weight=40566)  
G.add_edge("57", "76", weight=9160)  
G.add_edge("57", "78", weight=0)  
G.add_edge("57", "79", weight=0)  
G.add_edge("57", "81", weight=8840)  
G.add_edge("57", "82", weight=42892)  
G.add_edge("57", "83", weight=23024)  
G.add_edge("57", "87", weight=0)  
G.add_edge("57", "88", weight=6520)  
G.add_edge("57", "89", weight=10000)  
G.add_edge("57", "90", weight=9900)  
G.add_edge("57", "91", weight=9690)  
G.add_edge("57", "92", weight=0)  
G.add_edge("57", "95", weight=8780)  
G.add_edge("57", "97", weight=0)  
G.add_edge("57", "98", weight=8090)  
G.add_edge("57", "99", weight=0)  
G.add_edge("57", "100", weight=0)  
G.add_edge("57", "102", weight=36944)  
G.add_edge("57", "103", weight=0)  
G.add_edge("57", "104", weight=500)  
G.add_edge("57", "105", weight=0)  
G.add_edge("57", "107", weight=0)  
G.add_edge("57", "108", weight=0)  
G.add_edge("57", "109", weight=0)  
G.add_edge("57", "110", weight=0)  
G.add_edge("57", "111", weight=500)  
G.add_edge("57", "113", weight=0)  
G.add_edge("57", "114", weight=0)  
G.add_edge("57", "116", weight=0)  
G.add_edge("57", "118", weight=14131)  
G.add_edge("57", "121", weight=9690)  
G.add_edge("57", "122", weight=0)  
G.add_edge("57", "123", weight=0)  
G.add_edge("57", "124", weight=0)  
G.add_edge("57", "125", weight=25486)  
G.add_edge("57", "126", weight=0)  
G.add_edge("57", "127", weight=0)  
G.add_edge("57", "128", weight=0)  
G.add_edge("57", "130", weight=0)  
G.add_edge("57", "131", weight=40159)  
G.add_edge("57", "132", weight=0)  
G.add_edge("57", "137", weight=0)  
G.add_edge("57", "139", weight=0)  
G.add_edge("57", "140", weight=41047)  
G.add_edge("57", "142", weight=0)  
G.add_edge("57", "143", weight=0)  
G.add_edge("57", "145", weight=0)  
G.add_edge("57", "146", weight=8170)  
G.add_edge("57", "147", weight=0)  
G.add_edge("57", "151", weight=35459)  
G.add_edge("57", "154", weight=0)  
G.add_edge("57", "157", weight=0)  
G.add_edge("57", "161", weight=43443)  
G.add_edge("57", "163", weight=0)  
G.add_edge("57", "164", weight=21321)  
G.add_edge("57", "165", weight=0)  
G.add_edge("57", "166", weight=12705)  
G.add_edge("57", "168", weight=0)  
G.add_edge("57", "170", weight=8272)  
G.add_edge("57", "173", weight=0)  
G.add_edge("57", "174", weight=0)  
G.add_edge("57", "175", weight=0)  
G.add_edge("57", "176", weight=0)  
G.add_edge("58", "2", weight=0)  
G.add_edge("58", "5", weight=0)  
G.add_edge("58", "6", weight=0)  
G.add_edge("58", "9", weight=0)  
G.add_edge("58", "10", weight=0)  
G.add_edge("58", "11", weight=0)  
G.add_edge("58", "14", weight=0)  
G.add_edge("58", "17", weight=0)  
G.add_edge("58", "19", weight=0)  
G.add_edge("58", "31", weight=0)  
G.add_edge("58", "33", weight=0)  
G.add_edge("58", "34", weight=0)  
G.add_edge("58", "35", weight=0)  
G.add_edge("58", "39", weight=0)  
G.add_edge("58", "42", weight=0)  
G.add_edge("58", "46", weight=0)  
G.add_edge("58", "47", weight=0)  
G.add_edge("58", "56", weight=0)  
G.add_edge("58", "62", weight=0)  
G.add_edge("58", "68", weight=0)  
G.add_edge("58", "71", weight=0)  
G.add_edge("58", "72", weight=0)  
G.add_edge("58", "77", weight=0)  
G.add_edge("58", "78", weight=0)  
G.add_edge("58", "81", weight=0)  
G.add_edge("58", "83", weight=0)  
G.add_edge("58", "85", weight=0)  
G.add_edge("58", "89", weight=0)  
G.add_edge("58", "90", weight=0)  
G.add_edge("58", "91", weight=0)  
G.add_edge("58", "92", weight=0)  
G.add_edge("58", "106", weight=0)  
G.add_edge("58", "116", weight=0)  
G.add_edge("58", "131", weight=0)  
G.add_edge("58", "132", weight=0)  
G.add_edge("58", "143", weight=0)  
G.add_edge("58", "158", weight=0)  
G.add_edge("58", "159", weight=0)  
G.add_edge("59", "4", weight=0)  
G.add_edge("59", "6", weight=0)  
G.add_edge("59", "6", weight=0)  
G.add_edge("59", "8", weight=0)  
G.add_edge("59", "9", weight=0)  
G.add_edge("59", "14", weight=0)  
G.add_edge("59", "15", weight=0)  
G.add_edge("59", "19", weight=0)  
G.add_edge("59", "21", weight=0)  
G.add_edge("59", "22", weight=0)  
G.add_edge("59", "23", weight=0)  
G.add_edge("59", "24", weight=0)  
G.add_edge("59", "29", weight=0)  
G.add_edge("59", "32", weight=0)  
G.add_edge("59", "34", weight=0)  
G.add_edge("59", "37", weight=0)  
G.add_edge("59", "41", weight=0)  
G.add_edge("59", "44", weight=0)  
G.add_edge("59", "48", weight=0)  
G.add_edge("59", "49", weight=0)  
G.add_edge("59", "50", weight=0)  
G.add_edge("59", "51", weight=0)  
G.add_edge("59", "53", weight=0)  
G.add_edge("59", "57", weight=0)  
G.add_edge("59", "62", weight=0)  
G.add_edge("59", "63", weight=0)  
G.add_edge("59", "64", weight=0)  
G.add_edge("59", "69", weight=0)  
G.add_edge("59", "70", weight=0)  
G.add_edge("59", "75", weight=0)  
G.add_edge("59", "79", weight=0)  
G.add_edge("59", "83", weight=0)  
G.add_edge("59", "84", weight=0)  
G.add_edge("59", "85", weight=0)  
G.add_edge("59", "95", weight=0)  
G.add_edge("59", "97", weight=0)  
G.add_edge("59", "98", weight=0)  
G.add_edge("59", "100", weight=0)  
G.add_edge("59", "101", weight=0)  
G.add_edge("59", "102", weight=0)  
G.add_edge("59", "103", weight=0)  
G.add_edge("59", "104", weight=0)  
G.add_edge("59", "107", weight=0)  
G.add_edge("59", "108", weight=0)  
G.add_edge("59", "108", weight=0)  
G.add_edge("59", "110", weight=0)  
G.add_edge("59", "111", weight=0)  
G.add_edge("59", "118", weight=0)  
G.add_edge("59", "119", weight=0)  
G.add_edge("59", "122", weight=0)  
G.add_edge("59", "124", weight=0)  
G.add_edge("59", "125", weight=0)  
G.add_edge("59", "126", weight=0)  
G.add_edge("59", "127", weight=0)  
G.add_edge("59", "128", weight=0)  
G.add_edge("59", "130", weight=0)  
G.add_edge("59", "131", weight=0)  
G.add_edge("59", "132", weight=0)  
G.add_edge("59", "133", weight=0)  
G.add_edge("59", "134", weight=0)  
G.add_edge("59", "137", weight=0)  
G.add_edge("59", "139", weight=0)  
G.add_edge("59", "142", weight=0)  
G.add_edge("59", "147", weight=0)  
G.add_edge("59", "154", weight=0)  
G.add_edge("59", "156", weight=0)  
G.add_edge("59", "160", weight=0)  
G.add_edge("59", "161", weight=0)  
G.add_edge("59", "163", weight=0)  
G.add_edge("59", "165", weight=0)  
G.add_edge("59", "166", weight=0)  
G.add_edge("59", "168", weight=0)  
G.add_edge("59", "170", weight=0)  
G.add_edge("59", "172", weight=0)  
G.add_edge("59", "174", weight=0)  
G.add_edge("59", "175", weight=0)  
G.add_edge("60", "2", weight=0)  
G.add_edge("60", "2", weight=0)  
G.add_edge("60", "5", weight=0)  
G.add_edge("60", "6", weight=0)  
G.add_edge("60", "6", weight=0)  
G.add_edge("60", "8", weight=0)  
G.add_edge("60", "9", weight=0)  
G.add_edge("60", "11", weight=0)  
G.add_edge("60", "35", weight=0)  
G.add_edge("60", "35", weight=0)  
G.add_edge("60", "40", weight=0)  
G.add_edge("60", "41", weight=0)  
G.add_edge("60", "44", weight=0)  
G.add_edge("60", "44", weight=0)  
G.add_edge("60", "55", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=0)  
G.add_edge("60", "62", weight=1000)  
G.add_edge("60", "63", weight=0)  
G.add_edge("60", "64", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=0)  
G.add_edge("60", "70", weight=1000)  
G.add_edge("60", "73", weight=1000)  
G.add_edge("60", "82", weight=0)  
G.add_edge("60", "85", weight=0)  
G.add_edge("60", "85", weight=0)  
G.add_edge("60", "88", weight=0)  
G.add_edge("60", "97", weight=0)  
G.add_edge("60", "100", weight=0)  
G.add_edge("60", "100", weight=0)  
G.add_edge("60", "104", weight=0)  
G.add_edge("60", "104", weight=0)  
G.add_edge("60", "107", weight=0)  
G.add_edge("60", "118", weight=0)  
G.add_edge("60", "122", weight=0)  
G.add_edge("60", "122", weight=0)  
G.add_edge("60", "123", weight=0)  
G.add_edge("60", "124", weight=0)  
G.add_edge("60", "126", weight=0)  
G.add_edge("60", "126", weight=0)  
G.add_edge("60", "127", weight=0)  
G.add_edge("60", "128", weight=0)  
G.add_edge("60", "130", weight=0)  
G.add_edge("60", "130", weight=0)  
G.add_edge("60", "131", weight=0)  
G.add_edge("60", "131", weight=0)  
G.add_edge("60", "132", weight=0)  
G.add_edge("60", "135", weight=0)  
G.add_edge("60", "135", weight=0)  
G.add_edge("60", "137", weight=0)  
G.add_edge("60", "138", weight=0)  
G.add_edge("60", "140", weight=0)  
G.add_edge("60", "159", weight=0)  
G.add_edge("60", "164", weight=0)  
G.add_edge("60", "166", weight=0)  
G.add_edge("60", "168", weight=0)  
G.add_edge("60", "170", weight=0)  
G.add_edge("60", "171", weight=0)  
G.add_edge("60", "174", weight=0)  
G.add_edge("60", "174", weight=0)  
G.add_edge("60", "174", weight=0)  
G.add_edge("61", "6", weight=2)  
G.add_edge("61", "6", weight=2)  
G.add_edge("61", "7", weight=2)  
G.add_edge("61", "7", weight=2)  
G.add_edge("61", "8", weight=2)  
G.add_edge("61", "11", weight=2)  
G.add_edge("61", "37", weight=2)  
G.add_edge("61", "39", weight=2)  
G.add_edge("61", "43", weight=2)  
G.add_edge("61", "44", weight=2)  
G.add_edge("61", "46", weight=2)  
G.add_edge("61", "76", weight=2)  
G.add_edge("61", "94", weight=2)  
G.add_edge("61", "94", weight=2)  
G.add_edge("61", "95", weight=2)  
G.add_edge("61", "97", weight=2)  
G.add_edge("61", "99", weight=2)  
G.add_edge("61", "109", weight=2)  
G.add_edge("61", "120", weight=2)  
G.add_edge("61", "130", weight=2)  
G.add_edge("61", "132", weight=2)  
G.add_edge("61", "135", weight=2)  
G.add_edge("61", "145", weight=2)  
G.add_edge("61", "146", weight=2)  
G.add_edge("61", "165", weight=2)  
G.add_edge("62", "0", weight=1000)  
G.add_edge("62", "1", weight=1000)  
G.add_edge("62", "2", weight=1000)  
G.add_edge("62", "2", weight=1000)  
G.add_edge("62", "2", weight=1000)  
G.add_edge("62", "2", weight=1000)  
G.add_edge("62", "5", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "6", weight=1000)  
G.add_edge("62", "8", weight=1000)  
G.add_edge("62", "8", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "9", weight=1000)  
G.add_edge("62", "11", weight=1000)  
G.add_edge("62", "14", weight=1000)  
G.add_edge("62", "15", weight=1000)  
G.add_edge("62", "16", weight=1000)  
G.add_edge("62", "17", weight=1000)  
G.add_edge("62", "17", weight=1000)  
G.add_edge("62", "17", weight=1000)  
G.add_edge("62", "18", weight=1000)  
G.add_edge("62", "19", weight=1000)  
G.add_edge("62", "20", weight=1000)  
G.add_edge("62", "21", weight=1000)  
G.add_edge("62", "21", weight=1000)  
G.add_edge("62", "23", weight=1000)  
G.add_edge("62", "24", weight=1000)  
G.add_edge("62", "25", weight=1000)  
G.add_edge("62", "26", weight=1000)  
G.add_edge("62", "27", weight=1000)  
G.add_edge("62", "28", weight=1000)  
G.add_edge("62", "29", weight=1000)  
G.add_edge("62", "29", weight=1000)  
G.add_edge("62", "32", weight=1000)  
G.add_edge("62", "33", weight=1000)  
G.add_edge("62", "35", weight=1000)  
G.add_edge("62", "37", weight=1000)  
G.add_edge("62", "39", weight=1000)  
G.add_edge("62", "40", weight=1000)  
G.add_edge("62", "41", weight=1000)  
G.add_edge("62", "41", weight=1000)  
G.add_edge("62", "41", weight=1000)  
G.add_edge("62", "43", weight=1000)  
G.add_edge("62", "44", weight=1000)  
G.add_edge("62", "48", weight=1000)  
G.add_edge("62", "49", weight=1000)  
G.add_edge("62", "50", weight=1000)  
G.add_edge("62", "51", weight=1000)  
G.add_edge("62", "51", weight=1000)  
G.add_edge("62", "51", weight=1000)  
G.add_edge("62", "52", weight=1000)  
G.add_edge("62", "53", weight=1000)  
G.add_edge("62", "53", weight=1000)  
G.add_edge("62", "53", weight=1000)  
G.add_edge("62", "53", weight=1000)  
G.add_edge("62", "55", weight=1000)  
G.add_edge("62", "58", weight=1000)  
G.add_edge("62", "59", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "60", weight=1000)  
G.add_edge("62", "63", weight=1000)  
G.add_edge("62", "64", weight=1000)  
G.add_edge("62", "66", weight=1000)  
G.add_edge("62", "67", weight=1000)  
G.add_edge("62", "69", weight=1000)  
G.add_edge("62", "70", weight=1000)  
G.add_edge("62", "70", weight=1000)  
G.add_edge("62", "70", weight=1000)  
G.add_edge("62", "72", weight=1000)  
G.add_edge("62", "74", weight=1000)  
G.add_edge("62", "75", weight=1000)  
G.add_edge("62", "76", weight=1000)  
G.add_edge("62", "82", weight=1000)  
G.add_edge("62", "83", weight=1000)  
G.add_edge("62", "84", weight=1000)  
G.add_edge("62", "85", weight=1000)  
G.add_edge("62", "85", weight=1000)  
G.add_edge("62", "85", weight=1000)  
G.add_edge("62", "85", weight=1000)  
G.add_edge("62", "86", weight=1000)  
G.add_edge("62", "86", weight=1000)  
G.add_edge("62", "87", weight=1000)  
G.add_edge("62", "88", weight=1000)  
G.add_edge("62", "94", weight=1000)  
G.add_edge("62", "95", weight=1000)  
G.add_edge("62", "97", weight=1000)  
G.add_edge("62", "98", weight=1000)  
G.add_edge("62", "98", weight=1000)  
G.add_edge("62", "98", weight=1000)  
G.add_edge("62", "99", weight=1000)  
G.add_edge("62", "100", weight=1000)  
G.add_edge("62", "100", weight=1000)  
G.add_edge("62", "100", weight=1000)  
G.add_edge("62", "100", weight=1000)  
G.add_edge("62", "100", weight=1000)  
G.add_edge("62", "100", weight=1000)  
G.add_edge("62", "101", weight=1000)  
G.add_edge("62", "101", weight=1000)  
G.add_edge("62", "101", weight=1000)  
G.add_edge("62", "101", weight=1000)  
G.add_edge("62", "103", weight=1000)  
G.add_edge("62", "104", weight=1000)  
G.add_edge("62", "104", weight=1000)  
G.add_edge("62", "104", weight=1000)  
G.add_edge("62", "104", weight=1000)  
G.add_edge("62", "104", weight=1000)  
G.add_edge("62", "105", weight=1000)  
G.add_edge("62", "107", weight=1000)  
G.add_edge("62", "108", weight=1000)  
G.add_edge("62", "109", weight=1000)  
G.add_edge("62", "110", weight=1000)  
G.add_edge("62", "110", weight=1000)  
G.add_edge("62", "113", weight=1000)  
G.add_edge("62", "118", weight=1000)  
G.add_edge("62", "119", weight=1000)  
G.add_edge("62", "122", weight=1000)  
G.add_edge("62", "123", weight=1000)  
G.add_edge("62", "125", weight=1000)  
G.add_edge("62", "125", weight=1000)  
G.add_edge("62", "126", weight=1000)  
G.add_edge("62", "127", weight=1000)  
G.add_edge("62", "128", weight=1000)  
G.add_edge("62", "129", weight=1000)  
G.add_edge("62", "130", weight=1000)  
G.add_edge("62", "132", weight=1000)  
G.add_edge("62", "134", weight=1000)  
G.add_edge("62", "135", weight=1000)  
G.add_edge("62", "137", weight=1000)  
G.add_edge("62", "138", weight=1000)  
G.add_edge("62", "139", weight=1000)  
G.add_edge("62", "140", weight=1000)  
G.add_edge("62", "142", weight=1000)  
G.add_edge("62", "143", weight=1000)  
G.add_edge("62", "144", weight=1000)  
G.add_edge("62", "145", weight=1000)  
G.add_edge("62", "146", weight=1000)  
G.add_edge("62", "147", weight=1000)  
G.add_edge("62", "160", weight=1000)  
G.add_edge("62", "163", weight=1000)  
G.add_edge("62", "164", weight=1000)  
G.add_edge("62", "165", weight=1000)  
G.add_edge("62", "166", weight=1000)  
G.add_edge("62", "168", weight=1000)  
G.add_edge("62", "170", weight=1000)  
G.add_edge("62", "172", weight=1000)  
G.add_edge("62", "173", weight=1000)  
G.add_edge("62", "174", weight=1000)  
G.add_edge("62", "174", weight=1000)  
G.add_edge("62", "174", weight=1000)  
G.add_edge("62", "174", weight=1000)  
G.add_edge("62", "175", weight=1000)  
G.add_edge("63", "1", weight=0)  
G.add_edge("63", "2", weight=0)  
G.add_edge("63", "6", weight=0)  
G.add_edge("63", "8", weight=0)  
G.add_edge("63", "9", weight=0)  
G.add_edge("63", "16", weight=0)  
G.add_edge("63", "23", weight=0)  
G.add_edge("63", "35", weight=0)  
G.add_edge("63", "40", weight=0)  
G.add_edge("63", "44", weight=0)  
G.add_edge("63", "48", weight=0)  
G.add_edge("63", "57", weight=0)  
G.add_edge("63", "59", weight=0)  
G.add_edge("63", "60", weight=0)  
G.add_edge("63", "62", weight=0)  
G.add_edge("63", "64", weight=0)  
G.add_edge("63", "66", weight=0)  
G.add_edge("63", "79", weight=0)  
G.add_edge("63", "83", weight=0)  
G.add_edge("63", "84", weight=0)  
G.add_edge("63", "85", weight=0)  
G.add_edge("63", "87", weight=0)  
G.add_edge("63", "94", weight=0)  
G.add_edge("63", "95", weight=0)  
G.add_edge("63", "100", weight=0)  
G.add_edge("63", "105", weight=0)  
G.add_edge("63", "107", weight=0)  
G.add_edge("63", "112", weight=0)  
G.add_edge("63", "113", weight=0)  
G.add_edge("63", "114", weight=0)  
G.add_edge("63", "116", weight=0)  
G.add_edge("63", "122", weight=0)  
G.add_edge("63", "124", weight=0)  
G.add_edge("63", "125", weight=0)  
G.add_edge("63", "126", weight=0)  
G.add_edge("63", "128", weight=0)  
G.add_edge("63", "129", weight=0)  
G.add_edge("63", "133", weight=0)  
G.add_edge("63", "134", weight=0)  
G.add_edge("63", "139", weight=0)  
G.add_edge("63", "140", weight=0)  
G.add_edge("63", "142", weight=0)  
G.add_edge("63", "144", weight=0)  
G.add_edge("63", "145", weight=0)  
G.add_edge("63", "147", weight=0)  
G.add_edge("63", "148", weight=0)  
G.add_edge("63", "151", weight=0)  
G.add_edge("63", "160", weight=0)  
G.add_edge("63", "164", weight=0)  
G.add_edge("63", "166", weight=0)  
G.add_edge("63", "170", weight=0)  
G.add_edge("63", "173", weight=0)  
G.add_edge("63", "174", weight=0)  
G.add_edge("64", "1", weight=0)  
G.add_edge("64", "2", weight=0)  
G.add_edge("64", "4", weight=0)  
G.add_edge("64", "6", weight=0)  
G.add_edge("64", "8", weight=0)  
G.add_edge("64", "9", weight=0)  
G.add_edge("64", "11", weight=0)  
G.add_edge("64", "23", weight=0)  
G.add_edge("64", "31", weight=0)  
G.add_edge("64", "35", weight=0)  
G.add_edge("64", "37", weight=0)  
G.add_edge("64", "40", weight=0)  
G.add_edge("64", "41", weight=0)  
G.add_edge("64", "43", weight=0)  
G.add_edge("64", "44", weight=0)  
G.add_edge("64", "48", weight=0)  
G.add_edge("64", "50", weight=0)  
G.add_edge("64", "55", weight=0)  
G.add_edge("64", "57", weight=0)  
G.add_edge("64", "59", weight=0)  
G.add_edge("64", "60", weight=0)  
G.add_edge("64", "62", weight=0)  
G.add_edge("64", "63", weight=0)  
G.add_edge("64", "66", weight=0)  
G.add_edge("64", "67", weight=0)  
G.add_edge("64", "69", weight=0)  
G.add_edge("64", "70", weight=0)  
G.add_edge("64", "70", weight=0)  
G.add_edge("64", "76", weight=0)  
G.add_edge("64", "79", weight=0)  
G.add_edge("64", "79", weight=0)  
G.add_edge("64", "79", weight=0)  
G.add_edge("64", "80", weight=0)  
G.add_edge("64", "84", weight=0)  
G.add_edge("64", "85", weight=0)  
G.add_edge("64", "87", weight=0)  
G.add_edge("64", "95", weight=0)  
G.add_edge("64", "100", weight=0)  
G.add_edge("64", "101", weight=0)  
G.add_edge("64", "101", weight=0)  
G.add_edge("64", "102", weight=0)  
G.add_edge("64", "103", weight=0)  
G.add_edge("64", "105", weight=0)  
G.add_edge("64", "105", weight=0)  
G.add_edge("64", "107", weight=0)  
G.add_edge("64", "109", weight=0)  
G.add_edge("64", "111", weight=0)  
G.add_edge("64", "112", weight=0)  
G.add_edge("64", "113", weight=0)  
G.add_edge("64", "114", weight=0)  
G.add_edge("64", "116", weight=0)  
G.add_edge("64", "122", weight=0)  
G.add_edge("64", "125", weight=0)  
G.add_edge("64", "126", weight=0)  
G.add_edge("64", "127", weight=0)  
G.add_edge("64", "128", weight=0)  
G.add_edge("64", "129", weight=0)  
G.add_edge("64", "130", weight=0)  
G.add_edge("64", "133", weight=0)  
G.add_edge("64", "135", weight=0)  
G.add_edge("64", "136", weight=0)  
G.add_edge("64", "137", weight=0)  
G.add_edge("64", "138", weight=0)  
G.add_edge("64", "140", weight=0)  
G.add_edge("64", "142", weight=0)  
G.add_edge("64", "143", weight=0)  
G.add_edge("64", "144", weight=0)  
G.add_edge("64", "145", weight=0)  
G.add_edge("64", "147", weight=0)  
G.add_edge("64", "148", weight=0)  
G.add_edge("64", "154", weight=0)  
G.add_edge("64", "156", weight=0)  
G.add_edge("64", "161", weight=0)  
G.add_edge("64", "163", weight=0)  
G.add_edge("64", "165", weight=0)  
G.add_edge("64", "166", weight=0)  
G.add_edge("64", "168", weight=0)  
G.add_edge("64", "170", weight=0)  
G.add_edge("64", "174", weight=0)  
G.add_edge("64", "175", weight=0)  
G.add_edge("65", "0", weight=1000)  
G.add_edge("65", "1", weight=1000)  
G.add_edge("65", "2", weight=1000)  
G.add_edge("65", "3", weight=100)  
G.add_edge("65", "4", weight=100)  
G.add_edge("65", "6", weight=100)  
G.add_edge("65", "6", weight=100)  
G.add_edge("65", "6", weight=1000)  
G.add_edge("65", "10", weight=100)  
G.add_edge("65", "10", weight=100)  
G.add_edge("65", "11", weight=100)  
G.add_edge("65", "12", weight=100)  
G.add_edge("65", "13", weight=100)  
G.add_edge("65", "14", weight=100)  
G.add_edge("65", "14", weight=100)  
G.add_edge("65", "15", weight=100)  
G.add_edge("65", "15", weight=100)  
G.add_edge("65", "16", weight=100)  
G.add_edge("65", "19", weight=100)  
G.add_edge("65", "19", weight=100)  
G.add_edge("65", "20", weight=100)  
G.add_edge("65", "21", weight=100)  
G.add_edge("65", "21", weight=100)  
G.add_edge("65", "22", weight=100)  
G.add_edge("65", "23", weight=100)  
G.add_edge("65", "24", weight=100)  
G.add_edge("65", "28", weight=100)  
G.add_edge("65", "29", weight=100)  
G.add_edge("65", "30", weight=100)  
G.add_edge("65", "31", weight=100)  
G.add_edge("65", "32", weight=100)  
G.add_edge("65", "35", weight=100)  
G.add_edge("65", "38", weight=100)  
G.add_edge("65", "39", weight=1000)  
G.add_edge("65", "45", weight=100)  
G.add_edge("65", "49", weight=100)  
G.add_edge("65", "49", weight=100)  
G.add_edge("65", "50", weight=100)  
G.add_edge("65", "51", weight=100)  
G.add_edge("65", "52", weight=100)  
G.add_edge("65", "53", weight=100)  
G.add_edge("65", "55", weight=100)  
G.add_edge("65", "57", weight=100)  
G.add_edge("65", "69", weight=100)  
G.add_edge("65", "69", weight=1000)  
G.add_edge("65", "77", weight=1000)  
G.add_edge("65", "78", weight=100)  
G.add_edge("65", "78", weight=1000)  
G.add_edge("65", "81", weight=1000)  
G.add_edge("65", "90", weight=100)  
G.add_edge("65", "90", weight=1000)  
G.add_edge("65", "91", weight=1000)  
G.add_edge("65", "96", weight=1000)  
G.add_edge("65", "115", weight=100)  
G.add_edge("65", "115", weight=100)  
G.add_edge("65", "115", weight=1000)  
G.add_edge("65", "132", weight=1000)  
G.add_edge("65", "142", weight=1000)  
G.add_edge("65", "146", weight=1000)  
G.add_edge("65", "166", weight=1000)  
G.add_edge("66", "6", weight=1000)  
G.add_edge("66", "6", weight=1000)  
G.add_edge("66", "6", weight=1000)  
G.add_edge("66", "6", weight=1000)  
G.add_edge("66", "8", weight=1000)  
G.add_edge("66", "9", weight=1000)  
G.add_edge("66", "11", weight=1000)  
G.add_edge("66", "19", weight=1000)  
G.add_edge("66", "19", weight=1000)  
G.add_edge("66", "39", weight=1000)  
G.add_edge("66", "41", weight=1000)  
G.add_edge("66", "43", weight=1000)  
G.add_edge("66", "44", weight=1000)  
G.add_edge("66", "62", weight=1000)  
G.add_edge("66", "63", weight=1000)  
G.add_edge("66", "64", weight=1000)  
G.add_edge("66", "69", weight=1000)  
G.add_edge("66", "85", weight=1000)  
G.add_edge("66", "85", weight=1000)  
G.add_edge("66", "88", weight=1000)  
G.add_edge("66", "94", weight=1000)  
G.add_edge("66", "97", weight=1000)  
G.add_edge("66", "100", weight=1000)  
G.add_edge("66", "107", weight=1000)  
G.add_edge("66", "108", weight=1000)  
G.add_edge("66", "110", weight=1000)  
G.add_edge("66", "113", weight=1000)  
G.add_edge("66", "118", weight=1000)  
G.add_edge("66", "123", weight=1000)  
G.add_edge("66", "124", weight=1000)  
G.add_edge("66", "126", weight=1000)  
G.add_edge("66", "127", weight=1000)  
G.add_edge("66", "128", weight=1000)  
G.add_edge("66", "130", weight=1000)  
G.add_edge("66", "131", weight=1000)  
G.add_edge("66", "132", weight=1000)  
G.add_edge("66", "137", weight=1000)  
G.add_edge("66", "138", weight=1000)  
G.add_edge("66", "139", weight=1000)  
G.add_edge("66", "142", weight=1000)  
G.add_edge("66", "143", weight=1000)  
G.add_edge("66", "144", weight=1000)  
G.add_edge("66", "147", weight=1000)  
G.add_edge("66", "154", weight=1000)  
G.add_edge("66", "155", weight=1000)  
G.add_edge("66", "157", weight=1000)  
G.add_edge("66", "166", weight=1000)  
G.add_edge("66", "168", weight=1000)  
G.add_edge("66", "172", weight=1000)  
G.add_edge("66", "175", weight=1000)  
G.add_edge("67", "0", weight=0)  
G.add_edge("67", "2", weight=0)  
G.add_edge("67", "4", weight=0)  
G.add_edge("67", "6", weight=0)  
G.add_edge("67", "9", weight=0)  
G.add_edge("67", "31", weight=0)  
G.add_edge("67", "41", weight=0)  
G.add_edge("67", "43", weight=0)  
G.add_edge("67", "44", weight=0)  
G.add_edge("67", "62", weight=0)  
G.add_edge("67", "64", weight=0)  
G.add_edge("67", "83", weight=0)  
G.add_edge("67", "84", weight=0)  
G.add_edge("67", "85", weight=0)  
G.add_edge("67", "98", weight=0)  
G.add_edge("67", "100", weight=0)  
G.add_edge("67", "103", weight=0)  
G.add_edge("67", "107", weight=0)  
G.add_edge("67", "120", weight=0)  
G.add_edge("67", "122", weight=0)  
G.add_edge("67", "124", weight=0)  
G.add_edge("67", "128", weight=0)  
G.add_edge("67", "129", weight=0)  
G.add_edge("67", "130", weight=0)  
G.add_edge("67", "144", weight=0)  
G.add_edge("67", "145", weight=0)  
G.add_edge("67", "146", weight=0)  
G.add_edge("67", "147", weight=0)  
G.add_edge("67", "154", weight=0)  
G.add_edge("67", "155", weight=0)  
G.add_edge("67", "156", weight=0)  
G.add_edge("67", "157", weight=0)  
G.add_edge("67", "160", weight=0)  
G.add_edge("67", "165", weight=0)  
G.add_edge("67", "168", weight=0)  
G.add_edge("67", "170", weight=0)  
G.add_edge("68", "0", weight=1000)  
G.add_edge("68", "1", weight=1000)  
G.add_edge("68", "6", weight=1000)  
G.add_edge("68", "8", weight=1000)  
G.add_edge("68", "9", weight=1000)  
G.add_edge("68", "15", weight=1000)  
G.add_edge("68", "18", weight=1000)  
G.add_edge("68", "28", weight=1000)  
G.add_edge("68", "32", weight=1000)  
G.add_edge("68", "43", weight=1000)  
G.add_edge("68", "44", weight=1000)  
G.add_edge("68", "52", weight=1000)  
G.add_edge("68", "57", weight=1000)  
G.add_edge("68", "58", weight=1000)  
G.add_edge("68", "69", weight=1000)  
G.add_edge("68", "85", weight=1000)  
G.add_edge("68", "87", weight=1000)  
G.add_edge("68", "95", weight=1000)  
G.add_edge("68", "103", weight=1000)  
G.add_edge("68", "107", weight=1000)  
G.add_edge("68", "130", weight=1000)  
G.add_edge("68", "139", weight=1000)  
G.add_edge("68", "142", weight=1000)  
G.add_edge("68", "147", weight=1000)  
G.add_edge("68", "168", weight=1000)  
G.add_edge("69", "0", weight=0)  
G.add_edge("69", "1", weight=0)  
G.add_edge("69", "7", weight=0)  
G.add_edge("69", "9", weight=0)  
G.add_edge("69", "10", weight=0)  
G.add_edge("69", "17", weight=0)  
G.add_edge("69", "25", weight=0)  
G.add_edge("69", "31", weight=0)  
G.add_edge("69", "34", weight=0)  
G.add_edge("69", "36", weight=0)  
G.add_edge("69", "37", weight=0)  
G.add_edge("69", "39", weight=0)  
G.add_edge("69", "40", weight=0)  
G.add_edge("69", "41", weight=0)  
G.add_edge("69", "42", weight=0)  
G.add_edge("69", "44", weight=0)  
G.add_edge("69", "45", weight=0)  
G.add_edge("69", "46", weight=0)  
G.add_edge("69", "54", weight=0)  
G.add_edge("69", "56", weight=0)  
G.add_edge("69", "59", weight=0)  
G.add_edge("69", "62", weight=0)  
G.add_edge("69", "64", weight=0)  
G.add_edge("69", "65", weight=0)  
G.add_edge("69", "65", weight=0)  
G.add_edge("69", "66", weight=0)  
G.add_edge("69", "68", weight=0)  
G.add_edge("69", "74", weight=0)  
G.add_edge("69", "75", weight=0)  
G.add_edge("69", "76", weight=0)  
G.add_edge("69", "77", weight=0)  
G.add_edge("69", "78", weight=0)  
G.add_edge("69", "79", weight=0)  
G.add_edge("69", "82", weight=0)  
G.add_edge("69", "85", weight=0)  
G.add_edge("69", "86", weight=0)  
G.add_edge("69", "87", weight=0)  
G.add_edge("69", "88", weight=0)  
G.add_edge("69", "90", weight=0)  
G.add_edge("69", "91", weight=0)  
G.add_edge("69", "95", weight=0)  
G.add_edge("69", "96", weight=0)  
G.add_edge("69", "99", weight=0)  
G.add_edge("69", "100", weight=0)  
G.add_edge("69", "101", weight=0)  
G.add_edge("69", "101", weight=0)  
G.add_edge("69", "102", weight=0)  
G.add_edge("69", "103", weight=0)  
G.add_edge("69", "104", weight=0)  
G.add_edge("69", "105", weight=0)  
G.add_edge("69", "107", weight=0)  
G.add_edge("69", "109", weight=0)  
G.add_edge("69", "110", weight=0)  
G.add_edge("69", "111", weight=0)  
G.add_edge("69", "113", weight=0)  
G.add_edge("69", "114", weight=0)  
G.add_edge("69", "115", weight=0)  
G.add_edge("69", "116", weight=0)  
G.add_edge("69", "118", weight=0)  
G.add_edge("69", "119", weight=0)  
G.add_edge("69", "122", weight=0)  
G.add_edge("69", "123", weight=0)  
G.add_edge("69", "125", weight=0)  
G.add_edge("69", "126", weight=0)  
G.add_edge("69", "127", weight=0)  
G.add_edge("69", "128", weight=0)  
G.add_edge("69", "129", weight=0)  
G.add_edge("69", "130", weight=0)  
G.add_edge("69", "131", weight=0)  
G.add_edge("69", "132", weight=0)  
G.add_edge("69", "134", weight=0)  
G.add_edge("69", "136", weight=0)  
G.add_edge("69", "137", weight=0)  
G.add_edge("69", "138", weight=0)  
G.add_edge("69", "139", weight=0)  
G.add_edge("69", "141", weight=0)  
G.add_edge("69", "142", weight=0)  
G.add_edge("69", "147", weight=0)  
G.add_edge("69", "151", weight=0)  
G.add_edge("69", "155", weight=0)  
G.add_edge("69", "163", weight=0)  
G.add_edge("69", "164", weight=0)  
G.add_edge("69", "166", weight=0)  
G.add_edge("69", "168", weight=0)  
G.add_edge("69", "171", weight=0)  
G.add_edge("69", "172", weight=0)  
G.add_edge("69", "174", weight=0)  
G.add_edge("70", "1", weight=1000)  
G.add_edge("70", "2", weight=1000)  
G.add_edge("70", "6", weight=1000)  
G.add_edge("70", "6", weight=1000)  
G.add_edge("70", "6", weight=1000)  
G.add_edge("70", "6", weight=1000)  
G.add_edge("70", "6", weight=1000)  
G.add_edge("70", "6", weight=1000)  
G.add_edge("70", "8", weight=1000)  
G.add_edge("70", "9", weight=1000)  
G.add_edge("70", "9", weight=1000)  
G.add_edge("70", "9", weight=1000)  
G.add_edge("70", "9", weight=1000)  
G.add_edge("70", "11", weight=1000)  
G.add_edge("70", "14", weight=1000)  
G.add_edge("70", "20", weight=1000)  
G.add_edge("70", "20", weight=1000)  
G.add_edge("70", "31", weight=1000)  
G.add_edge("70", "31", weight=1000)  
G.add_edge("70", "32", weight=1000)  
G.add_edge("70", "33", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "35", weight=1000)  
G.add_edge("70", "37", weight=1000)  
G.add_edge("70", "39", weight=1000)  
G.add_edge("70", "41", weight=1000)  
G.add_edge("70", "41", weight=1000)  
G.add_edge("70", "41", weight=1000)  
G.add_edge("70", "43", weight=1000)  
G.add_edge("70", "44", weight=1000)  
G.add_edge("70", "44", weight=1000)  
G.add_edge("70", "49", weight=1000)  
G.add_edge("70", "49", weight=1000)  
G.add_edge("70", "53", weight=1000)  
G.add_edge("70", "53", weight=1000)  
G.add_edge("70", "57", weight=1000)  
G.add_edge("70", "59", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "60", weight=1000)  
G.add_edge("70", "62", weight=1000)  
G.add_edge("70", "62", weight=1000)  
G.add_edge("70", "62", weight=1000)  
G.add_edge("70", "64", weight=1000)  
G.add_edge("70", "64", weight=1000)  
G.add_edge("70", "71", weight=1000)  
G.add_edge("70", "75", weight=1000)  
G.add_edge("70", "76", weight=1000)  
G.add_edge("70", "82", weight=1000)  
G.add_edge("70", "83", weight=1000)  
G.add_edge("70", "84", weight=1000)  
G.add_edge("70", "85", weight=1000)  
G.add_edge("70", "86", weight=1000)  
G.add_edge("70", "86", weight=1000)  
G.add_edge("70", "87", weight=1000)  
G.add_edge("70", "88", weight=1000)  
G.add_edge("70", "94", weight=1000)  
G.add_edge("70", "94", weight=1000)  
G.add_edge("70", "94", weight=1000)  
G.add_edge("70", "95", weight=1000)  
G.add_edge("70", "97", weight=1000)  
G.add_edge("70", "98", weight=1000)  
G.add_edge("70", "98", weight=1000)  
G.add_edge("70", "98", weight=1000)  
G.add_edge("70", "98", weight=1000)  
G.add_edge("70", "98", weight=1000)  
G.add_edge("70", "100", weight=1000)  
G.add_edge("70", "100", weight=1000)  
G.add_edge("70", "100", weight=1000)  
G.add_edge("70", "100", weight=1000)  
G.add_edge("70", "101", weight=1000)  
G.add_edge("70", "101", weight=1000)  
G.add_edge("70", "103", weight=1000)  
G.add_edge("70", "103", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "104", weight=1000)  
G.add_edge("70", "105", weight=1000)  
G.add_edge("70", "107", weight=1000)  
G.add_edge("70", "108", weight=1000)  
G.add_edge("70", "109", weight=1000)  
G.add_edge("70", "113", weight=1000)  
G.add_edge("70", "114", weight=1000)  
G.add_edge("70", "116", weight=1000)  
G.add_edge("70", "118", weight=1000)  
G.add_edge("70", "119", weight=1000)  
G.add_edge("70", "122", weight=1000)  
G.add_edge("70", "122", weight=1000)  
G.add_edge("70", "123", weight=1000)  
G.add_edge("70", "124", weight=1000)  
G.add_edge("70", "125", weight=1000)  
G.add_edge("70", "126", weight=1000)  
G.add_edge("70", "127", weight=1000)  
G.add_edge("70", "128", weight=1000)  
G.add_edge("70", "129", weight=1000)  
G.add_edge("70", "130", weight=1000)  
G.add_edge("70", "131", weight=1000)  
G.add_edge("70", "132", weight=1000)  
G.add_edge("70", "133", weight=1000)  
G.add_edge("70", "134", weight=1000)  
G.add_edge("70", "137", weight=1000)  
G.add_edge("70", "138", weight=1000)  
G.add_edge("70", "140", weight=1000)  
G.add_edge("70", "142", weight=1000)  
G.add_edge("70", "144", weight=1000)  
G.add_edge("70", "145", weight=1000)  
G.add_edge("70", "145", weight=1000)  
G.add_edge("70", "146", weight=1000)  
G.add_edge("70", "147", weight=1000)  
G.add_edge("70", "149", weight=1000)  
G.add_edge("70", "151", weight=1000)  
G.add_edge("70", "154", weight=1000)  
G.add_edge("70", "155", weight=1000)  
G.add_edge("70", "160", weight=1000)  
G.add_edge("70", "163", weight=1000)  
G.add_edge("70", "164", weight=1000)  
G.add_edge("70", "165", weight=1000)  
G.add_edge("70", "166", weight=1000)  
G.add_edge("70", "168", weight=1000)  
G.add_edge("70", "170", weight=1000)  
G.add_edge("70", "171", weight=1000)  
G.add_edge("70", "172", weight=1000)  
G.add_edge("70", "174", weight=1000)  
G.add_edge("70", "174", weight=1000)  
G.add_edge("70", "174", weight=1000)  
G.add_edge("70", "174", weight=1000)  
G.add_edge("70", "174", weight=1000)  
G.add_edge("70", "175", weight=1000)  
G.add_edge("70", "176", weight=1000)  
G.add_edge("71", "1", weight=0)  
G.add_edge("71", "3", weight=0)  
G.add_edge("71", "15", weight=0)  
G.add_edge("71", "31", weight=0)  
G.add_edge("71", "39", weight=0)  
G.add_edge("71", "40", weight=0)  
G.add_edge("71", "43", weight=0)  
G.add_edge("71", "44", weight=0)  
G.add_edge("71", "46", weight=0)  
G.add_edge("71", "58", weight=0)  
G.add_edge("71", "70", weight=0)  
G.add_edge("71", "100", weight=0)  
G.add_edge("71", "103", weight=0)  
G.add_edge("71", "127", weight=0)  
G.add_edge("71", "128", weight=0)  
G.add_edge("71", "130", weight=0)  
G.add_edge("71", "132", weight=0)  
G.add_edge("71", "137", weight=0)  
G.add_edge("71", "139", weight=0)  
G.add_edge("71", "142", weight=0)  
G.add_edge("71", "146", weight=0)  
G.add_edge("71", "147", weight=0)  
G.add_edge("71", "161", weight=0)  
G.add_edge("71", "164", weight=0)  
G.add_edge("71", "165", weight=0)  
G.add_edge("71", "168", weight=0)  
G.add_edge("71", "175", weight=1000)  
G.add_edge("72", "1", weight=0)  
G.add_edge("72", "3", weight=0)  
G.add_edge("72", "6", weight=0)  
G.add_edge("72", "6", weight=0)  
G.add_edge("72", "7", weight=0)  
G.add_edge("72", "9", weight=0)  
G.add_edge("72", "10", weight=0)  
G.add_edge("72", "11", weight=0)  
G.add_edge("72", "12", weight=0)  
G.add_edge("72", "13", weight=0)  
G.add_edge("72", "31", weight=0)  
G.add_edge("72", "34", weight=0)  
G.add_edge("72", "43", weight=0)  
G.add_edge("72", "43", weight=0)  
G.add_edge("72", "46", weight=0)  
G.add_edge("72", "55", weight=0)  
G.add_edge("72", "56", weight=0)  
G.add_edge("72", "58", weight=0)  
G.add_edge("72", "62", weight=0)  
G.add_edge("72", "77", weight=0)  
G.add_edge("72", "102", weight=100)  
G.add_edge("72", "139", weight=100)  
G.add_edge("72", "142", weight=0)  
G.add_edge("72", "143", weight=0)  
G.add_edge("72", "146", weight=0)  
G.add_edge("72", "147", weight=100)  
G.add_edge("72", "151", weight=0)  
G.add_edge("72", "152", weight=0)  
G.add_edge("72", "155", weight=0)  
G.add_edge("72", "160", weight=0)  
G.add_edge("72", "161", weight=0)  
G.add_edge("72", "165", weight=0)  
G.add_edge("72", "172", weight=100)  
G.add_edge("73", "6", weight=1000)  
G.add_edge("73", "6", weight=1000)  
G.add_edge("73", "6", weight=1000)  
G.add_edge("73", "6", weight=1000)  
G.add_edge("73", "9", weight=1000)  
G.add_edge("73", "35", weight=1000)  
G.add_edge("73", "35", weight=1000)  
G.add_edge("73", "60", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "79", weight=1000)  
G.add_edge("73", "82", weight=1000)  
G.add_edge("73", "95", weight=1000)  
G.add_edge("73", "103", weight=1000)  
G.add_edge("73", "104", weight=1000)  
G.add_edge("73", "111", weight=1000)  
G.add_edge("73", "111", weight=1000)  
G.add_edge("73", "126", weight=1000)  
G.add_edge("74", "0", weight=0)  
G.add_edge("74", "1", weight=0)  
G.add_edge("74", "2", weight=0)  
G.add_edge("74", "6", weight=0)  
G.add_edge("74", "7", weight=0)  
G.add_edge("74", "8", weight=0)  
G.add_edge("74", "9", weight=0)  
G.add_edge("74", "13", weight=0)  
G.add_edge("74", "31", weight=0)  
G.add_edge("74", "37", weight=0)  
G.add_edge("74", "38", weight=0)  
G.add_edge("74", "39", weight=0)  
G.add_edge("74", "40", weight=0)  
G.add_edge("74", "44", weight=0)  
G.add_edge("74", "45", weight=0)  
G.add_edge("74", "48", weight=0)  
G.add_edge("74", "62", weight=0)  
G.add_edge("74", "69", weight=0)  
G.add_edge("74", "77", weight=0)  
G.add_edge("74", "78", weight=0)  
G.add_edge("74", "79", weight=0)  
G.add_edge("74", "81", weight=0)  
G.add_edge("74", "85", weight=0)  
G.add_edge("74", "88", weight=0)  
G.add_edge("74", "89", weight=0)  
G.add_edge("74", "90", weight=0)  
G.add_edge("74", "91", weight=0)  
G.add_edge("74", "94", weight=0)  
G.add_edge("74", "95", weight=0)  
G.add_edge("74", "96", weight=0)  
G.add_edge("74", "97", weight=0)  
G.add_edge("74", "99", weight=0)  
G.add_edge("74", "103", weight=0)  
G.add_edge("74", "106", weight=0)  
G.add_edge("74", "109", weight=0)  
G.add_edge("74", "110", weight=0)  
G.add_edge("74", "113", weight=0)  
G.add_edge("74", "115", weight=0)  
G.add_edge("74", "116", weight=0)  
G.add_edge("74", "125", weight=0)  
G.add_edge("74", "126", weight=0)  
G.add_edge("74", "128", weight=0)  
G.add_edge("74", "130", weight=0)  
G.add_edge("74", "137", weight=0)  
G.add_edge("74", "141", weight=0)  
G.add_edge("74", "142", weight=0)  
G.add_edge("74", "147", weight=0)  
G.add_edge("74", "155", weight=0)  
G.add_edge("74", "161", weight=0)  
G.add_edge("74", "164", weight=0)  
G.add_edge("74", "168", weight=0)  
G.add_edge("74", "175", weight=0)  
G.add_edge("74", "176", weight=0)  
G.add_edge("75", "2", weight=1000)  
G.add_edge("75", "6", weight=1000)  
G.add_edge("75", "9", weight=1000)  
G.add_edge("75", "10", weight=1000)  
G.add_edge("75", "11", weight=1000)  
G.add_edge("75", "12", weight=1000)  
G.add_edge("75", "13", weight=1000)  
G.add_edge("75", "13", weight=1000)  
G.add_edge("75", "14", weight=1000)  
G.add_edge("75", "14", weight=1000)  
G.add_edge("75", "15", weight=1000)  
G.add_edge("75", "15", weight=1000)  
G.add_edge("75", "17", weight=1000)  
G.add_edge("75", "17", weight=1000)  
G.add_edge("75", "23", weight=1000)  
G.add_edge("75", "24", weight=1000)  
G.add_edge("75", "25", weight=1000)  
G.add_edge("75", "26", weight=1000)  
G.add_edge("75", "29", weight=1000)  
G.add_edge("75", "43", weight=1000)  
G.add_edge("75", "44", weight=1000)  
G.add_edge("75", "52", weight=1000)  
G.add_edge("75", "53", weight=1000)  
G.add_edge("75", "59", weight=1000)  
G.add_edge("75", "62", weight=1000)  
G.add_edge("75", "69", weight=1000)  
G.add_edge("75", "70", weight=1000)  
G.add_edge("75", "76", weight=1000)  
G.add_edge("75", "87", weight=1000)  
G.add_edge("75", "95", weight=1000)  
G.add_edge("75", "103", weight=1000)  
G.add_edge("75", "107", weight=1000)  
G.add_edge("75", "108", weight=1000)  
G.add_edge("75", "108", weight=1000)  
G.add_edge("75", "143", weight=1000)  
G.add_edge("75", "147", weight=1000)  
G.add_edge("76", "5", weight=1000)  
G.add_edge("76", "8", weight=1000)  
G.add_edge("76", "9", weight=1000)  
G.add_edge("76", "10", weight=1000)  
G.add_edge("76", "10", weight=1000)  
G.add_edge("76", "10", weight=1000)  
G.add_edge("76", "10", weight=1000)  
G.add_edge("76", "12", weight=1000)  
G.add_edge("76", "12", weight=1000)  
G.add_edge("76", "13", weight=1000)  
G.add_edge("76", "13", weight=1000)  
G.add_edge("76", "14", weight=1000)  
G.add_edge("76", "14", weight=1000)  
G.add_edge("76", "16", weight=1000)  
G.add_edge("76", "16", weight=1000)  
G.add_edge("76", "17", weight=1000)  
G.add_edge("76", "17", weight=1000)  
G.add_edge("76", "19", weight=1000)  
G.add_edge("76", "19", weight=1000)  
G.add_edge("76", "20", weight=1000)  
G.add_edge("76", "21", weight=1000)  
G.add_edge("76", "22", weight=1000)  
G.add_edge("76", "22", weight=1000)  
G.add_edge("76", "24", weight=1000)  
G.add_edge("76", "24", weight=1000)  
G.add_edge("76", "26", weight=1000)  
G.add_edge("76", "28", weight=1000)  
G.add_edge("76", "30", weight=1000)  
G.add_edge("76", "32", weight=1000)  
G.add_edge("76", "32", weight=1000)  
G.add_edge("76", "39", weight=1000)  
G.add_edge("76", "43", weight=1000)  
G.add_edge("76", "43", weight=1000)  
G.add_edge("76", "46", weight=1000)  
G.add_edge("76", "52", weight=1000)  
G.add_edge("76", "57", weight=1000)  
G.add_edge("76", "61", weight=1000)  
G.add_edge("76", "62", weight=1000)  
G.add_edge("76", "64", weight=1000)  
G.add_edge("76", "69", weight=1000)  
G.add_edge("76", "70", weight=1000)  
G.add_edge("76", "75", weight=1000)  
G.add_edge("76", "94", weight=1000)  
G.add_edge("76", "95", weight=1000)  
G.add_edge("76", "100", weight=1000)  
G.add_edge("76", "103", weight=1000)  
G.add_edge("76", "108", weight=1000)  
G.add_edge("76", "113", weight=1000)  
G.add_edge("76", "126", weight=1000)  
G.add_edge("76", "128", weight=1000)  
G.add_edge("76", "138", weight=1000)  
G.add_edge("76", "142", weight=1000)  
G.add_edge("76", "143", weight=1000)  
G.add_edge("76", "151", weight=1000)  
G.add_edge("77", "7", weight=0)  
G.add_edge("77", "26", weight=0)  
G.add_edge("77", "38", weight=0)  
G.add_edge("77", "39", weight=0)  
G.add_edge("77", "58", weight=0)  
G.add_edge("77", "65", weight=0)  
G.add_edge("77", "69", weight=0)  
G.add_edge("77", "72", weight=0)  
G.add_edge("77", "74", weight=0)  
G.add_edge("77", "95", weight=0)  
G.add_edge("77", "97", weight=0)  
G.add_edge("77", "100", weight=0)  
G.add_edge("77", "109", weight=0)  
G.add_edge("77", "113", weight=0)  
G.add_edge("77", "114", weight=0)  
G.add_edge("77", "128", weight=0)  
G.add_edge("77", "142", weight=0)  
G.add_edge("77", "143", weight=0)  
G.add_edge("77", "146", weight=0)  
G.add_edge("77", "151", weight=0)  
G.add_edge("77", "161", weight=0)  
G.add_edge("77", "165", weight=0)  
G.add_edge("77", "165", weight=0)  
G.add_edge("78", "1", weight=0)  
G.add_edge("78", "6", weight=0)  
G.add_edge("78", "7", weight=0)  
G.add_edge("78", "8", weight=0)  
G.add_edge("78", "9", weight=0)  
G.add_edge("78", "24", weight=0)  
G.add_edge("78", "44", weight=0)  
G.add_edge("78", "57", weight=0)  
G.add_edge("78", "58", weight=0)  
G.add_edge("78", "65", weight=0)  
G.add_edge("78", "65", weight=0)  
G.add_edge("78", "69", weight=0)  
G.add_edge("78", "74", weight=0)  
G.add_edge("78", "83", weight=0)  
G.add_edge("78", "91", weight=0)  
G.add_edge("78", "93", weight=0)  
G.add_edge("78", "94", weight=0)  
G.add_edge("78", "95", weight=1000)  
G.add_edge("78", "96", weight=0)  
G.add_edge("78", "96", weight=0)  
G.add_edge("78", "97", weight=0)  
G.add_edge("78", "100", weight=0)  
G.add_edge("78", "103", weight=0)  
G.add_edge("78", "114", weight=1000)  
G.add_edge("78", "119", weight=0)  
G.add_edge("78", "125", weight=0)  
G.add_edge("78", "128", weight=0)  
G.add_edge("78", "129", weight=0)  
G.add_edge("78", "130", weight=0)  
G.add_edge("78", "132", weight=1000)  
G.add_edge("78", "146", weight=0)  
G.add_edge("78", "152", weight=0)  
G.add_edge("78", "161", weight=0)  
G.add_edge("78", "174", weight=0)  
G.add_edge("78", "175", weight=0)  
G.add_edge("79", "0", weight=1000)  
G.add_edge("79", "4", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "6", weight=1000)  
G.add_edge("79", "7", weight=1000)  
G.add_edge("79", "9", weight=1000)  
G.add_edge("79", "9", weight=1000)  
G.add_edge("79", "9", weight=1000)  
G.add_edge("79", "9", weight=1000)  
G.add_edge("79", "9", weight=1000)  
G.add_edge("79", "9", weight=1000)  
G.add_edge("79", "11", weight=1000)  
G.add_edge("79", "18", weight=1000)  
G.add_edge("79", "37", weight=1000)  
G.add_edge("79", "38", weight=1000)  
G.add_edge("79", "39", weight=1000)  
G.add_edge("79", "41", weight=1000)  
G.add_edge("79", "41", weight=1000)  
G.add_edge("79", "41", weight=1000)  
G.add_edge("79", "41", weight=1000)  
G.add_edge("79", "41", weight=1000)  
G.add_edge("79", "43", weight=1000)  
G.add_edge("79", "44", weight=1000)  
G.add_edge("79", "46", weight=1000)  
G.add_edge("79", "47", weight=1000)  
G.add_edge("79", "57", weight=1000)  
G.add_edge("79", "59", weight=1000)  
G.add_edge("79", "63", weight=1000)  
G.add_edge("79", "64", weight=1000)  
G.add_edge("79", "64", weight=1000)  
G.add_edge("79", "64", weight=1000)  
G.add_edge("79", "69", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "73", weight=1000)  
G.add_edge("79", "74", weight=1000)  
G.add_edge("79", "84", weight=1000)  
G.add_edge("79", "94", weight=1000)  
G.add_edge("79", "95", weight=1000)  
G.add_edge("79", "97", weight=1000)  
G.add_edge("79", "100", weight=1000)  
G.add_edge("79", "100", weight=1000)  
G.add_edge("79", "100", weight=1000)  
G.add_edge("79", "101", weight=1000)  
G.add_edge("79", "102", weight=1000)  
G.add_edge("79", "103", weight=1000)  
G.add_edge("79", "105", weight=1000)  
G.add_edge("79", "107", weight=1000)  
G.add_edge("79", "108", weight=1000)  
G.add_edge("79", "108", weight=1000)  
G.add_edge("79", "110", weight=1000)  
G.add_edge("79", "113", weight=1000)  
G.add_edge("79", "114", weight=1000)  
G.add_edge("79", "118", weight=1000)  
G.add_edge("79", "119", weight=1000)  
G.add_edge("79", "119", weight=1000)  
G.add_edge("79", "123", weight=1000)  
G.add_edge("79", "125", weight=1000)  
G.add_edge("79", "126", weight=1000)  
G.add_edge("79", "127", weight=1000)  
G.add_edge("79", "128", weight=1000)  
G.add_edge("79", "130", weight=1000)  
G.add_edge("79", "132", weight=1000)  
G.add_edge("79", "135", weight=1000)  
G.add_edge("79", "137", weight=1000)  
G.add_edge("79", "138", weight=1000)  
G.add_edge("79", "139", weight=1000)  
G.add_edge("79", "140", weight=1000)  
G.add_edge("79", "142", weight=1000)  
G.add_edge("79", "142", weight=1000)  
G.add_edge("79", "143", weight=1000)  
G.add_edge("79", "144", weight=1000)  
G.add_edge("79", "145", weight=1000)  
G.add_edge("79", "146", weight=1000)  
G.add_edge("79", "147", weight=1000)  
G.add_edge("79", "151", weight=1000)  
G.add_edge("79", "152", weight=1000)  
G.add_edge("79", "154", weight=1000)  
G.add_edge("79", "155", weight=1000)  
G.add_edge("79", "156", weight=1000)  
G.add_edge("79", "158", weight=1000)  
G.add_edge("79", "160", weight=1000)  
G.add_edge("79", "161", weight=1000)  
G.add_edge("79", "163", weight=1000)  
G.add_edge("79", "165", weight=1000)  
G.add_edge("79", "166", weight=1000)  
G.add_edge("79", "168", weight=1000)  
G.add_edge("79", "170", weight=1000)  
G.add_edge("79", "171", weight=1000)  
G.add_edge("79", "172", weight=1000)  
G.add_edge("79", "173", weight=1000)  
G.add_edge("79", "175", weight=1000)  
G.add_edge("80", "6", weight=1000)  
G.add_edge("80", "10", weight=1000)  
G.add_edge("80", "18", weight=1000)  
G.add_edge("80", "44", weight=1000)  
G.add_edge("80", "64", weight=1000)  
G.add_edge("80", "85", weight=1000)  
G.add_edge("80", "99", weight=1000)  
G.add_edge("80", "100", weight=1000)  
G.add_edge("80", "102", weight=1000)  
G.add_edge("80", "107", weight=1000)  
G.add_edge("80", "113", weight=1000)  
G.add_edge("80", "116", weight=1000)  
G.add_edge("80", "128", weight=1000)  
G.add_edge("80", "133", weight=1000)  
G.add_edge("80", "136", weight=1000)  
G.add_edge("80", "145", weight=1000)  
G.add_edge("80", "146", weight=1000)  
G.add_edge("80", "148", weight=1000)  
G.add_edge("80", "151", weight=1000)  
G.add_edge("80", "152", weight=1000)  
G.add_edge("80", "154", weight=1000)  
G.add_edge("80", "155", weight=1000)  
G.add_edge("80", "157", weight=1000)  
G.add_edge("80", "158", weight=1000)  
G.add_edge("80", "160", weight=1000)  
G.add_edge("80", "166", weight=1000)  
G.add_edge("80", "173", weight=1000)  
G.add_edge("80", "177", weight=1000)  
G.add_edge("81", "2", weight=5000)  
G.add_edge("81", "6", weight=5000)  
G.add_edge("81", "7", weight=5000)  
G.add_edge("81", "8", weight=5000)  
G.add_edge("81", "13", weight=5000)  
G.add_edge("81", "27", weight=5000)  
G.add_edge("81", "27", weight=5000)  
G.add_edge("81", "37", weight=5000)  
G.add_edge("81", "39", weight=5000)  
G.add_edge("81", "57", weight=5000)  
G.add_edge("81", "58", weight=5000)  
G.add_edge("81", "65", weight=5000)  
G.add_edge("81", "74", weight=5000)  
G.add_edge("81", "92", weight=5000)  
G.add_edge("81", "109", weight=5000)  
G.add_edge("81", "114", weight=5000)  
G.add_edge("81", "146", weight=5000)  
G.add_edge("81", "161", weight=5000)  
G.add_edge("82", "0", weight=1000)  
G.add_edge("82", "2", weight=1000)  
G.add_edge("82", "4", weight=1000)  
G.add_edge("82", "6", weight=1000)  
G.add_edge("82", "9", weight=1000)  
G.add_edge("82", "12", weight=1000)  
G.add_edge("82", "17", weight=1000)  
G.add_edge("82", "44", weight=1000)  
G.add_edge("82", "50", weight=1000)  
G.add_edge("82", "57", weight=1000)  
G.add_edge("82", "60", weight=1000)  
G.add_edge("82", "62", weight=1000)  
G.add_edge("82", "69", weight=1000)  
G.add_edge("82", "70", weight=1000)  
G.add_edge("82", "73", weight=1000)  
G.add_edge("82", "83", weight=1000)  
G.add_edge("82", "103", weight=1000)  
G.add_edge("82", "116", weight=1000)  
G.add_edge("82", "119", weight=1000)  
G.add_edge("82", "126", weight=1000)  
G.add_edge("82", "130", weight=1000)  
G.add_edge("82", "140", weight=1000)  
G.add_edge("82", "143", weight=1000)  
G.add_edge("82", "155", weight=1000)  
G.add_edge("82", "156", weight=1000)  
G.add_edge("82", "165", weight=1000)  
G.add_edge("82", "166", weight=1000)  
G.add_edge("82", "174", weight=1000)  
G.add_edge("82", "175", weight=1000)  
G.add_edge("83", "1", weight=0)  
G.add_edge("83", "6", weight=0)  
G.add_edge("83", "7", weight=0)  
G.add_edge("83", "9", weight=0)  
G.add_edge("83", "10", weight=0)  
G.add_edge("83", "11", weight=0)  
G.add_edge("83", "14", weight=0)  
G.add_edge("83", "23", weight=0)  
G.add_edge("83", "34", weight=0)  
G.add_edge("83", "37", weight=0)  
G.add_edge("83", "40", weight=0)  
G.add_edge("83", "41", weight=0)  
G.add_edge("83", "42", weight=0)  
G.add_edge("83", "43", weight=0)  
G.add_edge("83", "44", weight=0)  
G.add_edge("83", "45", weight=0)  
G.add_edge("83", "46", weight=0)  
G.add_edge("83", "47", weight=0)  
G.add_edge("83", "57", weight=0)  
G.add_edge("83", "58", weight=0)  
G.add_edge("83", "59", weight=0)  
G.add_edge("83", "62", weight=0)  
G.add_edge("83", "63", weight=0)  
G.add_edge("83", "67", weight=0)  
G.add_edge("83", "70", weight=0)  
G.add_edge("83", "78", weight=0)  
G.add_edge("83", "82", weight=0)  
G.add_edge("83", "92", weight=0)  
G.add_edge("83", "94", weight=0)  
G.add_edge("83", "100", weight=0)  
G.add_edge("83", "101", weight=0)  
G.add_edge("83", "102", weight=0)  
G.add_edge("83", "105", weight=0)  
G.add_edge("83", "106", weight=0)  
G.add_edge("83", "108", weight=0)  
G.add_edge("83", "119", weight=0)  
G.add_edge("83", "122", weight=0)  
G.add_edge("83", "132", weight=0)  
G.add_edge("83", "134", weight=0)  
G.add_edge("83", "139", weight=0)  
G.add_edge("83", "142", weight=0)  
G.add_edge("83", "158", weight=0)  
G.add_edge("83", "160", weight=0)  
G.add_edge("83", "171", weight=0)  
G.add_edge("83", "174", weight=0)  
G.add_edge("84", "1", weight=1000)  
G.add_edge("84", "6", weight=1000)  
G.add_edge("84", "8", weight=1000)  
G.add_edge("84", "9", weight=1000)  
G.add_edge("84", "9", weight=1000)  
G.add_edge("84", "16", weight=1000)  
G.add_edge("84", "40", weight=1000)  
G.add_edge("84", "40", weight=1000)  
G.add_edge("84", "41", weight=1000)  
G.add_edge("84", "48", weight=1000)  
G.add_edge("84", "53", weight=1000)  
G.add_edge("84", "59", weight=1000)  
G.add_edge("84", "62", weight=1000)  
G.add_edge("84", "63", weight=1000)  
G.add_edge("84", "64", weight=1000)  
G.add_edge("84", "67", weight=1000)  
G.add_edge("84", "70", weight=1000)  
G.add_edge("84", "79", weight=1000)  
G.add_edge("84", "85", weight=1000)  
G.add_edge("84", "85", weight=1000)  
G.add_edge("84", "99", weight=1000)  
G.add_edge("84", "100", weight=1000)  
G.add_edge("84", "101", weight=1000)  
G.add_edge("84", "102", weight=1000)  
G.add_edge("84", "103", weight=1000)  
G.add_edge("84", "104", weight=1000)  
G.add_edge("84", "107", weight=1000)  
G.add_edge("84", "108", weight=1000)  
G.add_edge("84", "113", weight=1000)  
G.add_edge("84", "118", weight=1000)  
G.add_edge("84", "123", weight=1000)  
G.add_edge("84", "125", weight=1000)  
G.add_edge("84", "127", weight=1000)  
G.add_edge("84", "128", weight=1000)  
G.add_edge("84", "130", weight=1000)  
G.add_edge("84", "132", weight=1000)  
G.add_edge("84", "134", weight=1000)  
G.add_edge("84", "138", weight=1000)  
G.add_edge("84", "140", weight=1000)  
G.add_edge("84", "155", weight=1000)  
G.add_edge("84", "157", weight=1000)  
G.add_edge("84", "160", weight=1000)  
G.add_edge("84", "160", weight=1000)  
G.add_edge("84", "163", weight=1000)  
G.add_edge("84", "166", weight=1000)  
G.add_edge("84", "170", weight=1000)  
G.add_edge("84", "172", weight=1000)  
G.add_edge("84", "173", weight=1000)  
G.add_edge("84", "175", weight=1000)  
G.add_edge("85", "2", weight=0)  
G.add_edge("85", "4", weight=0)  
G.add_edge("85", "6", weight=0)  
G.add_edge("85", "8", weight=0)  
G.add_edge("85", "11", weight=0)  
G.add_edge("85", "18", weight=0)  
G.add_edge("85", "27", weight=0)  
G.add_edge("85", "31", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "35", weight=0)  
G.add_edge("85", "39", weight=0)  
G.add_edge("85", "40", weight=0)  
G.add_edge("85", "40", weight=1000)  
G.add_edge("85", "41", weight=0)  
G.add_edge("85", "41", weight=0)  
G.add_edge("85", "42", weight=0)  
G.add_edge("85", "43", weight=0)  
G.add_edge("85", "44", weight=0)  
G.add_edge("85", "45", weight=0)  
G.add_edge("85", "46", weight=0)  
G.add_edge("85", "51", weight=0)  
G.add_edge("85", "55", weight=0)  
G.add_edge("85", "58", weight=0)  
G.add_edge("85", "59", weight=0)  
G.add_edge("85", "60", weight=0)  
G.add_edge("85", "60", weight=0)  
G.add_edge("85", "62", weight=0)  
G.add_edge("85", "62", weight=0)  
G.add_edge("85", "62", weight=0)  
G.add_edge("85", "62", weight=0)  
G.add_edge("85", "63", weight=0)  
G.add_edge("85", "64", weight=0)  
G.add_edge("85", "66", weight=0)  
G.add_edge("85", "66", weight=0)  
G.add_edge("85", "67", weight=0)  
G.add_edge("85", "68", weight=0)  
G.add_edge("85", "69", weight=0)  
G.add_edge("85", "70", weight=0)  
G.add_edge("85", "74", weight=0)  
G.add_edge("85", "80", weight=0)  
G.add_edge("85", "84", weight=0)  
G.add_edge("85", "84", weight=0)  
G.add_edge("85", "86", weight=0)  
G.add_edge("85", "92", weight=0)  
G.add_edge("85", "94", weight=0)  
G.add_edge("85", "97", weight=0)  
G.add_edge("85", "99", weight=0)  
G.add_edge("85", "100", weight=0)  
G.add_edge("85", "100", weight=0)  
G.add_edge("85", "101", weight=0)  
G.add_edge("85", "101", weight=0)  
G.add_edge("85", "103", weight=0)  
G.add_edge("85", "104", weight=0)  
G.add_edge("85", "105", weight=0)  
G.add_edge("85", "107", weight=0)  
G.add_edge("85", "108", weight=0)  
G.add_edge("85", "109", weight=0)  
G.add_edge("85", "110", weight=0)  
G.add_edge("85", "112", weight=0)  
G.add_edge("85", "113", weight=0)  
G.add_edge("85", "114", weight=0)  
G.add_edge("85", "116", weight=0)  
G.add_edge("85", "118", weight=0)  
G.add_edge("85", "119", weight=0)  
G.add_edge("85", "123", weight=0)  
G.add_edge("85", "124", weight=0)  
G.add_edge("85", "125", weight=0)  
G.add_edge("85", "126", weight=0)  
G.add_edge("85", "127", weight=0)  
G.add_edge("85", "128", weight=0)  
G.add_edge("85", "128", weight=0)  
G.add_edge("85", "130", weight=0)  
G.add_edge("85", "131", weight=0)  
G.add_edge("85", "132", weight=0)  
G.add_edge("85", "134", weight=0)  
G.add_edge("85", "135", weight=0)  
G.add_edge("85", "137", weight=0)  
G.add_edge("85", "138", weight=0)  
G.add_edge("85", "139", weight=0)  
G.add_edge("85", "140", weight=0)  
G.add_edge("85", "142", weight=0)  
G.add_edge("85", "145", weight=0)  
G.add_edge("85", "146", weight=0)  
G.add_edge("85", "147", weight=0)  
G.add_edge("85", "149", weight=0)  
G.add_edge("85", "151", weight=0)  
G.add_edge("85", "152", weight=0)  
G.add_edge("85", "154", weight=0)  
G.add_edge("85", "155", weight=0)  
G.add_edge("85", "157", weight=0)  
G.add_edge("85", "161", weight=0)  
G.add_edge("85", "163", weight=0)  
G.add_edge("85", "164", weight=0)  
G.add_edge("85", "165", weight=0)  
G.add_edge("85", "165", weight=0)  
G.add_edge("85", "166", weight=0)  
G.add_edge("85", "168", weight=0)  
G.add_edge("85", "170", weight=0)  
G.add_edge("85", "171", weight=0)  
G.add_edge("85", "172", weight=0)  
G.add_edge("85", "173", weight=0)  
G.add_edge("85", "174", weight=0)  
G.add_edge("85", "175", weight=0)  
G.add_edge("85", "176", weight=0)  
G.add_edge("86", "0", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "6", weight=1)  
G.add_edge("86", "35", weight=1)  
G.add_edge("86", "35", weight=1)  
G.add_edge("86", "35", weight=1)  
G.add_edge("86", "51", weight=1)  
G.add_edge("86", "53", weight=1)  
G.add_edge("86", "62", weight=1)  
G.add_edge("86", "62", weight=1)  
G.add_edge("86", "69", weight=1)  
G.add_edge("86", "70", weight=1)  
G.add_edge("86", "70", weight=1)  
G.add_edge("86", "85", weight=1)  
G.add_edge("86", "87", weight=1)  
G.add_edge("86", "104", weight=1)  
G.add_edge("86", "106", weight=1)  
G.add_edge("86", "106", weight=1)  
G.add_edge("86", "107", weight=1)  
G.add_edge("86", "118", weight=1)  
G.add_edge("86", "127", weight=1)  
G.add_edge("86", "130", weight=1)  
G.add_edge("86", "132", weight=1)  
G.add_edge("86", "134", weight=1)  
G.add_edge("86", "137", weight=1)  
G.add_edge("86", "138", weight=1)  
G.add_edge("86", "161", weight=1)  
G.add_edge("86", "166", weight=1)  
G.add_edge("86", "168", weight=1)  
G.add_edge("86", "170", weight=1)  
G.add_edge("87", "1", weight=0)  
G.add_edge("87", "5", weight=0)  
G.add_edge("87", "6", weight=0)  
G.add_edge("87", "7", weight=0)  
G.add_edge("87", "8", weight=0)  
G.add_edge("87", "9", weight=0)  
G.add_edge("87", "12", weight=0)  
G.add_edge("87", "13", weight=0)  
G.add_edge("87", "16", weight=0)  
G.add_edge("87", "18", weight=0)  
G.add_edge("87", "19", weight=0)  
G.add_edge("87", "23", weight=0)  
G.add_edge("87", "26", weight=0)  
G.add_edge("87", "28", weight=0)  
G.add_edge("87", "32", weight=0)  
G.add_edge("87", "34", weight=0)  
G.add_edge("87", "39", weight=0)  
G.add_edge("87", "41", weight=0)  
G.add_edge("87", "44", weight=0)  
G.add_edge("87", "46", weight=0)  
G.add_edge("87", "48", weight=0)  
G.add_edge("87", "49", weight=0)  
G.add_edge("87", "50", weight=0)  
G.add_edge("87", "51", weight=0)  
G.add_edge("87", "52", weight=0)  
G.add_edge("87", "54", weight=0)  
G.add_edge("87", "55", weight=0)  
G.add_edge("87", "56", weight=0)  
G.add_edge("87", "57", weight=0)  
G.add_edge("87", "62", weight=0)  
G.add_edge("87", "63", weight=0)  
G.add_edge("87", "64", weight=0)  
G.add_edge("87", "68", weight=0)  
G.add_edge("87", "69", weight=0)  
G.add_edge("87", "70", weight=0)  
G.add_edge("87", "75", weight=0)  
G.add_edge("87", "86", weight=0)  
G.add_edge("87", "92", weight=0)  
G.add_edge("87", "95", weight=0)  
G.add_edge("87", "101", weight=0)  
G.add_edge("87", "103", weight=0)  
G.add_edge("87", "107", weight=0)  
G.add_edge("87", "108", weight=0)  
G.add_edge("87", "113", weight=0)  
G.add_edge("87", "114", weight=0)  
G.add_edge("87", "116", weight=0)  
G.add_edge("87", "118", weight=0)  
G.add_edge("87", "125", weight=0)  
G.add_edge("87", "126", weight=0)  
G.add_edge("87", "127", weight=0)  
G.add_edge("87", "128", weight=0)  
G.add_edge("87", "130", weight=0)  
G.add_edge("87", "131", weight=0)  
G.add_edge("87", "132", weight=0)  
G.add_edge("87", "133", weight=0)  
G.add_edge("87", "134", weight=0)  
G.add_edge("87", "138", weight=0)  
G.add_edge("87", "139", weight=0)  
G.add_edge("87", "142", weight=0)  
G.add_edge("87", "144", weight=0)  
G.add_edge("87", "147", weight=0)  
G.add_edge("87", "154", weight=0)  
G.add_edge("87", "157", weight=0)  
G.add_edge("87", "158", weight=0)  
G.add_edge("87", "161", weight=0)  
G.add_edge("87", "164", weight=0)  
G.add_edge("87", "165", weight=0)  
G.add_edge("87", "166", weight=0)  
G.add_edge("87", "168", weight=0)  
G.add_edge("87", "170", weight=0)  
G.add_edge("87", "172", weight=0)  
G.add_edge("87", "173", weight=0)  
G.add_edge("87", "175", weight=0)  
G.add_edge("87", "177", weight=0)  
G.add_edge("88", "3", weight=2100)  
G.add_edge("88", "6", weight=2100)  
G.add_edge("88", "9", weight=2100)  
G.add_edge("88", "53", weight=2100)  
G.add_edge("88", "54", weight=2100)  
G.add_edge("88", "57", weight=2100)  
G.add_edge("88", "60", weight=2100)  
G.add_edge("88", "62", weight=2100)  
G.add_edge("88", "66", weight=2100)  
G.add_edge("88", "69", weight=2100)  
G.add_edge("88", "70", weight=2100)  
G.add_edge("88", "74", weight=2100)  
G.add_edge("88", "94", weight=2100)  
G.add_edge("88", "107", weight=2100)  
G.add_edge("88", "110", weight=2100)  
G.add_edge("88", "113", weight=2100)  
G.add_edge("88", "125", weight=2100)  
G.add_edge("88", "127", weight=2100)  
G.add_edge("88", "128", weight=2100)  
G.add_edge("88", "130", weight=2100)  
G.add_edge("88", "131", weight=2100)  
G.add_edge("88", "134", weight=2100)  
G.add_edge("88", "139", weight=2100)  
G.add_edge("88", "142", weight=2100)  
G.add_edge("88", "143", weight=2100)  
G.add_edge("88", "147", weight=2100)  
G.add_edge("88", "156", weight=2100)  
G.add_edge("88", "165", weight=2100)  
G.add_edge("89", "8", weight=0)  
G.add_edge("89", "39", weight=0)  
G.add_edge("89", "57", weight=1000)  
G.add_edge("89", "58", weight=0)  
G.add_edge("89", "74", weight=0)  
G.add_edge("89", "97", weight=0)  
G.add_edge("89", "106", weight=0)  
G.add_edge("89", "106", weight=0)  
G.add_edge("89", "109", weight=0)  
G.add_edge("89", "130", weight=0)  
G.add_edge("89", "132", weight=0)  
G.add_edge("89", "142", weight=0)  
G.add_edge("89", "146", weight=0)  
G.add_edge("89", "165", weight=0)  
G.add_edge("89", "170", weight=0)  
G.add_edge("89", "176", weight=0)  
G.add_edge("90", "6", weight=0)  
G.add_edge("90", "7", weight=0)  
G.add_edge("90", "16", weight=0)  
G.add_edge("90", "39", weight=0)  
G.add_edge("90", "57", weight=0)  
G.add_edge("90", "58", weight=0)  
G.add_edge("90", "65", weight=0)  
G.add_edge("90", "65", weight=0)  
G.add_edge("90", "69", weight=0)  
G.add_edge("90", "74", weight=0)  
G.add_edge("90", "93", weight=0)  
G.add_edge("90", "100", weight=0)  
G.add_edge("90", "109", weight=0)  
G.add_edge("90", "112", weight=0)  
G.add_edge("90", "114", weight=1000)  
G.add_edge("90", "116", weight=0)  
G.add_edge("90", "125", weight=0)  
G.add_edge("90", "128", weight=0)  
G.add_edge("90", "143", weight=0)  
G.add_edge("90", "146", weight=0)  
G.add_edge("90", "161", weight=0)  
G.add_edge("91", "0", weight=1000)  
G.add_edge("91", "7", weight=1000)  
G.add_edge("91", "21", weight=1000)  
G.add_edge("91", "39", weight=1000)  
G.add_edge("91", "57", weight=0)  
G.add_edge("91", "58", weight=0)  
G.add_edge("91", "65", weight=0)  
G.add_edge("91", "69", weight=0)  
G.add_edge("91", "74", weight=0)  
G.add_edge("91", "78", weight=0)  
G.add_edge("91", "92", weight=0)  
G.add_edge("91", "94", weight=0)  
G.add_edge("91", "100", weight=0)  
G.add_edge("91", "109", weight=0)  
G.add_edge("91", "114", weight=1000)  
G.add_edge("91", "116", weight=1000)  
G.add_edge("91", "132", weight=1000)  
G.add_edge("91", "142", weight=1000)  
G.add_edge("91", "146", weight=1000)  
G.add_edge("92", "1", weight=1000)  
G.add_edge("92", "3", weight=1000)  
G.add_edge("92", "7", weight=1000)  
G.add_edge("92", "31", weight=1000)  
G.add_edge("92", "39", weight=1000)  
G.add_edge("92", "40", weight=1000)  
G.add_edge("92", "42", weight=1000)  
G.add_edge("92", "43", weight=1000)  
G.add_edge("92", "46", weight=1000)  
G.add_edge("92", "57", weight=1000)  
G.add_edge("92", "58", weight=1000)  
G.add_edge("92", "81", weight=1000)  
G.add_edge("92", "83", weight=1000)  
G.add_edge("92", "85", weight=1000)  
G.add_edge("92", "87", weight=1000)  
G.add_edge("92", "91", weight=1000)  
G.add_edge("92", "93", weight=1000)  
G.add_edge("92", "94", weight=1000)  
G.add_edge("92", "97", weight=1000)  
G.add_edge("92", "100", weight=1000)  
G.add_edge("92", "110", weight=1000)  
G.add_edge("92", "125", weight=1000)  
G.add_edge("92", "127", weight=1000)  
G.add_edge("92", "128", weight=1000)  
G.add_edge("92", "130", weight=1000)  
G.add_edge("92", "146", weight=1000)  
G.add_edge("92", "147", weight=1000)  
G.add_edge("92", "161", weight=1000)  
G.add_edge("92", "165", weight=1000)  
G.add_edge("92", "168", weight=1000)  
G.add_edge("92", "170", weight=1000)  
G.add_edge("93", "5", weight=1000)  
G.add_edge("93", "78", weight=1000)  
G.add_edge("93", "90", weight=1000)  
G.add_edge("93", "92", weight=1000)  
G.add_edge("93", "97", weight=1000)  
G.add_edge("93", "142", weight=1000)  
G.add_edge("94", "5", weight=1000)  
G.add_edge("94", "6", weight=2000)  
G.add_edge("94", "7", weight=1000)  
G.add_edge("94", "8", weight=1500)  
G.add_edge("94", "9", weight=3000)  
G.add_edge("94", "10", weight=1000)  
G.add_edge("94", "12", weight=10000)  
G.add_edge("94", "16", weight=1000)  
G.add_edge("94", "25", weight=10000)  
G.add_edge("94", "31", weight=1000)  
G.add_edge("94", "37", weight=800)  
G.add_edge("94", "38", weight=800)  
G.add_edge("94", "39", weight=800)  
G.add_edge("94", "41", weight=3000)  
G.add_edge("94", "44", weight=1000)  
G.add_edge("94", "45", weight=1000)  
G.add_edge("94", "48", weight=3000)  
G.add_edge("94", "52", weight=10000)  
G.add_edge("94", "55", weight=3000)  
G.add_edge("94", "56", weight=800)  
G.add_edge("94", "61", weight=800)  
G.add_edge("94", "61", weight=1000)  
G.add_edge("94", "62", weight=3000)  
G.add_edge("94", "63", weight=2000)  
G.add_edge("94", "66", weight=3000)  
G.add_edge("94", "70", weight=3000)  
G.add_edge("94", "70", weight=3000)  
G.add_edge("94", "70", weight=3000)  
G.add_edge("94", "74", weight=1500)  
G.add_edge("94", "76", weight=1000)  
G.add_edge("94", "78", weight=3000)  
G.add_edge("94", "79", weight=3000)  
G.add_edge("94", "83", weight=2000)  
G.add_edge("94", "85", weight=10000)  
G.add_edge("94", "88", weight=2000)  
G.add_edge("94", "91", weight=3000)  
G.add_edge("94", "92", weight=800)  
G.add_edge("94", "96", weight=3000)  
G.add_edge("94", "98", weight=3000)  
G.add_edge("94", "100", weight=5000)  
G.add_edge("94", "101", weight=3000)  
G.add_edge("94", "111", weight=800)  
G.add_edge("94", "114", weight=2000)  
G.add_edge("94", "122", weight=1500)  
G.add_edge("94", "124", weight=1500)  
G.add_edge("94", "140", weight=2000)  
G.add_edge("94", "142", weight=5000)  
G.add_edge("94", "148", weight=10000)  
G.add_edge("94", "163", weight=2000)  
G.add_edge("94", "164", weight=1000)  
G.add_edge("94", "166", weight=1000)  
G.add_edge("94", "171", weight=2000)  
G.add_edge("94", "173", weight=1500)  
G.add_edge("94", "174", weight=800)  
G.add_edge("94", "174", weight=10000)  
G.add_edge("95", "1", weight=1000)  
G.add_edge("95", "6", weight=1000)  
G.add_edge("95", "7", weight=1000)  
G.add_edge("95", "9", weight=0)  
G.add_edge("95", "21", weight=0)  
G.add_edge("95", "31", weight=0)  
G.add_edge("95", "35", weight=0)  
G.add_edge("95", "39", weight=0)  
G.add_edge("95", "40", weight=0)  
G.add_edge("95", "41", weight=1000)  
G.add_edge("95", "43", weight=0)  
G.add_edge("95", "44", weight=1000)  
G.add_edge("95", "51", weight=0)  
G.add_edge("95", "57", weight=1000)  
G.add_edge("95", "59", weight=0)  
G.add_edge("95", "61", weight=1000)  
G.add_edge("95", "62", weight=1000)  
G.add_edge("95", "63", weight=1000)  
G.add_edge("95", "64", weight=1000)  
G.add_edge("95", "68", weight=0)  
G.add_edge("95", "69", weight=1000)  
G.add_edge("95", "70", weight=1000)  
G.add_edge("95", "73", weight=1000)  
G.add_edge("95", "74", weight=1000)  
G.add_edge("95", "75", weight=1000)  
G.add_edge("95", "76", weight=1000)  
G.add_edge("95", "77", weight=0)  
G.add_edge("95", "78", weight=1000)  
G.add_edge("95", "79", weight=2000)  
G.add_edge("95", "87", weight=1000)  
G.add_edge("95", "99", weight=0)  
G.add_edge("95", "100", weight=1000)  
G.add_edge("95", "103", weight=1000)  
G.add_edge("95", "103", weight=1000)  
G.add_edge("95", "104", weight=0)  
G.add_edge("95", "107", weight=0)  
G.add_edge("95", "108", weight=1000)  
G.add_edge("95", "109", weight=1000)  
G.add_edge("95", "113", weight=1000)  
G.add_edge("95", "114", weight=0)  
G.add_edge("95", "116", weight=0)  
G.add_edge("95", "118", weight=1000)  
G.add_edge("95", "119", weight=1000)  
G.add_edge("95", "119", weight=1000)  
G.add_edge("95", "125", weight=1000)  
G.add_edge("95", "126", weight=1000)  
G.add_edge("95", "128", weight=1000)  
G.add_edge("95", "129", weight=1000)  
G.add_edge("95", "130", weight=1000)  
G.add_edge("95", "131", weight=0)  
G.add_edge("95", "132", weight=0)  
G.add_edge("95", "134", weight=1000)  
G.add_edge("95", "135", weight=1000)  
G.add_edge("95", "137", weight=1000)  
G.add_edge("95", "139", weight=0)  
G.add_edge("95", "142", weight=0)  
G.add_edge("95", "146", weight=0)  
G.add_edge("95", "147", weight=1000)  
G.add_edge("95", "154", weight=1000)  
G.add_edge("95", "156", weight=1000)  
G.add_edge("95", "161", weight=0)  
G.add_edge("95", "163", weight=1000)  
G.add_edge("95", "165", weight=0)  
G.add_edge("95", "166", weight=0)  
G.add_edge("95", "168", weight=0)  
G.add_edge("95", "171", weight=0)  
G.add_edge("95", "172", weight=0)  
G.add_edge("95", "174", weight=0)  
G.add_edge("95", "175", weight=0)  
G.add_edge("96", "0", weight=0)  
G.add_edge("96", "7", weight=1000)  
G.add_edge("96", "39", weight=1000)  
G.add_edge("96", "65", weight=0)  
G.add_edge("96", "69", weight=0)  
G.add_edge("96", "74", weight=0)  
G.add_edge("96", "78", weight=0)  
G.add_edge("96", "78", weight=0)  
G.add_edge("96", "94", weight=0)  
G.add_edge("96", "100", weight=0)  
G.add_edge("96", "132", weight=1000)  
G.add_edge("97", "2", weight=0)  
G.add_edge("97", "9", weight=0)  
G.add_edge("97", "27", weight=0)  
G.add_edge("97", "31", weight=0)  
G.add_edge("97", "34", weight=0)  
G.add_edge("97", "35", weight=0)  
G.add_edge("97", "38", weight=0)  
G.add_edge("97", "40", weight=0)  
G.add_edge("97", "42", weight=0)  
G.add_edge("97", "44", weight=0)  
G.add_edge("97", "48", weight=0)  
G.add_edge("97", "55", weight=0)  
G.add_edge("97", "57", weight=0)  
G.add_edge("97", "59", weight=0)  
G.add_edge("97", "60", weight=0)  
G.add_edge("97", "61", weight=0)  
G.add_edge("97", "62", weight=0)  
G.add_edge("97", "66", weight=0)  
G.add_edge("97", "70", weight=0)  
G.add_edge("97", "74", weight=0)  
G.add_edge("97", "77", weight=0)  
G.add_edge("97", "78", weight=0)  
G.add_edge("97", "79", weight=0)  
G.add_edge("97", "85", weight=0)  
G.add_edge("97", "89", weight=0)  
G.add_edge("97", "92", weight=0)  
G.add_edge("97", "93", weight=0)  
G.add_edge("97", "104", weight=0)  
G.add_edge("97", "109", weight=0)  
G.add_edge("97", "111", weight=0)  
G.add_edge("97", "113", weight=0)  
G.add_edge("97", "115", weight=0)  
G.add_edge("97", "125", weight=0)  
G.add_edge("97", "137", weight=0)  
G.add_edge("97", "141", weight=0)  
G.add_edge("97", "142", weight=0)  
G.add_edge("97", "143", weight=0)  
G.add_edge("97", "150", weight=0)  
G.add_edge("97", "159", weight=0)  
G.add_edge("97", "162", weight=0)  
G.add_edge("97", "167", weight=0)  
G.add_edge("97", "174", weight=0)  
G.add_edge("97", "175", weight=0)  
G.add_edge("97", "176", weight=0)  
G.add_edge("98", "6", weight=0)  
G.add_edge("98", "9", weight=0)  
G.add_edge("98", "27", weight=0)  
G.add_edge("98", "35", weight=0)  
G.add_edge("98", "35", weight=0)  
G.add_edge("98", "35", weight=0)  
G.add_edge("98", "41", weight=0)  
G.add_edge("98", "41", weight=0)  
G.add_edge("98", "47", weight=0)  
G.add_edge("98", "57", weight=0)  
G.add_edge("98", "59", weight=0)  
G.add_edge("98", "62", weight=0)  
G.add_edge("98", "62", weight=0)  
G.add_edge("98", "62", weight=0)  
G.add_edge("98", "67", weight=0)  
G.add_edge("98", "70", weight=0)  
G.add_edge("98", "70", weight=0)  
G.add_edge("98", "70", weight=0)  
G.add_edge("98", "70", weight=0)  
G.add_edge("98", "70", weight=0)  
G.add_edge("98", "94", weight=0)  
G.add_edge("98", "100", weight=0)  
G.add_edge("98", "101", weight=0)  
G.add_edge("98", "103", weight=0)  
G.add_edge("98", "109", weight=0)  
G.add_edge("98", "116", weight=0)  
G.add_edge("98", "118", weight=0)  
G.add_edge("98", "124", weight=0)  
G.add_edge("98", "127", weight=0)  
G.add_edge("98", "128", weight=0)  
G.add_edge("98", "130", weight=0)  
G.add_edge("98", "135", weight=0)  
G.add_edge("98", "166", weight=0)  
G.add_edge("98", "168", weight=0)  
G.add_edge("98", "174", weight=0)  
G.add_edge("99", "5", weight=0)  
G.add_edge("99", "6", weight=1)  
G.add_edge("99", "9", weight=0)  
G.add_edge("99", "31", weight=0)  
G.add_edge("99", "35", weight=0)  
G.add_edge("99", "37", weight=0)  
G.add_edge("99", "41", weight=0)  
G.add_edge("99", "53", weight=1)  
G.add_edge("99", "57", weight=0)  
G.add_edge("99", "61", weight=0)  
G.add_edge("99", "62", weight=1)  
G.add_edge("99", "69", weight=0)  
G.add_edge("99", "74", weight=0)  
G.add_edge("99", "80", weight=0)  
G.add_edge("99", "84", weight=1)  
G.add_edge("99", "85", weight=1)  
G.add_edge("99", "95", weight=0)  
G.add_edge("99", "100", weight=0)  
G.add_edge("99", "103", weight=0)  
G.add_edge("99", "105", weight=0)  
G.add_edge("99", "107", weight=0)  
G.add_edge("99", "109", weight=0)  
G.add_edge("99", "113", weight=0)  
G.add_edge("99", "119", weight=0)  
G.add_edge("99", "122", weight=0)  
G.add_edge("99", "125", weight=0)  
G.add_edge("99", "126", weight=0)  
G.add_edge("99", "127", weight=0)  
G.add_edge("99", "128", weight=0)  
G.add_edge("99", "129", weight=0)  
G.add_edge("99", "130", weight=0)  
G.add_edge("99", "131", weight=0)  
G.add_edge("99", "134", weight=0)  
G.add_edge("99", "138", weight=0)  
G.add_edge("99", "139", weight=0)  
G.add_edge("99", "142", weight=0)  
G.add_edge("99", "146", weight=0)  
G.add_edge("99", "147", weight=0)  
G.add_edge("99", "149", weight=0)  
G.add_edge("99", "152", weight=0)  
G.add_edge("99", "154", weight=0)  
G.add_edge("99", "163", weight=0)  
G.add_edge("99", "164", weight=0)  
G.add_edge("99", "173", weight=0)  
G.add_edge("99", "174", weight=1)  
G.add_edge("100", "0", weight=1000)  
G.add_edge("100", "1", weight=1000)  
G.add_edge("100", "4", weight=1000)  
G.add_edge("100", "4", weight=1000)  
G.add_edge("100", "5", weight=1000)  
G.add_edge("100", "6", weight=1000)  
G.add_edge("100", "7", weight=1000)  
G.add_edge("100", "9", weight=1000)  
G.add_edge("100", "11", weight=1000)  
G.add_edge("100", "14", weight=1000)  
G.add_edge("100", "20", weight=1000)  
G.add_edge("100", "27", weight=1000)  
G.add_edge("100", "31", weight=1000)  
G.add_edge("100", "34", weight=1000)  
G.add_edge("100", "35", weight=1000)  
G.add_edge("100", "37", weight=1000)  
G.add_edge("100", "39", weight=1000)  
G.add_edge("100", "40", weight=1000)  
G.add_edge("100", "41", weight=1000)  
G.add_edge("100", "42", weight=1000)  
G.add_edge("100", "44", weight=1000)  
G.add_edge("100", "45", weight=1000)  
G.add_edge("100", "46", weight=1000)  
G.add_edge("100", "48", weight=1000)  
G.add_edge("100", "49", weight=1000)  
G.add_edge("100", "49", weight=1000)  
G.add_edge("100", "50", weight=1000)  
G.add_edge("100", "55", weight=1000)  
G.add_edge("100", "56", weight=1000)  
G.add_edge("100", "57", weight=1000)  
G.add_edge("100", "59", weight=1000)  
G.add_edge("100", "60", weight=1000)  
G.add_edge("100", "60", weight=1000)  
G.add_edge("100", "62", weight=1000)  
G.add_edge("100", "62", weight=1000)  
G.add_edge("100", "62", weight=1000)  
G.add_edge("100", "62", weight=1000)  
G.add_edge("100", "62", weight=1000)  
G.add_edge("100", "62", weight=1000)  
G.add_edge("100", "63", weight=1000)  
G.add_edge("100", "64", weight=1000)  
G.add_edge("100", "66", weight=1000)  
G.add_edge("100", "67", weight=1000)  
G.add_edge("100", "69", weight=1000)  
G.add_edge("100", "70", weight=1000)  
G.add_edge("100", "70", weight=1000)  
G.add_edge("100", "70", weight=1000)  
G.add_edge("100", "70", weight=1000)  
G.add_edge("100", "71", weight=1000)  
G.add_edge("100", "76", weight=1000)  
G.add_edge("100", "77", weight=1000)  
G.add_edge("100", "78", weight=1000)  
G.add_edge("100", "79", weight=1000)  
G.add_edge("100", "79", weight=1000)  
G.add_edge("100", "79", weight=1000)  
G.add_edge("100", "80", weight=1000)  
G.add_edge("100", "83", weight=1000)  
G.add_edge("100", "84", weight=1000)  
G.add_edge("100", "85", weight=1000)  
G.add_edge("100", "85", weight=1000)  
G.add_edge("100", "90", weight=1000)  
G.add_edge("100", "91", weight=1000)  
G.add_edge("100", "92", weight=1000)  
G.add_edge("100", "94", weight=1000)  
G.add_edge("100", "95", weight=1000)  
G.add_edge("100", "96", weight=1000)  
G.add_edge("100", "98", weight=1000)  
G.add_edge("100", "99", weight=1000)  
G.add_edge("100", "101", weight=1000)  
G.add_edge("100", "103", weight=1000)  
G.add_edge("100", "104", weight=1000)  
G.add_edge("100", "105", weight=1000)  
G.add_edge("100", "107", weight=1000)  
G.add_edge("100", "108", weight=1000)  
G.add_edge("100", "109", weight=1000)  
G.add_edge("100", "112", weight=1000)  
G.add_edge("100", "113", weight=1000)  
G.add_edge("100", "122", weight=1000)  
G.add_edge("100", "125", weight=1000)  
G.add_edge("100", "127", weight=1000)  
G.add_edge("100", "128", weight=1000)  
G.add_edge("100", "129", weight=1000)  
G.add_edge("100", "130", weight=1000)  
G.add_edge("100", "138", weight=1000)  
G.add_edge("100", "139", weight=1000)  
G.add_edge("100", "141", weight=1000)  
G.add_edge("100", "146", weight=1000)  
G.add_edge("100", "155", weight=1000)  
G.add_edge("100", "159", weight=1000)  
G.add_edge("100", "166", weight=1000)  
G.add_edge("100", "168", weight=1000)  
G.add_edge("100", "172", weight=1000)  
G.add_edge("100", "174", weight=1000)  
G.add_edge("101", "3", weight=0)  
G.add_edge("101", "6", weight=0)  
G.add_edge("101", "6", weight=0)  
G.add_edge("101", "9", weight=0)  
G.add_edge("101", "9", weight=0)  
G.add_edge("101", "10", weight=0)  
G.add_edge("101", "17", weight=0)  
G.add_edge("101", "19", weight=0)  
G.add_edge("101", "41", weight=0)  
G.add_edge("101", "51", weight=0)  
G.add_edge("101", "51", weight=0)  
G.add_edge("101", "59", weight=0)  
G.add_edge("101", "62", weight=0)  
G.add_edge("101", "62", weight=0)  
G.add_edge("101", "62", weight=0)  
G.add_edge("101", "62", weight=0)  
G.add_edge("101", "64", weight=0)  
G.add_edge("101", "64", weight=0)  
G.add_edge("101", "69", weight=0)  
G.add_edge("101", "69", weight=0)  
G.add_edge("101", "70", weight=0)  
G.add_edge("101", "70", weight=0)  
G.add_edge("101", "79", weight=0)  
G.add_edge("101", "83", weight=0)  
G.add_edge("101", "84", weight=0)  
G.add_edge("101", "85", weight=0)  
G.add_edge("101", "85", weight=0)  
G.add_edge("101", "87", weight=0)  
G.add_edge("101", "94", weight=0)  
G.add_edge("101", "98", weight=0)  
G.add_edge("101", "100", weight=0)  
G.add_edge("101", "103", weight=0)  
G.add_edge("101", "109", weight=0)  
G.add_edge("101", "113", weight=0)  
G.add_edge("101", "116", weight=0)  
G.add_edge("101", "119", weight=0)  
G.add_edge("101", "126", weight=0)  
G.add_edge("101", "127", weight=0)  
G.add_edge("101", "130", weight=0)  
G.add_edge("101", "144", weight=0)  
G.add_edge("101", "145", weight=0)  
G.add_edge("101", "151", weight=0)  
G.add_edge("101", "166", weight=0)  
G.add_edge("101", "168", weight=0)  
G.add_edge("101", "171", weight=0)  
G.add_edge("101", "174", weight=0)  
G.add_edge("102", "1", weight=0)  
G.add_edge("102", "44", weight=0)  
G.add_edge("102", "46", weight=5000000)  
G.add_edge("102", "48", weight=0)  
G.add_edge("102", "49", weight=5000000)  
G.add_edge("102", "57", weight=990)  
G.add_edge("102", "59", weight=990)  
G.add_edge("102", "64", weight=990)  
G.add_edge("102", "69", weight=990)  
G.add_edge("102", "72", weight=0)  
G.add_edge("102", "79", weight=5000000)  
G.add_edge("102", "80", weight=5000000)  
G.add_edge("102", "83", weight=990)  
G.add_edge("102", "84", weight=0)  
G.add_edge("102", "105", weight=1000)  
G.add_edge("102", "107", weight=990)  
G.add_edge("102", "111", weight=0)  
G.add_edge("102", "112", weight=990)  
G.add_edge("102", "113", weight=990)  
G.add_edge("102", "118", weight=0)  
G.add_edge("102", "119", weight=990)  
G.add_edge("102", "122", weight=990)  
G.add_edge("102", "128", weight=0)  
G.add_edge("102", "139", weight=990)  
G.add_edge("102", "142", weight=990)  
G.add_edge("102", "145", weight=990)  
G.add_edge("102", "147", weight=990)  
G.add_edge("102", "148", weight=990)  
G.add_edge("102", "149", weight=990)  
G.add_edge("102", "152", weight=990)  
G.add_edge("102", "156", weight=990)  
G.add_edge("102", "157", weight=1000)  
G.add_edge("102", "158", weight=0)  
G.add_edge("102", "160", weight=990)  
G.add_edge("102", "163", weight=990)  
G.add_edge("102", "164", weight=990)  
G.add_edge("102", "170", weight=0)  
G.add_edge("102", "171", weight=990)  
G.add_edge("102", "172", weight=5000000)  
G.add_edge("102", "173", weight=990)  
G.add_edge("102", "175", weight=0)  
G.add_edge("103", "1", weight=1000)  
G.add_edge("103", "4", weight=1000)  
G.add_edge("103", "4", weight=1000)  
G.add_edge("103", "5", weight=1000)  
G.add_edge("103", "9", weight=1000)  
G.add_edge("103", "11", weight=1000)  
G.add_edge("103", "35", weight=1000)  
G.add_edge("103", "41", weight=1000)  
G.add_edge("103", "42", weight=1000)  
G.add_edge("103", "44", weight=1000)  
G.add_edge("103", "45", weight=1000)  
G.add_edge("103", "47", weight=1000)  
G.add_edge("103", "48", weight=1000)  
G.add_edge("103", "51", weight=1000)  
G.add_edge("103", "53", weight=1000)  
G.add_edge("103", "54", weight=1000)  
G.add_edge("103", "57", weight=1000)  
G.add_edge("103", "59", weight=1000)  
G.add_edge("103", "62", weight=1000)  
G.add_edge("103", "64", weight=1000)  
G.add_edge("103", "67", weight=1000)  
G.add_edge("103", "68", weight=1000)  
G.add_edge("103", "69", weight=1000)  
G.add_edge("103", "70", weight=1000)  
G.add_edge("103", "70", weight=1000)  
G.add_edge("103", "71", weight=1000)  
G.add_edge("103", "73", weight=1000)  
G.add_edge("103", "74", weight=1000)  
G.add_edge("103", "75", weight=1000)  
G.add_edge("103", "76", weight=1000)  
G.add_edge("103", "78", weight=1000)  
G.add_edge("103", "79", weight=1000)  
G.add_edge("103", "82", weight=1000)  
G.add_edge("103", "84", weight=1000)  
G.add_edge("103", "85", weight=1000)  
G.add_edge("103", "87", weight=1000)  
G.add_edge("103", "95", weight=1000)  
G.add_edge("103", "95", weight=1000)  
G.add_edge("103", "98", weight=1000)  
G.add_edge("103", "99", weight=1000)  
G.add_edge("103", "100", weight=1000)  
G.add_edge("103", "101", weight=1000)  
G.add_edge("103", "107", weight=1000)  
G.add_edge("103", "112", weight=1000)  
G.add_edge("103", "113", weight=1000)  
G.add_edge("103", "114", weight=1000)  
G.add_edge("103", "115", weight=1000)  
G.add_edge("103", "122", weight=1000)  
G.add_edge("103", "123", weight=1000)  
G.add_edge("103", "124", weight=1000)  
G.add_edge("103", "125", weight=1000)  
G.add_edge("103", "126", weight=1000)  
G.add_edge("103", "127", weight=1000)  
G.add_edge("103", "128", weight=1000)  
G.add_edge("103", "129", weight=1000)  
G.add_edge("103", "130", weight=1000)  
G.add_edge("103", "131", weight=1000)  
G.add_edge("103", "131", weight=1000)  
G.add_edge("103", "132", weight=1000)  
G.add_edge("103", "133", weight=1000)  
G.add_edge("103", "134", weight=1000)  
G.add_edge("103", "137", weight=1000)  
G.add_edge("103", "139", weight=1000)  
G.add_edge("103", "141", weight=1000)  
G.add_edge("103", "142", weight=1000)  
G.add_edge("103", "144", weight=1000)  
G.add_edge("103", "147", weight=1000)  
G.add_edge("103", "152", weight=1000)  
G.add_edge("103", "155", weight=1000)  
G.add_edge("103", "161", weight=1000)  
G.add_edge("103", "164", weight=1000)  
G.add_edge("103", "165", weight=1000)  
G.add_edge("103", "166", weight=1000)  
G.add_edge("103", "168", weight=1000)  
G.add_edge("103", "172", weight=1000)  
G.add_edge("103", "174", weight=1000)  
G.add_edge("103", "174", weight=1000)  
G.add_edge("104", "6", weight=1000)  
G.add_edge("104", "6", weight=1000)  
G.add_edge("104", "9", weight=1000)  
G.add_edge("104", "16", weight=1000)  
G.add_edge("104", "35", weight=1000)  
G.add_edge("104", "39", weight=1000)  
G.add_edge("104", "40", weight=1000)  
G.add_edge("104", "41", weight=1000)  
G.add_edge("104", "41", weight=1000)  
G.add_edge("104", "44", weight=1000)  
G.add_edge("104", "47", weight=1000)  
G.add_edge("104", "57", weight=1000)  
G.add_edge("104", "59", weight=1000)  
G.add_edge("104", "60", weight=1000)  
G.add_edge("104", "60", weight=1000)  
G.add_edge("104", "62", weight=1000)  
G.add_edge("104", "62", weight=1000)  
G.add_edge("104", "62", weight=1000)  
G.add_edge("104", "62", weight=1000)  
G.add_edge("104", "62", weight=1000)  
G.add_edge("104", "69", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "70", weight=1000)  
G.add_edge("104", "73", weight=1000)  
G.add_edge("104", "84", weight=1000)  
G.add_edge("104", "85", weight=1000)  
G.add_edge("104", "86", weight=1000)  
G.add_edge("104", "95", weight=1000)  
G.add_edge("104", "97", weight=1000)  
G.add_edge("104", "100", weight=1000)  
G.add_edge("104", "105", weight=1000)  
G.add_edge("104", "107", weight=1000)  
G.add_edge("104", "108", weight=1000)  
G.add_edge("104", "120", weight=1000)  
G.add_edge("104", "122", weight=1000)  
G.add_edge("104", "125", weight=1000)  
G.add_edge("104", "128", weight=1000)  
G.add_edge("104", "135", weight=1000)  
G.add_edge("104", "137", weight=1000)  
G.add_edge("104", "142", weight=1000)  
G.add_edge("104", "146", weight=1000)  
G.add_edge("104", "154", weight=1000)  
G.add_edge("104", "156", weight=1000)  
G.add_edge("104", "163", weight=1000)  
G.add_edge("104", "165", weight=1000)  
G.add_edge("104", "166", weight=1000)  
G.add_edge("104", "174", weight=1000)  
G.add_edge("104", "175", weight=1000)  
G.add_edge("105", "6", weight=0)  
G.add_edge("105", "9", weight=0)  
G.add_edge("105", "12", weight=0)  
G.add_edge("105", "32", weight=0)  
G.add_edge("105", "48", weight=0)  
G.add_edge("105", "57", weight=0)  
G.add_edge("105", "62", weight=0)  
G.add_edge("105", "63", weight=1000)  
G.add_edge("105", "64", weight=1000)  
G.add_edge("105", "64", weight=1000)  
G.add_edge("105", "69", weight=0)  
G.add_edge("105", "70", weight=0)  
G.add_edge("105", "79", weight=0)  
G.add_edge("105", "83", weight=1000)  
G.add_edge("105", "85", weight=0)  
G.add_edge("105", "99", weight=1)  
G.add_edge("105", "100", weight=1000)  
G.add_edge("105", "102", weight=1)  
G.add_edge("105", "104", weight=0)  
G.add_edge("105", "107", weight=0)  
G.add_edge("105", "109", weight=1000)  
G.add_edge("105", "113", weight=0)  
G.add_edge("105", "114", weight=1)  
G.add_edge("105", "116", weight=1000)  
G.add_edge("105", "119", weight=0)  
G.add_edge("105", "122", weight=1000)  
G.add_edge("105", "124", weight=1000)  
G.add_edge("105", "125", weight=1000)  
G.add_edge("105", "126", weight=0)  
G.add_edge("105", "128", weight=1)  
G.add_edge("105", "130", weight=0)  
G.add_edge("105", "134", weight=0)  
G.add_edge("105", "140", weight=0)  
G.add_edge("105", "142", weight=1000)  
G.add_edge("105", "143", weight=1000)  
G.add_edge("105", "147", weight=1000)  
G.add_edge("105", "168", weight=1000)  
G.add_edge("105", "174", weight=1000)  
G.add_edge("106", "8", weight=1000)  
G.add_edge("106", "40", weight=1000)  
G.add_edge("106", "41", weight=1000)  
G.add_edge("106", "41", weight=1000)  
G.add_edge("106", "54", weight=1000)  
G.add_edge("106", "58", weight=1000)  
G.add_edge("106", "74", weight=1000)  
G.add_edge("106", "83", weight=1000)  
G.add_edge("106", "86", weight=1000)  
G.add_edge("106", "86", weight=1000)  
G.add_edge("106", "89", weight=1000)  
G.add_edge("106", "89", weight=1000)  
G.add_edge("106", "142", weight=1000)  
G.add_edge("106", "161", weight=1000)  
G.add_edge("107", "1", weight=0)  
G.add_edge("107", "4", weight=0)  
G.add_edge("107", "6", weight=0)  
G.add_edge("107", "9", weight=0)  
G.add_edge("107", "12", weight=0)  
G.add_edge("107", "17", weight=0)  
G.add_edge("107", "18", weight=0)  
G.add_edge("107", "23", weight=0)  
G.add_edge("107", "29", weight=0)  
G.add_edge("107", "34", weight=0)  
G.add_edge("107", "37", weight=0)  
G.add_edge("107", "40", weight=0)  
G.add_edge("107", "41", weight=0)  
G.add_edge("107", "44", weight=0)  
G.add_edge("107", "46", weight=0)  
G.add_edge("107", "48", weight=0)  
G.add_edge("107", "50", weight=0)  
G.add_edge("107", "55", weight=0)  
G.add_edge("107", "57", weight=0)  
G.add_edge("107", "59", weight=0)  
G.add_edge("107", "60", weight=0)  
G.add_edge("107", "62", weight=0)  
G.add_edge("107", "63", weight=0)  
G.add_edge("107", "64", weight=0)  
G.add_edge("107", "66", weight=0)  
G.add_edge("107", "67", weight=0)  
G.add_edge("107", "68", weight=0)  
G.add_edge("107", "69", weight=0)  
G.add_edge("107", "70", weight=0)  
G.add_edge("107", "75", weight=0)  
G.add_edge("107", "79", weight=0)  
G.add_edge("107", "80", weight=0)  
G.add_edge("107", "84", weight=0)  
G.add_edge("107", "85", weight=0)  
G.add_edge("107", "86", weight=0)  
G.add_edge("107", "87", weight=0)  
G.add_edge("107", "88", weight=0)  
G.add_edge("107", "95", weight=0)  
G.add_edge("107", "99", weight=0)  
G.add_edge("107", "100", weight=0)  
G.add_edge("107", "102", weight=0)  
G.add_edge("107", "103", weight=0)  
G.add_edge("107", "104", weight=0)  
G.add_edge("107", "105", weight=0)  
G.add_edge("107", "109", weight=0)  
G.add_edge("107", "111", weight=0)  
G.add_edge("107", "112", weight=0)  
G.add_edge("107", "113", weight=0)  
G.add_edge("107", "116", weight=0)  
G.add_edge("107", "118", weight=0)  
G.add_edge("107", "122", weight=0)  
G.add_edge("107", "123", weight=0)  
G.add_edge("107", "124", weight=0)  
G.add_edge("107", "125", weight=0)  
G.add_edge("107", "127", weight=0)  
G.add_edge("107", "128", weight=0)  
G.add_edge("107", "130", weight=0)  
G.add_edge("107", "132", weight=0)  
G.add_edge("107", "133", weight=0)  
G.add_edge("107", "134", weight=0)  
G.add_edge("107", "135", weight=0)  
G.add_edge("107", "136", weight=0)  
G.add_edge("107", "137", weight=0)  
G.add_edge("107", "138", weight=0)  
G.add_edge("107", "139", weight=0)  
G.add_edge("107", "140", weight=0)  
G.add_edge("107", "142", weight=0)  
G.add_edge("107", "144", weight=0)  
G.add_edge("107", "145", weight=0)  
G.add_edge("107", "146", weight=0)  
G.add_edge("107", "147", weight=0)  
G.add_edge("107", "148", weight=0)  
G.add_edge("107", "149", weight=0)  
G.add_edge("107", "151", weight=0)  
G.add_edge("107", "152", weight=0)  
G.add_edge("107", "153", weight=0)  
G.add_edge("107", "154", weight=0)  
G.add_edge("107", "155", weight=0)  
G.add_edge("107", "156", weight=0)  
G.add_edge("107", "157", weight=0)  
G.add_edge("107", "158", weight=0)  
G.add_edge("107", "160", weight=0)  
G.add_edge("107", "160", weight=0)  
G.add_edge("107", "163", weight=0)  
G.add_edge("107", "164", weight=0)  
G.add_edge("107", "165", weight=0)  
G.add_edge("107", "166", weight=0)  
G.add_edge("107", "168", weight=0)  
G.add_edge("107", "170", weight=0)  
G.add_edge("107", "171", weight=0)  
G.add_edge("107", "172", weight=0)  
G.add_edge("107", "173", weight=0)  
G.add_edge("107", "174", weight=0)  
G.add_edge("107", "175", weight=0)  
G.add_edge("108", "1", weight=1000)  
G.add_edge("108", "1", weight=1000)  
G.add_edge("108", "1", weight=1000)  
G.add_edge("108", "1", weight=1000)  
G.add_edge("108", "4", weight=1000)  
G.add_edge("108", "4", weight=1000)  
G.add_edge("108", "6", weight=1000)  
G.add_edge("108", "9", weight=1000)  
G.add_edge("108", "35", weight=1000)  
G.add_edge("108", "40", weight=1000)  
G.add_edge("108", "40", weight=1000)  
G.add_edge("108", "41", weight=1000)  
G.add_edge("108", "41", weight=1000)  
G.add_edge("108", "45", weight=1000)  
G.add_edge("108", "45", weight=1000)  
G.add_edge("108", "46", weight=1000)  
G.add_edge("108", "46", weight=1000)  
G.add_edge("108", "47", weight=1000)  
G.add_edge("108", "48", weight=1000)  
G.add_edge("108", "55", weight=1000)  
G.add_edge("108", "57", weight=1000)  
G.add_edge("108", "59", weight=1000)  
G.add_edge("108", "59", weight=1000)  
G.add_edge("108", "62", weight=1000)  
G.add_edge("108", "66", weight=1000)  
G.add_edge("108", "70", weight=1000)  
G.add_edge("108", "75", weight=1000)  
G.add_edge("108", "75", weight=1000)  
G.add_edge("108", "76", weight=1000)  
G.add_edge("108", "79", weight=1000)  
G.add_edge("108", "79", weight=1000)  
G.add_edge("108", "83", weight=1000)  
G.add_edge("108", "84", weight=1000)  
G.add_edge("108", "85", weight=1000)  
G.add_edge("108", "87", weight=1000)  
G.add_edge("108", "95", weight=1000)  
G.add_edge("108", "100", weight=1000)  
G.add_edge("108", "104", weight=1000)  
G.add_edge("108", "111", weight=1000)  
G.add_edge("108", "111", weight=1000)  
G.add_edge("108", "112", weight=1000)  
G.add_edge("108", "113", weight=1000)  
G.add_edge("108", "116", weight=1000)  
G.add_edge("108", "119", weight=1000)  
G.add_edge("108", "123", weight=1000)  
G.add_edge("108", "128", weight=1000)  
G.add_edge("108", "129", weight=1000)  
G.add_edge("108", "130", weight=1000)  
G.add_edge("108", "131", weight=1000)  
G.add_edge("108", "142", weight=1000)  
G.add_edge("108", "146", weight=1000)  
G.add_edge("108", "153", weight=1000)  
G.add_edge("108", "156", weight=1000)  
G.add_edge("108", "166", weight=1000)  
G.add_edge("108", "170", weight=1000)  
G.add_edge("108", "172", weight=1000)  
G.add_edge("109", "0", weight=100)  
G.add_edge("109", "1", weight=100)  
G.add_edge("109", "6", weight=10000)  
G.add_edge("109", "24", weight=10000)  
G.add_edge("109", "27", weight=10000)  
G.add_edge("109", "31", weight=100)  
G.add_edge("109", "40", weight=100)  
G.add_edge("109", "53", weight=10000)  
G.add_edge("109", "53", weight=10000)  
G.add_edge("109", "57", weight=100)  
G.add_edge("109", "61", weight=100)  
G.add_edge("109", "62", weight=10000)  
G.add_edge("109", "64", weight=100)  
G.add_edge("109", "69", weight=100)  
G.add_edge("109", "70", weight=10000)  
G.add_edge("109", "74", weight=100)  
G.add_edge("109", "77", weight=100)  
G.add_edge("109", "81", weight=100)  
G.add_edge("109", "85", weight=10000)  
G.add_edge("109", "89", weight=100)  
G.add_edge("109", "90", weight=100)  
G.add_edge("109", "91", weight=100)  
G.add_edge("109", "95", weight=100)  
G.add_edge("109", "97", weight=100)  
G.add_edge("109", "98", weight=100)  
G.add_edge("109", "99", weight=100)  
G.add_edge("109", "100", weight=100)  
G.add_edge("109", "101", weight=100)  
G.add_edge("109", "105", weight=100)  
G.add_edge("109", "107", weight=100)  
G.add_edge("109", "113", weight=100)  
G.add_edge("109", "114", weight=100)  
G.add_edge("109", "116", weight=100)  
G.add_edge("109", "118", weight=100)  
G.add_edge("109", "119", weight=100)  
G.add_edge("109", "137", weight=100)  
G.add_edge("109", "142", weight=100)  
G.add_edge("109", "143", weight=10000)  
G.add_edge("109", "174", weight=100)  
G.add_edge("109", "174", weight=10000)  
G.add_edge("110", "1", weight=449)  
G.add_edge("110", "6", weight=2000)  
G.add_edge("110", "6", weight=4000)  
G.add_edge("110", "9", weight=2000)  
G.add_edge("110", "17", weight=1000)  
G.add_edge("110", "39", weight=449)  
G.add_edge("110", "40", weight=4000)  
G.add_edge("110", "44", weight=1000)  
G.add_edge("110", "48", weight=449)  
G.add_edge("110", "50", weight=449)  
G.add_edge("110", "50", weight=449)  
G.add_edge("110", "50", weight=449)  
G.add_edge("110", "51", weight=1000)  
G.add_edge("110", "52", weight=1000)  
G.add_edge("110", "52", weight=1000)  
G.add_edge("110", "53", weight=1000)  
G.add_edge("110", "53", weight=1000)  
G.add_edge("110", "53", weight=1000)  
G.add_edge("110", "53", weight=1000)  
G.add_edge("110", "57", weight=449)  
G.add_edge("110", "59", weight=449)  
G.add_edge("110", "62", weight=1000)  
G.add_edge("110", "62", weight=1000)  
G.add_edge("110", "66", weight=449)  
G.add_edge("110", "69", weight=449)  
G.add_edge("110", "74", weight=1000)  
G.add_edge("110", "79", weight=2000)  
G.add_edge("110", "85", weight=2000)  
G.add_edge("110", "88", weight=449)  
G.add_edge("110", "92", weight=2000)  
G.add_edge("110", "111", weight=449)  
G.add_edge("110", "113", weight=2000)  
G.add_edge("110", "123", weight=449)  
G.add_edge("110", "130", weight=449)  
G.add_edge("110", "138", weight=449)  
G.add_edge("110", "142", weight=1000)  
G.add_edge("110", "153", weight=2000)  
G.add_edge("110", "168", weight=1000)  
G.add_edge("110", "171", weight=1000)  
G.add_edge("110", "175", weight=449)  
G.add_edge("111", "4", weight=1000)  
G.add_edge("111", "6", weight=1000)  
G.add_edge("111", "40", weight=1000)  
G.add_edge("111", "41", weight=1000)  
G.add_edge("111", "43", weight=1000)  
G.add_edge("111", "44", weight=1000)  
G.add_edge("111", "49", weight=1000)  
G.add_edge("111", "57", weight=1000)  
G.add_edge("111", "59", weight=1000)  
G.add_edge("111", "64", weight=1000)  
G.add_edge("111", "69", weight=1000)  
G.add_edge("111", "73", weight=1000)  
G.add_edge("111", "73", weight=1000)  
G.add_edge("111", "94", weight=1000)  
G.add_edge("111", "97", weight=1000)  
G.add_edge("111", "102", weight=1000)  
G.add_edge("111", "107", weight=1000)  
G.add_edge("111", "108", weight=1000)  
G.add_edge("111", "108", weight=1000)  
G.add_edge("111", "110", weight=1000)  
G.add_edge("111", "113", weight=1000)  
G.add_edge("111", "118", weight=1000)  
G.add_edge("111", "119", weight=1000)  
G.add_edge("111", "123", weight=1000)  
G.add_edge("111", "124", weight=1000)  
G.add_edge("111", "126", weight=1000)  
G.add_edge("111", "127", weight=1000)  
G.add_edge("111", "130", weight=1000)  
G.add_edge("111", "132", weight=1000)  
G.add_edge("111", "136", weight=1000)  
G.add_edge("111", "137", weight=1000)  
G.add_edge("111", "138", weight=1000)  
G.add_edge("111", "140", weight=1000)  
G.add_edge("111", "142", weight=1000)  
G.add_edge("111", "146", weight=1000)  
G.add_edge("111", "157", weight=1000)  
G.add_edge("111", "163", weight=1000)  
G.add_edge("111", "165", weight=1000)  
G.add_edge("111", "166", weight=1000)  
G.add_edge("111", "168", weight=1000)  
G.add_edge("111", "171", weight=1000)  
G.add_edge("111", "172", weight=1000)  
G.add_edge("111", "174", weight=1000)  
G.add_edge("111", "175", weight=1000)  
G.add_edge("112", "2", weight=1000)  
G.add_edge("112", "6", weight=1000)  
G.add_edge("112", "9", weight=1000)  
G.add_edge("112", "17", weight=1000)  
G.add_edge("112", "18", weight=1000)  
G.add_edge("112", "63", weight=1000)  
G.add_edge("112", "64", weight=1000)  
G.add_edge("112", "85", weight=1000)  
G.add_edge("112", "90", weight=1000)  
G.add_edge("112", "100", weight=1000)  
G.add_edge("112", "102", weight=1000)  
G.add_edge("112", "103", weight=1000)  
G.add_edge("112", "107", weight=1000)  
G.add_edge("112", "108", weight=1000)  
G.add_edge("112", "113", weight=1000)  
G.add_edge("112", "116", weight=1000)  
G.add_edge("112", "122", weight=1000)  
G.add_edge("112", "124", weight=1000)  
G.add_edge("112", "125", weight=1000)  
G.add_edge("112", "126", weight=1000)  
G.add_edge("112", "137", weight=1000)  
G.add_edge("112", "139", weight=1000)  
G.add_edge("112", "142", weight=1000)  
G.add_edge("112", "146", weight=1000)  
G.add_edge("112", "149", weight=1000)  
G.add_edge("112", "151", weight=1000)  
G.add_edge("112", "154", weight=1000)  
G.add_edge("112", "156", weight=1000)  
G.add_edge("112", "160", weight=1000)  
G.add_edge("112", "163", weight=1000)  
G.add_edge("112", "164", weight=1000)  
G.add_edge("112", "171", weight=1000)  
G.add_edge("112", "172", weight=1000)  
G.add_edge("113", "1", weight=0)  
G.add_edge("113", "6", weight=0)  
G.add_edge("113", "8", weight=0)  
G.add_edge("113", "9", weight=0)  
G.add_edge("113", "14", weight=0)  
G.add_edge("113", "39", weight=0)  
G.add_edge("113", "40", weight=0)  
G.add_edge("113", "41", weight=0)  
G.add_edge("113", "44", weight=0)  
G.add_edge("113", "46", weight=0)  
G.add_edge("113", "48", weight=0)  
G.add_edge("113", "55", weight=0)  
G.add_edge("113", "57", weight=0)  
G.add_edge("113", "62", weight=0)  
G.add_edge("113", "63", weight=0)  
G.add_edge("113", "64", weight=0)  
G.add_edge("113", "66", weight=0)  
G.add_edge("113", "69", weight=0)  
G.add_edge("113", "70", weight=0)  
G.add_edge("113", "74", weight=0)  
G.add_edge("113", "76", weight=0)  
G.add_edge("113", "77", weight=0)  
G.add_edge("113", "79", weight=0)  
G.add_edge("113", "80", weight=0)  
G.add_edge("113", "84", weight=0)  
G.add_edge("113", "85", weight=0)  
G.add_edge("113", "87", weight=0)  
G.add_edge("113", "88", weight=0)  
G.add_edge("113", "95", weight=0)  
G.add_edge("113", "97", weight=0)  
G.add_edge("113", "99", weight=0)  
G.add_edge("113", "100", weight=0)  
G.add_edge("113", "101", weight=0)  
G.add_edge("113", "102", weight=0)  
G.add_edge("113", "103", weight=0)  
G.add_edge("113", "105", weight=0)  
G.add_edge("113", "107", weight=0)  
G.add_edge("113", "108", weight=0)  
G.add_edge("113", "109", weight=0)  
G.add_edge("113", "110", weight=0)  
G.add_edge("113", "111", weight=0)  
G.add_edge("113", "112", weight=0)  
G.add_edge("113", "116", weight=0)  
G.add_edge("113", "118", weight=0)  
G.add_edge("113", "119", weight=0)  
G.add_edge("113", "120", weight=0)  
G.add_edge("113", "122", weight=0)  
G.add_edge("113", "125", weight=0)  
G.add_edge("113", "126", weight=0)  
G.add_edge("113", "127", weight=0)  
G.add_edge("113", "128", weight=0)  
G.add_edge("113", "129", weight=0)  
G.add_edge("113", "130", weight=0)  
G.add_edge("113", "132", weight=0)  
G.add_edge("113", "133", weight=0)  
G.add_edge("113", "134", weight=0)  
G.add_edge("113", "136", weight=0)  
G.add_edge("113", "137", weight=0)  
G.add_edge("113", "138", weight=0)  
G.add_edge("113", "142", weight=0)  
G.add_edge("113", "143", weight=0)  
G.add_edge("113", "144", weight=0)  
G.add_edge("113", "145", weight=0)  
G.add_edge("113", "146", weight=0)  
G.add_edge("113", "147", weight=0)  
G.add_edge("113", "149", weight=0)  
G.add_edge("113", "151", weight=0)  
G.add_edge("113", "154", weight=0)  
G.add_edge("113", "155", weight=0)  
G.add_edge("113", "156", weight=0)  
G.add_edge("113", "157", weight=0)  
G.add_edge("113", "163", weight=0)  
G.add_edge("113", "164", weight=0)  
G.add_edge("113", "166", weight=0)  
G.add_edge("113", "170", weight=0)  
G.add_edge("113", "174", weight=0)  
G.add_edge("113", "174", weight=0)  
G.add_edge("113", "175", weight=0)  
G.add_edge("113", "176", weight=0)  
G.add_edge("114", "1", weight=1000)  
G.add_edge("114", "2", weight=1000)  
G.add_edge("114", "6", weight=10000)  
G.add_edge("114", "7", weight=1000)  
G.add_edge("114", "8", weight=1000)  
G.add_edge("114", "9", weight=1000)  
G.add_edge("114", "21", weight=1000)  
G.add_edge("114", "31", weight=500)  
G.add_edge("114", "35", weight=1000)  
G.add_edge("114", "38", weight=500)  
G.add_edge("114", "40", weight=500)  
G.add_edge("114", "41", weight=10000)  
G.add_edge("114", "44", weight=1000)  
G.add_edge("114", "57", weight=1000)  
G.add_edge("114", "63", weight=1000)  
G.add_edge("114", "64", weight=1000)  
G.add_edge("114", "69", weight=1000)  
G.add_edge("114", "70", weight=10000)  
G.add_edge("114", "77", weight=500)  
G.add_edge("114", "78", weight=500)  
G.add_edge("114", "79", weight=10000)  
G.add_edge("114", "81", weight=500)  
G.add_edge("114", "85", weight=10000)  
G.add_edge("114", "87", weight=1000)  
G.add_edge("114", "90", weight=500)  
G.add_edge("114", "91", weight=500)  
G.add_edge("114", "94", weight=1000)  
G.add_edge("114", "95", weight=1000)  
G.add_edge("114", "103", weight=1000)  
G.add_edge("114", "105", weight=500)  
G.add_edge("114", "109", weight=1000)  
G.add_edge("114", "115", weight=500)  
G.add_edge("114", "116", weight=1000)  
G.add_edge("114", "122", weight=10000)  
G.add_edge("114", "124", weight=1000)  
G.add_edge("114", "125", weight=1000)  
G.add_edge("114", "128", weight=1000)  
G.add_edge("114", "131", weight=1000)  
G.add_edge("114", "132", weight=1000)  
G.add_edge("114", "134", weight=1000)  
G.add_edge("114", "139", weight=1000)  
G.add_edge("114", "140", weight=1000)  
G.add_edge("114", "141", weight=500)  
G.add_edge("114", "142", weight=1000)  
G.add_edge("114", "144", weight=10000)  
G.add_edge("114", "146", weight=500)  
G.add_edge("114", "150", weight=500)  
G.add_edge("114", "154", weight=1000)  
G.add_edge("114", "159", weight=500)  
G.add_edge("114", "160", weight=1000)  
G.add_edge("114", "162", weight=500)  
G.add_edge("114", "163", weight=10000)  
G.add_edge("114", "164", weight=1000)  
G.add_edge("114", "166", weight=1000)  
G.add_edge("114", "168", weight=1000)  
G.add_edge("114", "171", weight=1000)  
G.add_edge("115", "0", weight=0)  
G.add_edge("115", "3", weight=0)  
G.add_edge("115", "7", weight=0)  
G.add_edge("115", "21", weight=0)  
G.add_edge("115", "39", weight=0)  
G.add_edge("115", "46", weight=0)  
G.add_edge("115", "65", weight=0)  
G.add_edge("115", "65", weight=0)  
G.add_edge("115", "65", weight=0)  
G.add_edge("115", "69", weight=0)  
G.add_edge("115", "74", weight=0)  
G.add_edge("115", "97", weight=0)  
G.add_edge("115", "103", weight=0)  
G.add_edge("115", "114", weight=0)  
G.add_edge("115", "124", weight=0)  
G.add_edge("115", "126", weight=0)  
G.add_edge("115", "128", weight=0)  
G.add_edge("115", "130", weight=0)  
G.add_edge("115", "141", weight=0)  
G.add_edge("115", "143", weight=0)  
G.add_edge("115", "150", weight=0)  
G.add_edge("115", "159", weight=0)  
G.add_edge("115", "161", weight=0)  
G.add_edge("115", "174", weight=0)  
G.add_edge("115", "176", weight=0)  
G.add_edge("116", "1", weight=0)  
G.add_edge("116", "6", weight=0)  
G.add_edge("116", "9", weight=0)  
G.add_edge("116", "12", weight=0)  
G.add_edge("116", "25", weight=0)  
G.add_edge("116", "33", weight=0)  
G.add_edge("116", "37", weight=0)  
G.add_edge("116", "44", weight=0)  
G.add_edge("116", "48", weight=0)  
G.add_edge("116", "51", weight=0)  
G.add_edge("116", "52", weight=0)  
G.add_edge("116", "57", weight=0)  
G.add_edge("116", "58", weight=0)  
G.add_edge("116", "63", weight=0)  
G.add_edge("116", "64", weight=0)  
G.add_edge("116", "69", weight=0)  
G.add_edge("116", "70", weight=0)  
G.add_edge("116", "74", weight=0)  
G.add_edge("116", "80", weight=0)  
G.add_edge("116", "82", weight=0)  
G.add_edge("116", "85", weight=0)  
G.add_edge("116", "87", weight=0)  
G.add_edge("116", "90", weight=1893)  
G.add_edge("116", "91", weight=2199)  
G.add_edge("116", "95", weight=0)  
G.add_edge("116", "98", weight=0)  
G.add_edge("116", "101", weight=0)  
G.add_edge("116", "105", weight=632)  
G.add_edge("116", "107", weight=0)  
G.add_edge("116", "108", weight=0)  
G.add_edge("116", "109", weight=0)  
G.add_edge("116", "112", weight=0)  
G.add_edge("116", "113", weight=0)  
G.add_edge("116", "114", weight=0)  
G.add_edge("116", "118", weight=0)  
G.add_edge("116", "122", weight=0)  
G.add_edge("116", "124", weight=0)  
G.add_edge("116", "125", weight=0)  
G.add_edge("116", "126", weight=0)  
G.add_edge("116", "127", weight=0)  
G.add_edge("116", "128", weight=1813)  
G.add_edge("116", "131", weight=0)  
G.add_edge("116", "132", weight=0)  
G.add_edge("116", "134", weight=0)  
G.add_edge("116", "136", weight=0)  
G.add_edge("116", "139", weight=0)  
G.add_edge("116", "142", weight=0)  
G.add_edge("116", "144", weight=0)  
G.add_edge("116", "145", weight=0)  
G.add_edge("116", "148", weight=0)  
G.add_edge("116", "149", weight=0)  
G.add_edge("116", "151", weight=0)  
G.add_edge("116", "153", weight=0)  
G.add_edge("116", "154", weight=0)  
G.add_edge("116", "156", weight=0)  
G.add_edge("116", "157", weight=0)  
G.add_edge("116", "160", weight=0)  
G.add_edge("116", "163", weight=0)  
G.add_edge("116", "164", weight=0)  
G.add_edge("116", "166", weight=0)  
G.add_edge("116", "171", weight=0)  
G.add_edge("116", "172", weight=0)  
G.add_edge("116", "173", weight=0)  
G.add_edge("116", "177", weight=0)  
G.add_edge("117", "39", weight=3000)  
G.add_edge("117", "155", weight=3000)  
G.add_edge("117", "171", weight=3000)  
G.add_edge("118", "1", weight=1000)  
G.add_edge("118", "6", weight=1000)  
G.add_edge("118", "9", weight=0)  
G.add_edge("118", "25", weight=1000)  
G.add_edge("118", "34", weight=1000)  
G.add_edge("118", "44", weight=1000)  
G.add_edge("118", "48", weight=0)  
G.add_edge("118", "49", weight=1000)  
G.add_edge("118", "57", weight=1000)  
G.add_edge("118", "59", weight=0)  
G.add_edge("118", "60", weight=0)  
G.add_edge("118", "62", weight=1000)  
G.add_edge("118", "66", weight=1000)  
G.add_edge("118", "69", weight=0)  
G.add_edge("118", "70", weight=1000)  
G.add_edge("118", "79", weight=1000)  
G.add_edge("118", "84", weight=1000)  
G.add_edge("118", "85", weight=0)  
G.add_edge("118", "86", weight=1000)  
G.add_edge("118", "87", weight=0)  
G.add_edge("118", "95", weight=1000)  
G.add_edge("118", "98", weight=0)  
G.add_edge("118", "102", weight=28000)  
G.add_edge("118", "107", weight=0)  
G.add_edge("118", "109", weight=0)  
G.add_edge("118", "111", weight=1000)  
G.add_edge("118", "113", weight=0)  
G.add_edge("118", "116", weight=0)  
G.add_edge("118", "122", weight=28000)  
G.add_edge("118", "123", weight=1000)  
G.add_edge("118", "127", weight=1000)  
G.add_edge("118", "128", weight=0)  
G.add_edge("118", "131", weight=0)  
G.add_edge("118", "135", weight=1000)  
G.add_edge("118", "138", weight=28000)  
G.add_edge("118", "139", weight=0)  
G.add_edge("118", "140", weight=1000)  
G.add_edge("118", "142", weight=1000)  
G.add_edge("118", "147", weight=1000)  
G.add_edge("118", "166", weight=0)  
G.add_edge("118", "168", weight=0)  
G.add_edge("118", "170", weight=0)  
G.add_edge("118", "174", weight=1000)  
G.add_edge("118", "175", weight=0)  
G.add_edge("119", "6", weight=1)  
G.add_edge("119", "9", weight=1)  
G.add_edge("119", "29", weight=1000)  
G.add_edge("119", "31", weight=1)  
G.add_edge("119", "48", weight=1)  
G.add_edge("119", "59", weight=1)  
G.add_edge("119", "62", weight=1000)  
G.add_edge("119", "69", weight=2)  
G.add_edge("119", "70", weight=1000)  
G.add_edge("119", "78", weight=1)  
G.add_edge("119", "79", weight=1111)  
G.add_edge("119", "79", weight=1111)  
G.add_edge("119", "82", weight=1000)  
G.add_edge("119", "83", weight=10)  
G.add_edge("119", "85", weight=1)  
G.add_edge("119", "95", weight=1)  
G.add_edge("119", "95", weight=1)  
G.add_edge("119", "99", weight=10)  
G.add_edge("119", "101", weight=200)  
G.add_edge("119", "102", weight=10)  
G.add_edge("119", "105", weight=1)  
G.add_edge("119", "108", weight=2000)  
G.add_edge("119", "109", weight=10)  
G.add_edge("119", "111", weight=1)  
G.add_edge("119", "113", weight=10)  
G.add_edge("119", "125", weight=10)  
G.add_edge("119", "126", weight=10)  
G.add_edge("119", "128", weight=10)  
G.add_edge("119", "129", weight=10)  
G.add_edge("119", "130", weight=10)  
G.add_edge("119", "132", weight=10)  
G.add_edge("119", "134", weight=10)  
G.add_edge("119", "136", weight=10)  
G.add_edge("119", "138", weight=20)  
G.add_edge("119", "142", weight=10)  
G.add_edge("119", "166", weight=10)  
G.add_edge("120", "53", weight=0)  
G.add_edge("120", "54", weight=0)  
G.add_edge("120", "61", weight=0)  
G.add_edge("120", "67", weight=0)  
G.add_edge("120", "104", weight=0)  
G.add_edge("120", "113", weight=0)  
G.add_edge("120", "124", weight=0)  
G.add_edge("120", "133", weight=0)  
G.add_edge("120", "140", weight=0)  
G.add_edge("120", "142", weight=0)  
G.add_edge("120", "146", weight=0)  
G.add_edge("120", "148", weight=0)  
G.add_edge("120", "156", weight=0)  
G.add_edge("121", "57", weight=1000)  
G.add_edge("121", "132", weight=1000)  
G.add_edge("121", "137", weight=1000)  
G.add_edge("121", "142", weight=1000)  
G.add_edge("121", "146", weight=1000)  
G.add_edge("121", "147", weight=1000)  
G.add_edge("121", "155", weight=1000)  
G.add_edge("121", "156", weight=1000)  
G.add_edge("121", "168", weight=1000)  
G.add_edge("121", "171", weight=1000)  
G.add_edge("122", "6", weight=0)  
G.add_edge("122", "8", weight=0)  
G.add_edge("122", "9", weight=0)  
G.add_edge("122", "16", weight=0)  
G.add_edge("122", "18", weight=0)  
G.add_edge("122", "21", weight=0)  
G.add_edge("122", "41", weight=0)  
G.add_edge("122", "44", weight=0)  
G.add_edge("122", "51", weight=0)  
G.add_edge("122", "57", weight=0)  
G.add_edge("122", "59", weight=0)  
G.add_edge("122", "60", weight=0)  
G.add_edge("122", "60", weight=0)  
G.add_edge("122", "62", weight=0)  
G.add_edge("122", "63", weight=0)  
G.add_edge("122", "64", weight=0)  
G.add_edge("122", "67", weight=0)  
G.add_edge("122", "69", weight=0)  
G.add_edge("122", "70", weight=0)  
G.add_edge("122", "70", weight=0)  
G.add_edge("122", "83", weight=0)  
G.add_edge("122", "94", weight=0)  
G.add_edge("122", "99", weight=0)  
G.add_edge("122", "100", weight=0)  
G.add_edge("122", "102", weight=0)  
G.add_edge("122", "103", weight=0)  
G.add_edge("122", "104", weight=0)  
G.add_edge("122", "105", weight=0)  
G.add_edge("122", "107", weight=0)  
G.add_edge("122", "112", weight=0)  
G.add_edge("122", "113", weight=0)  
G.add_edge("122", "114", weight=0)  
G.add_edge("122", "116", weight=0)  
G.add_edge("122", "118", weight=0)  
G.add_edge("122", "123", weight=0)  
G.add_edge("122", "124", weight=0)  
G.add_edge("122", "125", weight=0)  
G.add_edge("122", "126", weight=0)  
G.add_edge("122", "127", weight=0)  
G.add_edge("122", "128", weight=0)  
G.add_edge("122", "130", weight=0)  
G.add_edge("122", "131", weight=0)  
G.add_edge("122", "132", weight=0)  
G.add_edge("122", "138", weight=0)  
G.add_edge("122", "139", weight=0)  
G.add_edge("122", "140", weight=0)  
G.add_edge("122", "142", weight=0)  
G.add_edge("122", "145", weight=0)  
G.add_edge("122", "146", weight=0)  
G.add_edge("122", "146", weight=0)  
G.add_edge("122", "148", weight=0)  
G.add_edge("122", "151", weight=0)  
G.add_edge("122", "154", weight=0)  
G.add_edge("122", "156", weight=0)  
G.add_edge("122", "158", weight=0)  
G.add_edge("122", "160", weight=0)  
G.add_edge("122", "163", weight=0)  
G.add_edge("122", "164", weight=0)  
G.add_edge("122", "166", weight=0)  
G.add_edge("122", "168", weight=0)  
G.add_edge("122", "170", weight=0)  
G.add_edge("122", "171", weight=0)  
G.add_edge("122", "172", weight=0)  
G.add_edge("122", "175", weight=0)  
G.add_edge("123", "1", weight=999)  
G.add_edge("123", "6", weight=999)  
G.add_edge("123", "9", weight=999)  
G.add_edge("123", "18", weight=999)  
G.add_edge("123", "44", weight=999)  
G.add_edge("123", "44", weight=999)  
G.add_edge("123", "48", weight=999)  
G.add_edge("123", "51", weight=999)  
G.add_edge("123", "57", weight=999)  
G.add_edge("123", "60", weight=2000)  
G.add_edge("123", "62", weight=999)  
G.add_edge("123", "66", weight=999)  
G.add_edge("123", "69", weight=999)  
G.add_edge("123", "70", weight=999)  
G.add_edge("123", "79", weight=999)  
G.add_edge("123", "84", weight=999)  
G.add_edge("123", "85", weight=999)  
G.add_edge("123", "103", weight=999)  
G.add_edge("123", "107", weight=999)  
G.add_edge("123", "108", weight=999)  
G.add_edge("123", "110", weight=999)  
G.add_edge("123", "111", weight=999)  
G.add_edge("123", "118", weight=999)  
G.add_edge("123", "122", weight=999)  
G.add_edge("123", "127", weight=999)  
G.add_edge("123", "128", weight=999)  
G.add_edge("123", "130", weight=999)  
G.add_edge("123", "131", weight=0)  
G.add_edge("123", "131", weight=0)  
G.add_edge("123", "138", weight=999)  
G.add_edge("123", "139", weight=999)  
G.add_edge("123", "142", weight=999)  
G.add_edge("123", "147", weight=999)  
G.add_edge("123", "148", weight=999)  
G.add_edge("123", "154", weight=999)  
G.add_edge("123", "156", weight=999)  
G.add_edge("123", "160", weight=999)  
G.add_edge("123", "164", weight=999)  
G.add_edge("123", "166", weight=999)  
G.add_edge("123", "168", weight=999)  
G.add_edge("123", "171", weight=999)  
G.add_edge("123", "173", weight=999)  
G.add_edge("123", "175", weight=99000)  
G.add_edge("124", "3", weight=0)  
G.add_edge("124", "4", weight=0)  
G.add_edge("124", "6", weight=0)  
G.add_edge("124", "9", weight=0)  
G.add_edge("124", "40", weight=0)  
G.add_edge("124", "48", weight=0)  
G.add_edge("124", "49", weight=10000)  
G.add_edge("124", "57", weight=0)  
G.add_edge("124", "59", weight=0)  
G.add_edge("124", "60", weight=0)  
G.add_edge("124", "63", weight=0)  
G.add_edge("124", "66", weight=0)  
G.add_edge("124", "67", weight=0)  
G.add_edge("124", "70", weight=10000)  
G.add_edge("124", "85", weight=10000)  
G.add_edge("124", "94", weight=0)  
G.add_edge("124", "98", weight=10000)  
G.add_edge("124", "103", weight=0)  
G.add_edge("124", "105", weight=0)  
G.add_edge("124", "107", weight=0)  
G.add_edge("124", "111", weight=0)  
G.add_edge("124", "112", weight=0)  
G.add_edge("124", "114", weight=0)  
G.add_edge("124", "115", weight=0)  
G.add_edge("124", "116", weight=10000)  
G.add_edge("124", "120", weight=0)  
G.add_edge("124", "122", weight=0)  
G.add_edge("124", "125", weight=0)  
G.add_edge("124", "127", weight=0)  
G.add_edge("124", "128", weight=10000)  
G.add_edge("124", "129", weight=0)  
G.add_edge("124", "132", weight=0)  
G.add_edge("124", "140", weight=0)  
G.add_edge("124", "142", weight=0)  
G.add_edge("124", "144", weight=0)  
G.add_edge("124", "145", weight=0)  
G.add_edge("124", "148", weight=0)  
G.add_edge("124", "149", weight=0)  
G.add_edge("124", "151", weight=10000)  
G.add_edge("124", "154", weight=10000)  
G.add_edge("124", "166", weight=0)  
G.add_edge("124", "175", weight=0)  
G.add_edge("125", "1", weight=1000)  
G.add_edge("125", "4", weight=0)  
G.add_edge("125", "6", weight=0)  
G.add_edge("125", "8", weight=0)  
G.add_edge("125", "9", weight=1000)  
G.add_edge("125", "20", weight=1000)  
G.add_edge("125", "21", weight=1000)  
G.add_edge("125", "31", weight=0)  
G.add_edge("125", "33", weight=0)  
G.add_edge("125", "37", weight=0)  
G.add_edge("125", "39", weight=1000)  
G.add_edge("125", "40", weight=0)  
G.add_edge("125", "41", weight=1000)  
G.add_edge("125", "44", weight=0)  
G.add_edge("125", "47", weight=1000)  
G.add_edge("125", "48", weight=0)  
G.add_edge("125", "49", weight=1000)  
G.add_edge("125", "55", weight=0)  
G.add_edge("125", "56", weight=0)  
G.add_edge("125", "57", weight=0)  
G.add_edge("125", "59", weight=0)  
G.add_edge("125", "62", weight=0)  
G.add_edge("125", "62", weight=1000)  
G.add_edge("125", "63", weight=0)  
G.add_edge("125", "64", weight=0)  
G.add_edge("125", "69", weight=0)  
G.add_edge("125", "70", weight=0)  
G.add_edge("125", "74", weight=0)  
G.add_edge("125", "78", weight=0)  
G.add_edge("125", "79", weight=0)  
G.add_edge("125", "84", weight=1000)  
G.add_edge("125", "85", weight=1000)  
G.add_edge("125", "87", weight=0)  
G.add_edge("125", "88", weight=0)  
G.add_edge("125", "90", weight=0)  
G.add_edge("125", "92", weight=0)  
G.add_edge("125", "95", weight=0)  
G.add_edge("125", "97", weight=0)  
G.add_edge("125", "99", weight=0)  
G.add_edge("125", "100", weight=1000)  
G.add_edge("125", "103", weight=1000)  
G.add_edge("125", "104", weight=0)  
G.add_edge("125", "105", weight=0)  
G.add_edge("125", "107", weight=1000)  
G.add_edge("125", "112", weight=1000)  
G.add_edge("125", "113", weight=0)  
G.add_edge("125", "114", weight=1000)  
G.add_edge("125", "116", weight=0)  
G.add_edge("125", "119", weight=1000)  
G.add_edge("125", "122", weight=1000)  
G.add_edge("125", "124", weight=0)  
G.add_edge("125", "126", weight=1000)  
G.add_edge("125", "128", weight=0)  
G.add_edge("125", "129", weight=0)  
G.add_edge("125", "130", weight=0)  
G.add_edge("125", "131", weight=0)  
G.add_edge("125", "134", weight=0)  
G.add_edge("125", "140", weight=0)  
G.add_edge("125", "142", weight=0)  
G.add_edge("125", "144", weight=0)  
G.add_edge("125", "145", weight=1000)  
G.add_edge("125", "149", weight=1000)  
G.add_edge("125", "154", weight=1000)  
G.add_edge("125", "163", weight=1000)  
G.add_edge("125", "165", weight=1000)  
G.add_edge("125", "168", weight=1000)  
G.add_edge("125", "171", weight=1000)  
G.add_edge("125", "174", weight=1000)  
G.add_edge("125", "175", weight=1000)  
G.add_edge("126", "1", weight=0)  
G.add_edge("126", "2", weight=0)  
G.add_edge("126", "6", weight=0)  
G.add_edge("126", "14", weight=10000)  
G.add_edge("126", "15", weight=0)  
G.add_edge("126", "22", weight=0)  
G.add_edge("126", "26", weight=0)  
G.add_edge("126", "31", weight=0)  
G.add_edge("126", "41", weight=0)  
G.add_edge("126", "44", weight=0)  
G.add_edge("126", "46", weight=0)  
G.add_edge("126", "47", weight=0)  
G.add_edge("126", "48", weight=0)  
G.add_edge("126", "57", weight=0)  
G.add_edge("126", "59", weight=0)  
G.add_edge("126", "60", weight=0)  
G.add_edge("126", "60", weight=0)  
G.add_edge("126", "62", weight=0)  
G.add_edge("126", "63", weight=0)  
G.add_edge("126", "64", weight=0)  
G.add_edge("126", "66", weight=0)  
G.add_edge("126", "69", weight=0)  
G.add_edge("126", "70", weight=0)  
G.add_edge("126", "73", weight=0)  
G.add_edge("126", "74", weight=0)  
G.add_edge("126", "76", weight=0)  
G.add_edge("126", "79", weight=0)  
G.add_edge("126", "82", weight=0)  
G.add_edge("126", "85", weight=0)  
G.add_edge("126", "87", weight=0)  
G.add_edge("126", "95", weight=0)  
G.add_edge("126", "99", weight=0)  
G.add_edge("126", "101", weight=0)  
G.add_edge("126", "103", weight=0)  
G.add_edge("126", "105", weight=0)  
G.add_edge("126", "111", weight=0)  
G.add_edge("126", "112", weight=0)  
G.add_edge("126", "113", weight=0)  
G.add_edge("126", "115", weight=0)  
G.add_edge("126", "116", weight=0)  
G.add_edge("126", "119", weight=0)  
G.add_edge("126", "122", weight=0)  
G.add_edge("126", "125", weight=0)  
G.add_edge("126", "127", weight=0)  
G.add_edge("126", "128", weight=0)  
G.add_edge("126", "130", weight=0)  
G.add_edge("126", "131", weight=0)  
G.add_edge("126", "134", weight=0)  
G.add_edge("126", "135", weight=0)  
G.add_edge("126", "138", weight=0)  
G.add_edge("126", "140", weight=0)  
G.add_edge("126", "142", weight=0)  
G.add_edge("126", "143", weight=0)  
G.add_edge("126", "146", weight=0)  
G.add_edge("126", "150", weight=0)  
G.add_edge("126", "152", weight=0)  
G.add_edge("126", "154", weight=0)  
G.add_edge("126", "160", weight=0)  
G.add_edge("126", "163", weight=0)  
G.add_edge("126", "164", weight=0)  
G.add_edge("126", "165", weight=0)  
G.add_edge("126", "166", weight=0)  
G.add_edge("126", "167", weight=0)  
G.add_edge("126", "168", weight=0)  
G.add_edge("126", "169", weight=0)  
G.add_edge("126", "170", weight=0)  
G.add_edge("126", "175", weight=0)  
G.add_edge("126", "176", weight=0)  
G.add_edge("127", "1", weight=100)  
G.add_edge("127", "2", weight=500)  
G.add_edge("127", "4", weight=200)  
G.add_edge("127", "5", weight=200)  
G.add_edge("127", "6", weight=300)  
G.add_edge("127", "8", weight=300)  
G.add_edge("127", "9", weight=400)  
G.add_edge("127", "10", weight=300)  
G.add_edge("127", "14", weight=400)  
G.add_edge("127", "18", weight=400)  
G.add_edge("127", "28", weight=400)  
G.add_edge("127", "34", weight=200)  
G.add_edge("127", "39", weight=20)  
G.add_edge("127", "44", weight=200)  
G.add_edge("127", "46", weight=300)  
G.add_edge("127", "47", weight=300)  
G.add_edge("127", "48", weight=100)  
G.add_edge("127", "49", weight=400)  
G.add_edge("127", "51", weight=400)  
G.add_edge("127", "52", weight=500)  
G.add_edge("127", "53", weight=400)  
G.add_edge("127", "57", weight=400)  
G.add_edge("127", "59", weight=300)  
G.add_edge("127", "60", weight=200)  
G.add_edge("127", "62", weight=300)  
G.add_edge("127", "64", weight=400)  
G.add_edge("127", "66", weight=300)  
G.add_edge("127", "69", weight=400)  
G.add_edge("127", "70", weight=500)  
G.add_edge("127", "71", weight=200)  
G.add_edge("127", "79", weight=300)  
G.add_edge("127", "84", weight=400)  
G.add_edge("127", "85", weight=900)  
G.add_edge("127", "86", weight=300)  
G.add_edge("127", "87", weight=400)  
G.add_edge("127", "88", weight=200)  
G.add_edge("127", "92", weight=0)  
G.add_edge("127", "98", weight=400)  
G.add_edge("127", "99", weight=400)  
G.add_edge("127", "100", weight=300)  
G.add_edge("127", "101", weight=200)  
G.add_edge("127", "103", weight=300)  
G.add_edge("127", "107", weight=100)  
G.add_edge("127", "111", weight=100)  
G.add_edge("127", "113", weight=400)  
G.add_edge("127", "116", weight=200)  
G.add_edge("127", "118", weight=400)  
G.add_edge("127", "122", weight=400)  
G.add_edge("127", "123", weight=300)  
G.add_edge("127", "124", weight=200)  
G.add_edge("127", "126", weight=200)  
G.add_edge("127", "129", weight=400)  
G.add_edge("127", "130", weight=100)  
G.add_edge("127", "131", weight=0)  
G.add_edge("127", "132", weight=400)  
G.add_edge("127", "134", weight=200)  
G.add_edge("127", "135", weight=300)  
G.add_edge("127", "136", weight=400)  
G.add_edge("127", "137", weight=400)  
G.add_edge("127", "138", weight=400)  
G.add_edge("127", "139", weight=400)  
G.add_edge("127", "140", weight=400)  
G.add_edge("127", "142", weight=400)  
G.add_edge("127", "143", weight=305)  
G.add_edge("127", "144", weight=400)  
G.add_edge("127", "146", weight=400)  
G.add_edge("127", "154", weight=400)  
G.add_edge("127", "155", weight=400)  
G.add_edge("127", "157", weight=400)  
G.add_edge("127", "158", weight=300)  
G.add_edge("127", "163", weight=200)  
G.add_edge("127", "166", weight=400)  
G.add_edge("127", "168", weight=400)  
G.add_edge("127", "170", weight=0)  
G.add_edge("127", "171", weight=400)  
G.add_edge("127", "172", weight=300)  
G.add_edge("127", "174", weight=400)  
G.add_edge("127", "175", weight=200)  
G.add_edge("128", "1", weight=0)  
G.add_edge("128", "2", weight=0)  
G.add_edge("128", "6", weight=0)  
G.add_edge("128", "7", weight=0)  
G.add_edge("128", "8", weight=0)  
G.add_edge("128", "9", weight=0)  
G.add_edge("128", "16", weight=0)  
G.add_edge("128", "18", weight=0)  
G.add_edge("128", "22", weight=0)  
G.add_edge("128", "25", weight=0)  
G.add_edge("128", "28", weight=0)  
G.add_edge("128", "31", weight=0)  
G.add_edge("128", "34", weight=0)  
G.add_edge("128", "35", weight=0)  
G.add_edge("128", "39", weight=0)  
G.add_edge("128", "40", weight=0)  
G.add_edge("128", "41", weight=0)  
G.add_edge("128", "42", weight=0)  
G.add_edge("128", "44", weight=0)  
G.add_edge("128", "45", weight=0)  
G.add_edge("128", "46", weight=0)  
G.add_edge("128", "47", weight=0)  
G.add_edge("128", "48", weight=0)  
G.add_edge("128", "51", weight=0)  
G.add_edge("128", "53", weight=0)  
G.add_edge("128", "55", weight=0)  
G.add_edge("128", "56", weight=0)  
G.add_edge("128", "57", weight=0)  
G.add_edge("128", "59", weight=0)  
G.add_edge("128", "60", weight=0)  
G.add_edge("128", "62", weight=0)  
G.add_edge("128", "63", weight=0)  
G.add_edge("128", "64", weight=0)  
G.add_edge("128", "66", weight=0)  
G.add_edge("128", "67", weight=0)  
G.add_edge("128", "69", weight=0)  
G.add_edge("128", "70", weight=0)  
G.add_edge("128", "71", weight=0)  
G.add_edge("128", "74", weight=0)  
G.add_edge("128", "76", weight=0)  
G.add_edge("128", "77", weight=0)  
G.add_edge("128", "78", weight=0)  
G.add_edge("128", "79", weight=0)  
G.add_edge("128", "80", weight=0)  
G.add_edge("128", "84", weight=0)  
G.add_edge("128", "85", weight=0)  
G.add_edge("128", "85", weight=0)  
G.add_edge("128", "87", weight=0)  
G.add_edge("128", "88", weight=0)  
G.add_edge("128", "90", weight=0)  
G.add_edge("128", "92", weight=0)  
G.add_edge("128", "95", weight=0)  
G.add_edge("128", "98", weight=0)  
G.add_edge("128", "99", weight=0)  
G.add_edge("128", "100", weight=0)  
G.add_edge("128", "102", weight=0)  
G.add_edge("128", "103", weight=0)  
G.add_edge("128", "104", weight=0)  
G.add_edge("128", "105", weight=0)  
G.add_edge("128", "107", weight=0)  
G.add_edge("128", "108", weight=0)  
G.add_edge("128", "113", weight=0)  
G.add_edge("128", "114", weight=0)  
G.add_edge("128", "115", weight=0)  
G.add_edge("128", "116", weight=0)  
G.add_edge("128", "118", weight=0)  
G.add_edge("128", "119", weight=0)  
G.add_edge("128", "122", weight=0)  
G.add_edge("128", "123", weight=0)  
G.add_edge("128", "124", weight=0)  
G.add_edge("128", "125", weight=0)  
G.add_edge("128", "126", weight=0)  
G.add_edge("128", "129", weight=0)  
G.add_edge("128", "130", weight=0)  
G.add_edge("128", "131", weight=0)  
G.add_edge("128", "132", weight=0)  
G.add_edge("128", "134", weight=0)  
G.add_edge("128", "136", weight=0)  
G.add_edge("128", "139", weight=0)  
G.add_edge("128", "140", weight=0)  
G.add_edge("128", "141", weight=0)  
G.add_edge("128", "142", weight=0)  
G.add_edge("128", "145", weight=0)  
G.add_edge("128", "146", weight=0)  
G.add_edge("128", "147", weight=0)  
G.add_edge("128", "148", weight=0)  
G.add_edge("128", "149", weight=0)  
G.add_edge("128", "150", weight=0)  
G.add_edge("128", "152", weight=0)  
G.add_edge("128", "154", weight=0)  
G.add_edge("128", "156", weight=0)  
G.add_edge("128", "157", weight=0)  
G.add_edge("128", "159", weight=0)  
G.add_edge("128", "160", weight=0)  
G.add_edge("128", "163", weight=0)  
G.add_edge("128", "164", weight=0)  
G.add_edge("128", "165", weight=0)  
G.add_edge("128", "166", weight=0)  
G.add_edge("128", "168", weight=0)  
G.add_edge("128", "169", weight=0)  
G.add_edge("128", "170", weight=0)  
G.add_edge("128", "171", weight=0)  
G.add_edge("128", "172", weight=0)  
G.add_edge("128", "173", weight=0)  
G.add_edge("128", "174", weight=0)  
G.add_edge("128", "175", weight=0)  
G.add_edge("129", "1", weight=0)  
G.add_edge("129", "6", weight=0)  
G.add_edge("129", "9", weight=0)  
G.add_edge("129", "35", weight=0)  
G.add_edge("129", "40", weight=0)  
G.add_edge("129", "42", weight=0)  
G.add_edge("129", "44", weight=0)  
G.add_edge("129", "48", weight=0)  
G.add_edge("129", "53", weight=0)  
G.add_edge("129", "62", weight=0)  
G.add_edge("129", "63", weight=0)  
G.add_edge("129", "64", weight=0)  
G.add_edge("129", "67", weight=0)  
G.add_edge("129", "69", weight=0)  
G.add_edge("129", "70", weight=0)  
G.add_edge("129", "78", weight=0)  
G.add_edge("129", "95", weight=0)  
G.add_edge("129", "99", weight=0)  
G.add_edge("129", "100", weight=0)  
G.add_edge("129", "103", weight=0)  
G.add_edge("129", "108", weight=0)  
G.add_edge("129", "113", weight=0)  
G.add_edge("129", "119", weight=0)  
G.add_edge("129", "124", weight=0)  
G.add_edge("129", "125", weight=0)  
G.add_edge("129", "127", weight=0)  
G.add_edge("129", "128", weight=0)  
G.add_edge("129", "130", weight=0)  
G.add_edge("129", "132", weight=0)  
G.add_edge("129", "134", weight=0)  
G.add_edge("129", "138", weight=0)  
G.add_edge("129", "142", weight=0)  
G.add_edge("129", "145", weight=0)  
G.add_edge("129", "146", weight=0)  
G.add_edge("129", "151", weight=0)  
G.add_edge("129", "152", weight=0)  
G.add_edge("129", "154", weight=0)  
G.add_edge("129", "160", weight=0)  
G.add_edge("129", "166", weight=0)  
G.add_edge("130", "1", weight=400)  
G.add_edge("130", "6", weight=400)  
G.add_edge("130", "9", weight=400)  
G.add_edge("130", "28", weight=400)  
G.add_edge("130", "33", weight=400)  
G.add_edge("130", "34", weight=400)  
G.add_edge("130", "35", weight=400)  
G.add_edge("130", "37", weight=400)  
G.add_edge("130", "40", weight=400)  
G.add_edge("130", "41", weight=400)  
G.add_edge("130", "42", weight=400)  
G.add_edge("130", "44", weight=400)  
G.add_edge("130", "45", weight=400)  
G.add_edge("130", "47", weight=400)  
G.add_edge("130", "48", weight=400)  
G.add_edge("130", "51", weight=400)  
G.add_edge("130", "53", weight=400)  
G.add_edge("130", "55", weight=400)  
G.add_edge("130", "57", weight=400)  
G.add_edge("130", "59", weight=400)  
G.add_edge("130", "60", weight=400)  
G.add_edge("130", "60", weight=400)  
G.add_edge("130", "61", weight=400)  
G.add_edge("130", "62", weight=400)  
G.add_edge("130", "64", weight=400)  
G.add_edge("130", "66", weight=400)  
G.add_edge("130", "67", weight=400)  
G.add_edge("130", "68", weight=400)  
G.add_edge("130", "69", weight=400)  
G.add_edge("130", "70", weight=400)  
G.add_edge("130", "71", weight=400)  
G.add_edge("130", "74", weight=400)  
G.add_edge("130", "78", weight=400)  
G.add_edge("130", "79", weight=400)  
G.add_edge("130", "82", weight=400)  
G.add_edge("130", "84", weight=400)  
G.add_edge("130", "85", weight=400)  
G.add_edge("130", "86", weight=400)  
G.add_edge("130", "87", weight=400)  
G.add_edge("130", "88", weight=400)  
G.add_edge("130", "89", weight=400)  
G.add_edge("130", "92", weight=400)  
G.add_edge("130", "95", weight=400)  
G.add_edge("130", "98", weight=400)  
G.add_edge("130", "99", weight=400)  
G.add_edge("130", "100", weight=400)  
G.add_edge("130", "101", weight=400)  
G.add_edge("130", "103", weight=400)  
G.add_edge("130", "105", weight=400)  
G.add_edge("130", "107", weight=400)  
G.add_edge("130", "108", weight=400)  
G.add_edge("130", "110", weight=400)  
G.add_edge("130", "111", weight=400)  
G.add_edge("130", "113", weight=400)  
G.add_edge("130", "115", weight=400)  
G.add_edge("130", "119", weight=400)  
G.add_edge("130", "122", weight=400)  
G.add_edge("130", "123", weight=400)  
G.add_edge("130", "125", weight=400)  
G.add_edge("130", "126", weight=400)  
G.add_edge("130", "127", weight=400)  
G.add_edge("130", "128", weight=400)  
G.add_edge("130", "129", weight=400)  
G.add_edge("130", "131", weight=400)  
G.add_edge("130", "132", weight=400)  
G.add_edge("130", "133", weight=400)  
G.add_edge("130", "134", weight=400)  
G.add_edge("130", "135", weight=400)  
G.add_edge("130", "136", weight=400)  
G.add_edge("130", "138", weight=400)  
G.add_edge("130", "139", weight=400)  
G.add_edge("130", "141", weight=400)  
G.add_edge("130", "142", weight=400)  
G.add_edge("130", "143", weight=400)  
G.add_edge("130", "147", weight=400)  
G.add_edge("130", "154", weight=400)  
G.add_edge("130", "164", weight=400)  
G.add_edge("130", "166", weight=400)  
G.add_edge("130", "168", weight=400)  
G.add_edge("130", "170", weight=400)  
G.add_edge("130", "171", weight=400)  
G.add_edge("130", "172", weight=400)  
G.add_edge("130", "174", weight=400)  
G.add_edge("130", "174", weight=400)  
G.add_edge("130", "175", weight=400)  
G.add_edge("131", "1", weight=169420)  
G.add_edge("131", "2", weight=9999000)  
G.add_edge("131", "6", weight=69420)  
G.add_edge("131", "6", weight=69420)  
G.add_edge("131", "7", weight=269420)  
G.add_edge("131", "9", weight=269420)  
G.add_edge("131", "18", weight=9999000)  
G.add_edge("131", "31", weight=269420)  
G.add_edge("131", "33", weight=269420)  
G.add_edge("131", "34", weight=169420)  
G.add_edge("131", "40", weight=269420)  
G.add_edge("131", "41", weight=169420)  
G.add_edge("131", "42", weight=269420)  
G.add_edge("131", "44", weight=269420)  
G.add_edge("131", "52", weight=9999000)  
G.add_edge("131", "57", weight=269420)  
G.add_edge("131", "58", weight=269420)  
G.add_edge("131", "59", weight=269420)  
G.add_edge("131", "60", weight=69420)  
G.add_edge("131", "60", weight=69420)  
G.add_edge("131", "66", weight=269420)  
G.add_edge("131", "69", weight=269420)  
G.add_edge("131", "70", weight=69420)  
G.add_edge("131", "85", weight=269420)  
G.add_edge("131", "87", weight=9999000)  
G.add_edge("131", "88", weight=269420)  
G.add_edge("131", "95", weight=269420)  
G.add_edge("131", "99", weight=269420)  
G.add_edge("131", "103", weight=269420)  
G.add_edge("131", "103", weight=269420)  
G.add_edge("131", "108", weight=69420)  
G.add_edge("131", "114", weight=269420)  
G.add_edge("131", "116", weight=269420)  
G.add_edge("131", "118", weight=269420)  
G.add_edge("131", "122", weight=269420)  
G.add_edge("131", "123", weight=269420)  
G.add_edge("131", "123", weight=269420)  
G.add_edge("131", "125", weight=9999000)  
G.add_edge("131", "126", weight=169420)  
G.add_edge("131", "127", weight=269420)  
G.add_edge("131", "128", weight=169420)  
G.add_edge("131", "130", weight=269420)  
G.add_edge("131", "132", weight=269420)  
G.add_edge("131", "138", weight=9999000)  
G.add_edge("131", "139", weight=9999000)  
G.add_edge("131", "140", weight=269420)  
G.add_edge("131", "142", weight=269420)  
G.add_edge("131", "143", weight=9999000)  
G.add_edge("131", "146", weight=169420)  
G.add_edge("131", "155", weight=269420)  
G.add_edge("131", "156", weight=269420)  
G.add_edge("131", "164", weight=269420)  
G.add_edge("131", "166", weight=269420)  
G.add_edge("131", "168", weight=269420)  
G.add_edge("131", "170", weight=169420)  
G.add_edge("131", "171", weight=169420)  
G.add_edge("131", "172", weight=269420)  
G.add_edge("131", "174", weight=69420)  
G.add_edge("131", "175", weight=269420)  
G.add_edge("132", "1", weight=0)  
G.add_edge("132", "2", weight=0)  
G.add_edge("132", "4", weight=0)  
G.add_edge("132", "6", weight=0)  
G.add_edge("132", "9", weight=0)  
G.add_edge("132", "31", weight=0)  
G.add_edge("132", "34", weight=0)  
G.add_edge("132", "40", weight=0)  
G.add_edge("132", "44", weight=0)  
G.add_edge("132", "45", weight=0)  
G.add_edge("132", "46", weight=0)  
G.add_edge("132", "47", weight=0)  
G.add_edge("132", "48", weight=0)  
G.add_edge("132", "52", weight=0)  
G.add_edge("132", "56", weight=0)  
G.add_edge("132", "57", weight=0)  
G.add_edge("132", "58", weight=0)  
G.add_edge("132", "59", weight=0)  
G.add_edge("132", "60", weight=0)  
G.add_edge("132", "61", weight=0)  
G.add_edge("132", "62", weight=0)  
G.add_edge("132", "65", weight=0)  
G.add_edge("132", "66", weight=0)  
G.add_edge("132", "69", weight=0)  
G.add_edge("132", "70", weight=0)  
G.add_edge("132", "71", weight=0)  
G.add_edge("132", "78", weight=0)  
G.add_edge("132", "79", weight=0)  
G.add_edge("132", "83", weight=0)  
G.add_edge("132", "84", weight=5)  
G.add_edge("132", "85", weight=0)  
G.add_edge("132", "86", weight=0)  
G.add_edge("132", "87", weight=0)  
G.add_edge("132", "89", weight=0)  
G.add_edge("132", "91", weight=0)  
G.add_edge("132", "95", weight=0)  
G.add_edge("132", "96", weight=0)  
G.add_edge("132", "103", weight=0)  
G.add_edge("132", "107", weight=0)  
G.add_edge("132", "111", weight=0)  
G.add_edge("132", "113", weight=0)  
G.add_edge("132", "114", weight=0)  
G.add_edge("132", "116", weight=0)  
G.add_edge("132", "119", weight=0)  
G.add_edge("132", "121", weight=0)  
G.add_edge("132", "122", weight=0)  
G.add_edge("132", "124", weight=0)  
G.add_edge("132", "127", weight=0)  
G.add_edge("132", "128", weight=0)  
G.add_edge("132", "129", weight=0)  
G.add_edge("132", "130", weight=0)  
G.add_edge("132", "131", weight=0)  
G.add_edge("132", "138", weight=0)  
G.add_edge("132", "139", weight=0)  
G.add_edge("132", "141", weight=0)  
G.add_edge("132", "142", weight=0)  
G.add_edge("132", "144", weight=0)  
G.add_edge("132", "148", weight=0)  
G.add_edge("132", "153", weight=0)  
G.add_edge("132", "156", weight=0)  
G.add_edge("132", "158", weight=0)  
G.add_edge("132", "160", weight=0)  
G.add_edge("132", "161", weight=0)  
G.add_edge("132", "164", weight=0)  
G.add_edge("132", "166", weight=0)  
G.add_edge("132", "175", weight=0)  
G.add_edge("133", "6", weight=0)  
G.add_edge("133", "18", weight=0)  
G.add_edge("133", "49", weight=0)  
G.add_edge("133", "59", weight=0)  
G.add_edge("133", "63", weight=0)  
G.add_edge("133", "64", weight=0)  
G.add_edge("133", "70", weight=0)  
G.add_edge("133", "80", weight=0)  
G.add_edge("133", "87", weight=0)  
G.add_edge("133", "103", weight=0)  
G.add_edge("133", "107", weight=0)  
G.add_edge("133", "113", weight=0)  
G.add_edge("133", "120", weight=0)  
G.add_edge("133", "130", weight=0)  
G.add_edge("133", "137", weight=0)  
G.add_edge("133", "139", weight=0)  
G.add_edge("133", "145", weight=0)  
G.add_edge("133", "148", weight=0)  
G.add_edge("133", "157", weight=0)  
G.add_edge("133", "164", weight=0)  
G.add_edge("133", "166", weight=0)  
G.add_edge("133", "168", weight=0)  
G.add_edge("133", "168", weight=0)  
G.add_edge("133", "170", weight=0)  
G.add_edge("133", "173", weight=0)  
G.add_edge("133", "175", weight=0)  
G.add_edge("134", "1", weight=0)  
G.add_edge("134", "2", weight=0)  
G.add_edge("134", "6", weight=0)  
G.add_edge("134", "9", weight=0)  
G.add_edge("134", "35", weight=0)  
G.add_edge("134", "40", weight=0)  
G.add_edge("134", "48", weight=0)  
G.add_edge("134", "51", weight=0)  
G.add_edge("134", "56", weight=0)  
G.add_edge("134", "59", weight=0)  
G.add_edge("134", "62", weight=0)  
G.add_edge("134", "63", weight=0)  
G.add_edge("134", "69", weight=0)  
G.add_edge("134", "70", weight=0)  
G.add_edge("134", "83", weight=0)  
G.add_edge("134", "84", weight=0)  
G.add_edge("134", "85", weight=0)  
G.add_edge("134", "86", weight=0)  
G.add_edge("134", "87", weight=0)  
G.add_edge("134", "88", weight=0)  
G.add_edge("134", "95", weight=0)  
G.add_edge("134", "99", weight=0)  
G.add_edge("134", "103", weight=0)  
G.add_edge("134", "105", weight=0)  
G.add_edge("134", "107", weight=0)  
G.add_edge("134", "113", weight=0)  
G.add_edge("134", "114", weight=0)  
G.add_edge("134", "116", weight=0)  
G.add_edge("134", "119", weight=0)  
G.add_edge("134", "125", weight=0)  
G.add_edge("134", "126", weight=0)  
G.add_edge("134", "127", weight=0)  
G.add_edge("134", "128", weight=0)  
G.add_edge("134", "129", weight=0)  
G.add_edge("134", "130", weight=0)  
G.add_edge("134", "137", weight=0)  
G.add_edge("134", "142", weight=0)  
G.add_edge("134", "145", weight=0)  
G.add_edge("134", "147", weight=0)  
G.add_edge("134", "148", weight=0)  
G.add_edge("134", "151", weight=0)  
G.add_edge("134", "153", weight=0)  
G.add_edge("134", "155", weight=0)  
G.add_edge("134", "160", weight=0)  
G.add_edge("134", "163", weight=0)  
G.add_edge("134", "164", weight=0)  
G.add_edge("134", "166", weight=0)  
G.add_edge("134", "170", weight=0)  
G.add_edge("134", "171", weight=0)  
G.add_edge("134", "175", weight=0)  
G.add_edge("135", "0", weight=1000)  
G.add_edge("135", "6", weight=1000)  
G.add_edge("135", "6", weight=1000)  
G.add_edge("135", "25", weight=0)  
G.add_edge("135", "35", weight=1000)  
G.add_edge("135", "40", weight=0)  
G.add_edge("135", "44", weight=1000)  
G.add_edge("135", "60", weight=0)  
G.add_edge("135", "60", weight=1000)  
G.add_edge("135", "61", weight=0)  
G.add_edge("135", "62", weight=1000)  
G.add_edge("135", "64", weight=1000)  
G.add_edge("135", "79", weight=1000)  
G.add_edge("135", "85", weight=2000)  
G.add_edge("135", "95", weight=1000)  
G.add_edge("135", "98", weight=1000)  
G.add_edge("135", "104", weight=1000)  
G.add_edge("135", "107", weight=1000)  
G.add_edge("135", "118", weight=1000)  
G.add_edge("135", "126", weight=1000)  
G.add_edge("135", "127", weight=1000)  
G.add_edge("135", "130", weight=1000)  
G.add_edge("135", "139", weight=1000)  
G.add_edge("135", "140", weight=1000)  
G.add_edge("135", "144", weight=1000)  
G.add_edge("135", "147", weight=1000)  
G.add_edge("135", "157", weight=1000)  
G.add_edge("135", "166", weight=1000)  
G.add_edge("135", "168", weight=1000)  
G.add_edge("135", "172", weight=1000)  
G.add_edge("135", "174", weight=1000)  
G.add_edge("136", "1", weight=0)  
G.add_edge("136", "9", weight=0)  
G.add_edge("136", "37", weight=0)  
G.add_edge("136", "46", weight=0)  
G.add_edge("136", "56", weight=0)  
G.add_edge("136", "64", weight=0)  
G.add_edge("136", "69", weight=0)  
G.add_edge("136", "80", weight=0)  
G.add_edge("136", "107", weight=0)  
G.add_edge("136", "111", weight=0)  
G.add_edge("136", "113", weight=0)  
G.add_edge("136", "116", weight=0)  
G.add_edge("136", "119", weight=0)  
G.add_edge("136", "127", weight=0)  
G.add_edge("136", "128", weight=0)  
G.add_edge("136", "130", weight=0)  
G.add_edge("136", "139", weight=0)  
G.add_edge("136", "142", weight=0)  
G.add_edge("136", "148", weight=0)  
G.add_edge("136", "152", weight=0)  
G.add_edge("136", "156", weight=0)  
G.add_edge("136", "158", weight=0)  
G.add_edge("136", "166", weight=0)  
G.add_edge("136", "171", weight=0)  
G.add_edge("136", "173", weight=0)  
G.add_edge("136", "175", weight=0)  
G.add_edge("136", "177", weight=1000)  
G.add_edge("137", "1", weight=0)  
G.add_edge("137", "2", weight=0)  
G.add_edge("137", "4", weight=0)  
G.add_edge("137", "6", weight=0)  
G.add_edge("137", "9", weight=0)  
G.add_edge("137", "17", weight=0)  
G.add_edge("137", "39", weight=0)  
G.add_edge("137", "40", weight=0)  
G.add_edge("137", "44", weight=0)  
G.add_edge("137", "48", weight=0)  
G.add_edge("137", "50", weight=0)  
G.add_edge("137", "55", weight=0)  
G.add_edge("137", "57", weight=0)  
G.add_edge("137", "59", weight=0)  
G.add_edge("137", "60", weight=0)  
G.add_edge("137", "62", weight=0)  
G.add_edge("137", "64", weight=0)  
G.add_edge("137", "66", weight=0)  
G.add_edge("137", "69", weight=0)  
G.add_edge("137", "70", weight=0)  
G.add_edge("137", "71", weight=0)  
G.add_edge("137", "74", weight=0)  
G.add_edge("137", "79", weight=0)  
G.add_edge("137", "85", weight=0)  
G.add_edge("137", "86", weight=0)  
G.add_edge("137", "95", weight=0)  
G.add_edge("137", "97", weight=0)  
G.add_edge("137", "103", weight=0)  
G.add_edge("137", "104", weight=0)  
G.add_edge("137", "107", weight=0)  
G.add_edge("137", "109", weight=0)  
G.add_edge("137", "111", weight=0)  
G.add_edge("137", "112", weight=0)  
G.add_edge("137", "113", weight=0)  
G.add_edge("137", "121", weight=0)  
G.add_edge("137", "127", weight=0)  
G.add_edge("137", "133", weight=0)  
G.add_edge("137", "134", weight=0)  
G.add_edge("137", "138", weight=0)  
G.add_edge("137", "139", weight=0)  
G.add_edge("137", "140", weight=0)  
G.add_edge("137", "142", weight=0)  
G.add_edge("137", "144", weight=0)  
G.add_edge("137", "146", weight=0)  
G.add_edge("137", "147", weight=0)  
G.add_edge("137", "148", weight=0)  
G.add_edge("137", "155", weight=0)  
G.add_edge("137", "170", weight=0)  
G.add_edge("137", "173", weight=0)  
G.add_edge("137", "174", weight=0)  
G.add_edge("137", "175", weight=0)  
G.add_edge("138", "1", weight=0)  
G.add_edge("138", "2", weight=0)  
G.add_edge("138", "6", weight=0)  
G.add_edge("138", "9", weight=0)  
G.add_edge("138", "10", weight=0)  
G.add_edge("138", "15", weight=0)  
G.add_edge("138", "16", weight=0)  
G.add_edge("138", "16", weight=0)  
G.add_edge("138", "17", weight=0)  
G.add_edge("138", "17", weight=0)  
G.add_edge("138", "24", weight=0)  
G.add_edge("138", "25", weight=0)  
G.add_edge("138", "28", weight=0)  
G.add_edge("138", "30", weight=1000)  
G.add_edge("138", "32", weight=0)  
G.add_edge("138", "35", weight=1000)  
G.add_edge("138", "39", weight=0)  
G.add_edge("138", "41", weight=99999)  
G.add_edge("138", "44", weight=0)  
G.add_edge("138", "46", weight=0)  
G.add_edge("138", "48", weight=0)  
G.add_edge("138", "49", weight=1000)  
G.add_edge("138", "51", weight=0)  
G.add_edge("138", "53", weight=0)  
G.add_edge("138", "60", weight=0)  
G.add_edge("138", "62", weight=0)  
G.add_edge("138", "64", weight=1000)  
G.add_edge("138", "66", weight=0)  
G.add_edge("138", "69", weight=0)  
G.add_edge("138", "70", weight=0)  
G.add_edge("138", "76", weight=1000)  
G.add_edge("138", "79", weight=0)  
G.add_edge("138", "84", weight=0)  
G.add_edge("138", "85", weight=0)  
G.add_edge("138", "86", weight=0)  
G.add_edge("138", "87", weight=0)  
G.add_edge("138", "99", weight=0)  
G.add_edge("138", "100", weight=0)  
G.add_edge("138", "107", weight=0)  
G.add_edge("138", "110", weight=0)  
G.add_edge("138", "111", weight=0)  
G.add_edge("138", "113", weight=0)  
G.add_edge("138", "118", weight=0)  
G.add_edge("138", "119", weight=0)  
G.add_edge("138", "122", weight=0)  
G.add_edge("138", "123", weight=0)  
G.add_edge("138", "126", weight=0)  
G.add_edge("138", "127", weight=0)  
G.add_edge("138", "129", weight=0)  
G.add_edge("138", "130", weight=0)  
G.add_edge("138", "131", weight=0)  
G.add_edge("138", "132", weight=0)  
G.add_edge("138", "137", weight=0)  
G.add_edge("138", "140", weight=0)  
G.add_edge("138", "142", weight=0)  
G.add_edge("138", "144", weight=0)  
G.add_edge("138", "148", weight=0)  
G.add_edge("138", "155", weight=0)  
G.add_edge("138", "164", weight=0)  
G.add_edge("138", "166", weight=0)  
G.add_edge("138", "170", weight=0)  
G.add_edge("138", "171", weight=0)  
G.add_edge("138", "174", weight=0)  
G.add_edge("138", "175", weight=0)  
G.add_edge("139", "1", weight=0)  
G.add_edge("139", "4", weight=0)  
G.add_edge("139", "6", weight=0)  
G.add_edge("139", "18", weight=0)  
G.add_edge("139", "34", weight=0)  
G.add_edge("139", "41", weight=0)  
G.add_edge("139", "48", weight=0)  
G.add_edge("139", "57", weight=0)  
G.add_edge("139", "59", weight=0)  
G.add_edge("139", "63", weight=0)  
G.add_edge("139", "66", weight=0)  
G.add_edge("139", "68", weight=0)  
G.add_edge("139", "69", weight=0)  
G.add_edge("139", "71", weight=0)  
G.add_edge("139", "72", weight=0)  
G.add_edge("139", "79", weight=0)  
G.add_edge("139", "83", weight=0)  
G.add_edge("139", "85", weight=0)  
G.add_edge("139", "87", weight=0)  
G.add_edge("139", "88", weight=0)  
G.add_edge("139", "95", weight=0)  
G.add_edge("139", "99", weight=0)  
G.add_edge("139", "100", weight=0)  
G.add_edge("139", "102", weight=0)  
G.add_edge("139", "103", weight=0)  
G.add_edge("139", "107", weight=0)  
G.add_edge("139", "112", weight=0)  
G.add_edge("139", "114", weight=0)  
G.add_edge("139", "116", weight=0)  
G.add_edge("139", "118", weight=0)  
G.add_edge("139", "122", weight=0)  
G.add_edge("139", "123", weight=0)  
G.add_edge("139", "127", weight=0)  
G.add_edge("139", "128", weight=0)  
G.add_edge("139", "130", weight=0)  
G.add_edge("139", "131", weight=0)  
G.add_edge("139", "132", weight=0)  
G.add_edge("139", "133", weight=0)  
G.add_edge("139", "135", weight=0)  
G.add_edge("139", "136", weight=0)  
G.add_edge("139", "137", weight=0)  
G.add_edge("139", "140", weight=0)  
G.add_edge("139", "142", weight=0)  
G.add_edge("139", "144", weight=0)  
G.add_edge("139", "145", weight=0)  
G.add_edge("139", "146", weight=0)  
G.add_edge("139", "147", weight=0)  
G.add_edge("139", "148", weight=0)  
G.add_edge("139", "149", weight=0)  
G.add_edge("139", "152", weight=0)  
G.add_edge("139", "154", weight=0)  
G.add_edge("139", "155", weight=0)  
G.add_edge("139", "156", weight=0)  
G.add_edge("139", "157", weight=0)  
G.add_edge("139", "158", weight=0)  
G.add_edge("139", "160", weight=0)  
G.add_edge("139", "163", weight=0)  
G.add_edge("139", "164", weight=0)  
G.add_edge("139", "165", weight=0)  
G.add_edge("139", "166", weight=0)  
G.add_edge("139", "168", weight=0)  
G.add_edge("139", "170", weight=0)  
G.add_edge("139", "171", weight=0)  
G.add_edge("139", "172", weight=0)  
G.add_edge("139", "173", weight=0)  
G.add_edge("139", "174", weight=0)  
G.add_edge("139", "175", weight=0)  
G.add_edge("139", "177", weight=0)  
G.add_edge("140", "1", weight=50)  
G.add_edge("140", "6", weight=50)  
G.add_edge("140", "9", weight=50)  
G.add_edge("140", "29", weight=50)  
G.add_edge("140", "34", weight=50)  
G.add_edge("140", "55", weight=100)  
G.add_edge("140", "57", weight=50)  
G.add_edge("140", "60", weight=1000)  
G.add_edge("140", "62", weight=500)  
G.add_edge("140", "63", weight=50)  
G.add_edge("140", "64", weight=100)  
G.add_edge("140", "70", weight=500)  
G.add_edge("140", "79", weight=50)  
G.add_edge("140", "82", weight=1000)  
G.add_edge("140", "84", weight=50)  
G.add_edge("140", "85", weight=50)  
G.add_edge("140", "94", weight=50)  
G.add_edge("140", "105", weight=100)  
G.add_edge("140", "107", weight=50)  
G.add_edge("140", "111", weight=50)  
G.add_edge("140", "114", weight=100)  
G.add_edge("140", "118", weight=50)  
G.add_edge("140", "120", weight=50)  
G.add_edge("140", "122", weight=50)  
G.add_edge("140", "124", weight=50)  
G.add_edge("140", "125", weight=50)  
G.add_edge("140", "126", weight=50)  
G.add_edge("140", "127", weight=50)  
G.add_edge("140", "128", weight=50)  
G.add_edge("140", "131", weight=0)  
G.add_edge("140", "135", weight=100)  
G.add_edge("140", "137", weight=50)  
G.add_edge("140", "138", weight=50)  
G.add_edge("140", "139", weight=50)  
G.add_edge("140", "142", weight=50)  
G.add_edge("140", "144", weight=50)  
G.add_edge("140", "151", weight=50)  
G.add_edge("140", "154", weight=50)  
G.add_edge("140", "156", weight=50)  
G.add_edge("140", "160", weight=100)  
G.add_edge("140", "170", weight=50)  
G.add_edge("140", "173", weight=50)  
G.add_edge("140", "174", weight=500)  
G.add_edge("140", "175", weight=100)  
G.add_edge("141", "0", weight=0)  
G.add_edge("141", "3", weight=0)  
G.add_edge("141", "7", weight=0)  
G.add_edge("141", "29", weight=0)  
G.add_edge("141", "69", weight=0)  
G.add_edge("141", "74", weight=0)  
G.add_edge("141", "97", weight=0)  
G.add_edge("141", "100", weight=0)  
G.add_edge("141", "103", weight=0)  
G.add_edge("141", "114", weight=0)  
G.add_edge("141", "115", weight=0)  
G.add_edge("141", "128", weight=0)  
G.add_edge("141", "130", weight=0)  
G.add_edge("141", "132", weight=0)  
G.add_edge("141", "146", weight=0)  
G.add_edge("141", "159", weight=0)  
G.add_edge("141", "165", weight=0)  
G.add_edge("141", "167", weight=0)  
G.add_edge("141", "169", weight=0)  
G.add_edge("142", "1", weight=1312)  
G.add_edge("142", "4", weight=1864)  
G.add_edge("142", "6", weight=210)  
G.add_edge("142", "6", weight=210)  
G.add_edge("142", "8", weight=210)  
G.add_edge("142", "9", weight=229)  
G.add_edge("142", "10", weight=210)  
G.add_edge("142", "11", weight=210)  
G.add_edge("142", "13", weight=210)  
G.add_edge("142", "14", weight=210)  
G.add_edge("142", "15", weight=210)  
G.add_edge("142", "16", weight=210)  
G.add_edge("142", "17", weight=210)  
G.add_edge("142", "18", weight=457)  
G.add_edge("142", "19", weight=210)  
G.add_edge("142", "22", weight=210)  
G.add_edge("142", "24", weight=216)  
G.add_edge("142", "27", weight=210)  
G.add_edge("142", "29", weight=210)  
G.add_edge("142", "31", weight=210)  
G.add_edge("142", "32", weight=210)  
G.add_edge("142", "35", weight=216)  
G.add_edge("142", "37", weight=957)  
G.add_edge("142", "38", weight=243)  
G.add_edge("142", "39", weight=210)  
G.add_edge("142", "41", weight=210)  
G.add_edge("142", "44", weight=210)  
G.add_edge("142", "45", weight=210)  
G.add_edge("142", "46", weight=210)  
G.add_edge("142", "47", weight=1659)  
G.add_edge("142", "48", weight=1119)  
G.add_edge("142", "49", weight=210)  
G.add_edge("142", "50", weight=210)  
G.add_edge("142", "51", weight=210)  
G.add_edge("142", "52", weight=210)  
G.add_edge("142", "53", weight=210)  
G.add_edge("142", "54", weight=7647)  
G.add_edge("142", "55", weight=210)  
G.add_edge("142", "56", weight=210)  
G.add_edge("142", "57", weight=1702)  
G.add_edge("142", "59", weight=216)  
G.add_edge("142", "62", weight=643)  
G.add_edge("142", "63", weight=522)  
G.add_edge("142", "64", weight=210)  
G.add_edge("142", "65", weight=223)  
G.add_edge("142", "66", weight=1694)  
G.add_edge("142", "68", weight=8808)  
G.add_edge("142", "69", weight=221)  
G.add_edge("142", "70", weight=210)  
G.add_edge("142", "71", weight=210)  
G.add_edge("142", "72", weight=210)  
G.add_edge("142", "74", weight=210)  
G.add_edge("142", "76", weight=210)  
G.add_edge("142", "77", weight=210)  
G.add_edge("142", "79", weight=236)  
G.add_edge("142", "79", weight=236)  
G.add_edge("142", "83", weight=1336)  
G.add_edge("142", "85", weight=210)  
G.add_edge("142", "87", weight=210)  
G.add_edge("142", "88", weight=210)  
G.add_edge("142", "89", weight=708)  
G.add_edge("142", "91", weight=210)  
G.add_edge("142", "93", weight=210)  
G.add_edge("142", "94", weight=621)  
G.add_edge("142", "95", weight=210)  
G.add_edge("142", "97", weight=210)  
G.add_edge("142", "99", weight=288)  
G.add_edge("142", "102", weight=243)  
G.add_edge("142", "103", weight=210)  
G.add_edge("142", "104", weight=297)  
G.add_edge("142", "105", weight=210)  
G.add_edge("142", "106", weight=288)  
G.add_edge("142", "107", weight=210)  
G.add_edge("142", "108", weight=234)  
G.add_edge("142", "109", weight=210)  
G.add_edge("142", "110", weight=210)  
G.add_edge("142", "111", weight=210)  
G.add_edge("142", "112", weight=210)  
G.add_edge("142", "113", weight=300)  
G.add_edge("142", "114", weight=210)  
G.add_edge("142", "116", weight=222)  
G.add_edge("142", "118", weight=1342)  
G.add_edge("142", "119", weight=5038)  
G.add_edge("142", "120", weight=210)  
G.add_edge("142", "121", weight=210)  
G.add_edge("142", "122", weight=210)  
G.add_edge("142", "123", weight=210)  
G.add_edge("142", "124", weight=210)  
G.add_edge("142", "125", weight=210)  
G.add_edge("142", "126", weight=243)  
G.add_edge("142", "127", weight=6932)  
G.add_edge("142", "128", weight=210)  
G.add_edge("142", "129", weight=462)  
G.add_edge("142", "130", weight=297)  
G.add_edge("142", "131", weight=210)  
G.add_edge("142", "132", weight=2909)  
G.add_edge("142", "134", weight=216)  
G.add_edge("142", "136", weight=501)  
G.add_edge("142", "137", weight=5934)  
G.add_edge("142", "138", weight=14157)  
G.add_edge("142", "139", weight=297)  
G.add_edge("142", "140", weight=210)  
G.add_edge("142", "143", weight=210)  
G.add_edge("142", "144", weight=9804)  
G.add_edge("142", "146", weight=210)  
G.add_edge("142", "147", weight=300)  
G.add_edge("142", "148", weight=210)  
G.add_edge("142", "149", weight=210)  
G.add_edge("142", "151", weight=210)  
G.add_edge("142", "152", weight=210)  
G.add_edge("142", "154", weight=486)  
G.add_edge("142", "155", weight=977)  
G.add_edge("142", "156", weight=210)  
G.add_edge("142", "157", weight=236)  
G.add_edge("142", "157", weight=236)  
G.add_edge("142", "158", weight=789)  
G.add_edge("142", "160", weight=210)  
G.add_edge("142", "161", weight=210)  
G.add_edge("142", "163", weight=210)  
G.add_edge("142", "164", weight=315)  
G.add_edge("142", "165", weight=210)  
G.add_edge("142", "166", weight=4073)  
G.add_edge("142", "168", weight=210)  
G.add_edge("142", "170", weight=472)  
G.add_edge("142", "172", weight=210)  
G.add_edge("142", "173", weight=210)  
G.add_edge("142", "174", weight=486)  
G.add_edge("142", "175", weight=3976)  
G.add_edge("142", "177", weight=1687)  
G.add_edge("143", "9", weight=1000)  
G.add_edge("143", "31", weight=100)  
G.add_edge("143", "35", weight=100)  
G.add_edge("143", "40", weight=100)  
G.add_edge("143", "42", weight=1000)  
G.add_edge("143", "45", weight=1000)  
G.add_edge("143", "54", weight=1000)  
G.add_edge("143", "56", weight=1000)  
G.add_edge("143", "57", weight=100)  
G.add_edge("143", "58", weight=1000)  
G.add_edge("143", "62", weight=1000)  
G.add_edge("143", "64", weight=1000)  
G.add_edge("143", "66", weight=1000)  
G.add_edge("143", "72", weight=1000)  
G.add_edge("143", "75", weight=1000)  
G.add_edge("143", "76", weight=1000)  
G.add_edge("143", "77", weight=1000)  
G.add_edge("143", "79", weight=1000)  
G.add_edge("143", "82", weight=1000)  
G.add_edge("143", "88", weight=1000)  
G.add_edge("143", "90", weight=1000)  
G.add_edge("143", "97", weight=1000)  
G.add_edge("143", "105", weight=1000)  
G.add_edge("143", "109", weight=1000)  
G.add_edge("143", "113", weight=100)  
G.add_edge("143", "115", weight=1000)  
G.add_edge("143", "126", weight=100)  
G.add_edge("143", "127", weight=1000)  
G.add_edge("143", "130", weight=1000)  
G.add_edge("143", "131", weight=1000)  
G.add_edge("143", "142", weight=1000)  
G.add_edge("143", "151", weight=1000)  
G.add_edge("143", "153", weight=100)  
G.add_edge("143", "154", weight=1000)  
G.add_edge("143", "159", weight=1000)  
G.add_edge("143", "166", weight=1000)  
G.add_edge("143", "168", weight=1000)  
G.add_edge("143", "174", weight=1000)  
G.add_edge("144", "4", weight=0)  
G.add_edge("144", "6", weight=0)  
G.add_edge("144", "9", weight=0)  
G.add_edge("144", "31", weight=0)  
G.add_edge("144", "34", weight=0)  
G.add_edge("144", "35", weight=0)  
G.add_edge("144", "37", weight=0)  
G.add_edge("144", "39", weight=0)  
G.add_edge("144", "45", weight=0)  
G.add_edge("144", "52", weight=0)  
G.add_edge("144", "62", weight=0)  
G.add_edge("144", "63", weight=0)  
G.add_edge("144", "64", weight=0)  
G.add_edge("144", "66", weight=0)  
G.add_edge("144", "67", weight=0)  
G.add_edge("144", "70", weight=0)  
G.add_edge("144", "79", weight=0)  
G.add_edge("144", "87", weight=0)  
G.add_edge("144", "101", weight=0)  
G.add_edge("144", "103", weight=0)  
G.add_edge("144", "107", weight=0)  
G.add_edge("144", "113", weight=0)  
G.add_edge("144", "114", weight=0)  
G.add_edge("144", "116", weight=0)  
G.add_edge("144", "124", weight=0)  
G.add_edge("144", "125", weight=0)  
G.add_edge("144", "127", weight=0)  
G.add_edge("144", "132", weight=0)  
G.add_edge("144", "135", weight=0)  
G.add_edge("144", "137", weight=0)  
G.add_edge("144", "138", weight=0)  
G.add_edge("144", "139", weight=0)  
G.add_edge("144", "140", weight=0)  
G.add_edge("144", "142", weight=0)  
G.add_edge("144", "145", weight=0)  
G.add_edge("144", "146", weight=0)  
G.add_edge("144", "154", weight=0)  
G.add_edge("144", "166", weight=0)  
G.add_edge("144", "168", weight=0)  
G.add_edge("144", "175", weight=0)  
G.add_edge("144", "177", weight=0)  
G.add_edge("145", "1", weight=0)  
G.add_edge("145", "18", weight=0)  
G.add_edge("145", "27", weight=0)  
G.add_edge("145", "53", weight=0)  
G.add_edge("145", "53", weight=0)  
G.add_edge("145", "57", weight=0)  
G.add_edge("145", "61", weight=0)  
G.add_edge("145", "62", weight=0)  
G.add_edge("145", "63", weight=0)  
G.add_edge("145", "64", weight=0)  
G.add_edge("145", "67", weight=0)  
G.add_edge("145", "70", weight=0)  
G.add_edge("145", "70", weight=0)  
G.add_edge("145", "79", weight=0)  
G.add_edge("145", "80", weight=0)  
G.add_edge("145", "85", weight=0)  
G.add_edge("145", "101", weight=0)  
G.add_edge("145", "102", weight=0)  
G.add_edge("145", "107", weight=0)  
G.add_edge("145", "113", weight=0)  
G.add_edge("145", "116", weight=0)  
G.add_edge("145", "122", weight=0)  
G.add_edge("145", "124", weight=0)  
G.add_edge("145", "125", weight=0)  
G.add_edge("145", "128", weight=0)  
G.add_edge("145", "129", weight=0)  
G.add_edge("145", "133", weight=0)  
G.add_edge("145", "134", weight=0)  
G.add_edge("145", "139", weight=0)  
G.add_edge("145", "144", weight=0)  
G.add_edge("145", "147", weight=0)  
G.add_edge("145", "148", weight=0)  
G.add_edge("145", "149", weight=0)  
G.add_edge("145", "151", weight=0)  
G.add_edge("145", "152", weight=0)  
G.add_edge("145", "154", weight=0)  
G.add_edge("145", "155", weight=0)  
G.add_edge("145", "156", weight=0)  
G.add_edge("145", "157", weight=0)  
G.add_edge("145", "160", weight=0)  
G.add_edge("145", "163", weight=0)  
G.add_edge("145", "164", weight=0)  
G.add_edge("145", "166", weight=0)  
G.add_edge("145", "171", weight=0)  
G.add_edge("145", "172", weight=0)  
G.add_edge("145", "173", weight=0)  
G.add_edge("146", "1", weight=2000)  
G.add_edge("146", "2", weight=2000)  
G.add_edge("146", "4", weight=3000)  
G.add_edge("146", "5", weight=2000)  
G.add_edge("146", "6", weight=2000)  
G.add_edge("146", "9", weight=2000)  
G.add_edge("146", "16", weight=0)  
G.add_edge("146", "27", weight=0)  
G.add_edge("146", "31", weight=0)  
G.add_edge("146", "35", weight=0)  
G.add_edge("146", "36", weight=0)  
G.add_edge("146", "40", weight=2000)  
G.add_edge("146", "44", weight=0)  
G.add_edge("146", "45", weight=2000)  
G.add_edge("146", "46", weight=0)  
G.add_edge("146", "48", weight=3000)  
G.add_edge("146", "49", weight=0)  
G.add_edge("146", "51", weight=0)  
G.add_edge("146", "55", weight=0)  
G.add_edge("146", "56", weight=2000)  
G.add_edge("146", "57", weight=2000)  
G.add_edge("146", "61", weight=2000)  
G.add_edge("146", "62", weight=3000)  
G.add_edge("146", "65", weight=2000)  
G.add_edge("146", "67", weight=2000)  
G.add_edge("146", "70", weight=3000)  
G.add_edge("146", "71", weight=0)  
G.add_edge("146", "72", weight=2000)  
G.add_edge("146", "77", weight=0)  
G.add_edge("146", "78", weight=2000)  
G.add_edge("146", "79", weight=0)  
G.add_edge("146", "80", weight=0)  
G.add_edge("146", "81", weight=0)  
G.add_edge("146", "85", weight=2000)  
G.add_edge("146", "89", weight=2000)  
G.add_edge("146", "90", weight=2000)  
G.add_edge("146", "91", weight=0)  
G.add_edge("146", "92", weight=2000)  
G.add_edge("146", "95", weight=0)  
G.add_edge("146", "99", weight=2000)  
G.add_edge("146", "100", weight=0)  
G.add_edge("146", "104", weight=2000)  
G.add_edge("146", "107", weight=3000)  
G.add_edge("146", "108", weight=0)  
G.add_edge("146", "111", weight=2000)  
G.add_edge("146", "112", weight=0)  
G.add_edge("146", "113", weight=2000)  
G.add_edge("146", "114", weight=2000)  
G.add_edge("146", "120", weight=2000)  
G.add_edge("146", "121", weight=2000)  
G.add_edge("146", "122", weight=2000)  
G.add_edge("146", "122", weight=2000)  
G.add_edge("146", "126", weight=0)  
G.add_edge("146", "127", weight=2000)  
G.add_edge("146", "128", weight=2000)  
G.add_edge("146", "129", weight=2000)  
G.add_edge("146", "131", weight=0)  
G.add_edge("146", "137", weight=2000)  
G.add_edge("146", "139", weight=2000)  
G.add_edge("146", "141", weight=0)  
G.add_edge("146", "142", weight=2000)  
G.add_edge("146", "144", weight=0)  
G.add_edge("146", "148", weight=2000)  
G.add_edge("146", "154", weight=2000)  
G.add_edge("146", "156", weight=2000)  
G.add_edge("146", "158", weight=2000)  
G.add_edge("146", "160", weight=2000)  
G.add_edge("146", "161", weight=0)  
G.add_edge("146", "162", weight=0)  
G.add_edge("146", "163", weight=2000)  
G.add_edge("146", "165", weight=2000)  
G.add_edge("146", "166", weight=2000)  
G.add_edge("147", "1", weight=999)  
G.add_edge("147", "4", weight=999)  
G.add_edge("147", "5", weight=500)  
G.add_edge("147", "6", weight=999)  
G.add_edge("147", "18", weight=0)  
G.add_edge("147", "33", weight=999)  
G.add_edge("147", "35", weight=0)  
G.add_edge("147", "39", weight=500)  
G.add_edge("147", "40", weight=0)  
G.add_edge("147", "41", weight=500)  
G.add_edge("147", "44", weight=999)  
G.add_edge("147", "46", weight=0)  
G.add_edge("147", "48", weight=999)  
G.add_edge("147", "49", weight=500)  
G.add_edge("147", "51", weight=500)  
G.add_edge("147", "52", weight=500)  
G.add_edge("147", "53", weight=500)  
G.add_edge("147", "57", weight=999)  
G.add_edge("147", "59", weight=999)  
G.add_edge("147", "62", weight=0)  
G.add_edge("147", "63", weight=500)  
G.add_edge("147", "64", weight=999)  
G.add_edge("147", "66", weight=999)  
G.add_edge("147", "67", weight=0)  
G.add_edge("147", "68", weight=500)  
G.add_edge("147", "69", weight=500)  
G.add_edge("147", "70", weight=999)  
G.add_edge("147", "71", weight=500)  
G.add_edge("147", "72", weight=0)  
G.add_edge("147", "74", weight=250)  
G.add_edge("147", "75", weight=999)  
G.add_edge("147", "79", weight=999)  
G.add_edge("147", "85", weight=999)  
G.add_edge("147", "87", weight=0)  
G.add_edge("147", "88", weight=0)  
G.add_edge("147", "92", weight=999)  
G.add_edge("147", "95", weight=999)  
G.add_edge("147", "99", weight=250)  
G.add_edge("147", "102", weight=250)  
G.add_edge("147", "103", weight=0)  
G.add_edge("147", "105", weight=0)  
G.add_edge("147", "107", weight=999)  
G.add_edge("147", "113", weight=0)  
G.add_edge("147", "118", weight=500)  
G.add_edge("147", "121", weight=0)  
G.add_edge("147", "123", weight=999)  
G.add_edge("147", "128", weight=250)  
G.add_edge("147", "130", weight=999)  
G.add_edge("147", "134", weight=250)  
G.add_edge("147", "135", weight=999)  
G.add_edge("147", "137", weight=999)  
G.add_edge("147", "139", weight=999)  
G.add_edge("147", "142", weight=999)  
G.add_edge("147", "145", weight=999)  
G.add_edge("147", "151", weight=250)  
G.add_edge("147", "154", weight=0)  
G.add_edge("147", "156", weight=0)  
G.add_edge("147", "163", weight=250)  
G.add_edge("147", "164", weight=250)  
G.add_edge("147", "166", weight=500)  
G.add_edge("147", "168", weight=999)  
G.add_edge("147", "170", weight=999)  
G.add_edge("147", "171", weight=250)  
G.add_edge("147", "175", weight=999)  
G.add_edge("147", "176", weight=500)  
G.add_edge("148", "9", weight=1000)  
G.add_edge("148", "63", weight=1000)  
G.add_edge("148", "64", weight=1000)  
G.add_edge("148", "80", weight=1000)  
G.add_edge("148", "94", weight=1000)  
G.add_edge("148", "102", weight=1000)  
G.add_edge("148", "107", weight=1000)  
G.add_edge("148", "116", weight=1000)  
G.add_edge("148", "120", weight=1000)  
G.add_edge("148", "122", weight=100080)  
G.add_edge("148", "123", weight=1000)  
G.add_edge("148", "124", weight=1000)  
G.add_edge("148", "128", weight=1000)  
G.add_edge("148", "132", weight=1000)  
G.add_edge("148", "133", weight=1000)  
G.add_edge("148", "134", weight=1000)  
G.add_edge("148", "136", weight=1000)  
G.add_edge("148", "137", weight=1000)  
G.add_edge("148", "138", weight=1000)  
G.add_edge("148", "139", weight=1000)  
G.add_edge("148", "142", weight=1000)  
G.add_edge("148", "145", weight=1000)  
G.add_edge("148", "146", weight=1000)  
G.add_edge("148", "149", weight=1000)  
G.add_edge("148", "152", weight=1000)  
G.add_edge("148", "154", weight=1000)  
G.add_edge("148", "155", weight=1000)  
G.add_edge("148", "156", weight=1000)  
G.add_edge("148", "157", weight=1000)  
G.add_edge("148", "160", weight=1000)  
G.add_edge("148", "163", weight=1000)  
G.add_edge("148", "164", weight=1000)  
G.add_edge("148", "166", weight=1000)  
G.add_edge("148", "171", weight=1000)  
G.add_edge("148", "173", weight=1000)  
G.add_edge("148", "174", weight=1000)  
G.add_edge("149", "21", weight=0)  
G.add_edge("149", "70", weight=0)  
G.add_edge("149", "85", weight=1000)  
G.add_edge("149", "99", weight=2000)  
G.add_edge("149", "102", weight=1000)  
G.add_edge("149", "107", weight=2000)  
G.add_edge("149", "112", weight=0)  
G.add_edge("149", "113", weight=1000)  
G.add_edge("149", "116", weight=2000)  
G.add_edge("149", "124", weight=1000)  
G.add_edge("149", "125", weight=2000)  
G.add_edge("149", "128", weight=1000)  
G.add_edge("149", "139", weight=2000)  
G.add_edge("149", "142", weight=1000)  
G.add_edge("149", "145", weight=0)  
G.add_edge("149", "148", weight=2000)  
G.add_edge("149", "151", weight=2000)  
G.add_edge("149", "156", weight=0)  
G.add_edge("149", "157", weight=0)  
G.add_edge("149", "158", weight=2000)  
G.add_edge("149", "160", weight=0)  
G.add_edge("149", "163", weight=2000)  
G.add_edge("149", "166", weight=1000)  
G.add_edge("149", "171", weight=2000)  
G.add_edge("149", "172", weight=0)  
G.add_edge("149", "173", weight=0)  
G.add_edge("149", "175", weight=0)  
G.add_edge("150", "0", weight=0)  
G.add_edge("150", "3", weight=0)  
G.add_edge("150", "7", weight=0)  
G.add_edge("150", "27", weight=0)  
G.add_edge("150", "38", weight=0)  
G.add_edge("150", "39", weight=0)  
G.add_edge("150", "97", weight=0)  
G.add_edge("150", "114", weight=0)  
G.add_edge("150", "115", weight=0)  
G.add_edge("150", "126", weight=0)  
G.add_edge("150", "128", weight=0)  
G.add_edge("150", "162", weight=0)  
G.add_edge("150", "169", weight=0)  
G.add_edge("151", "0", weight=1000)  
G.add_edge("151", "3", weight=888)  
G.add_edge("151", "6", weight=1000)  
G.add_edge("151", "9", weight=1000)  
G.add_edge("151", "57", weight=1000)  
G.add_edge("151", "63", weight=1000)  
G.add_edge("151", "69", weight=1000)  
G.add_edge("151", "70", weight=1000)  
G.add_edge("151", "72", weight=1000)  
G.add_edge("151", "76", weight=1000)  
G.add_edge("151", "77", weight=1000)  
G.add_edge("151", "79", weight=1000)  
G.add_edge("151", "80", weight=1000)  
G.add_edge("151", "85", weight=1000)  
G.add_edge("151", "101", weight=1000)  
G.add_edge("151", "107", weight=1000)  
G.add_edge("151", "112", weight=1000)  
G.add_edge("151", "113", weight=1000)  
G.add_edge("151", "116", weight=1000)  
G.add_edge("151", "122", weight=1000)  
G.add_edge("151", "124", weight=1000)  
G.add_edge("151", "129", weight=1000)  
G.add_edge("151", "134", weight=1000)  
G.add_edge("151", "140", weight=1000)  
G.add_edge("151", "142", weight=1000)  
G.add_edge("151", "143", weight=1000)  
G.add_edge("151", "145", weight=1000)  
G.add_edge("151", "147", weight=1000)  
G.add_edge("151", "149", weight=1000)  
G.add_edge("151", "154", weight=1000)  
G.add_edge("151", "157", weight=1000)  
G.add_edge("151", "158", weight=1000)  
G.add_edge("151", "160", weight=1000)  
G.add_edge("151", "163", weight=1000)  
G.add_edge("151", "166", weight=1000)  
G.add_edge("151", "173", weight=1000)  
G.add_edge("151", "174", weight=1000)  
G.add_edge("152", "1", weight=1000)  
G.add_edge("152", "18", weight=1000)  
G.add_edge("152", "72", weight=1000)  
G.add_edge("152", "78", weight=1000)  
G.add_edge("152", "79", weight=1000)  
G.add_edge("152", "80", weight=1000)  
G.add_edge("152", "85", weight=1000)  
G.add_edge("152", "99", weight=1000)  
G.add_edge("152", "102", weight=1000)  
G.add_edge("152", "103", weight=1000)  
G.add_edge("152", "107", weight=1000)  
G.add_edge("152", "126", weight=1000)  
G.add_edge("152", "128", weight=1000)  
G.add_edge("152", "129", weight=1000)  
G.add_edge("152", "136", weight=500)  
G.add_edge("152", "139", weight=1000)  
G.add_edge("152", "142", weight=1000)  
G.add_edge("152", "145", weight=500)  
G.add_edge("152", "148", weight=1000)  
G.add_edge("152", "154", weight=1000)  
G.add_edge("152", "156", weight=1000)  
G.add_edge("152", "157", weight=1000)  
G.add_edge("152", "158", weight=1000)  
G.add_edge("152", "163", weight=1000)  
G.add_edge("152", "164", weight=1000)  
G.add_edge("152", "166", weight=1000)  
G.add_edge("153", "4", weight=1000)  
G.add_edge("153", "6", weight=3000)  
G.add_edge("153", "107", weight=1000)  
G.add_edge("153", "108", weight=1000)  
G.add_edge("153", "110", weight=1000)  
G.add_edge("153", "116", weight=3000)  
G.add_edge("153", "132", weight=1000)  
G.add_edge("153", "134", weight=1000)  
G.add_edge("153", "143", weight=1000)  
G.add_edge("153", "166", weight=1000)  
G.add_edge("154", "1", weight=0)  
G.add_edge("154", "4", weight=0)  
G.add_edge("154", "6", weight=5000)  
G.add_edge("154", "8", weight=0)  
G.add_edge("154", "18", weight=0)  
G.add_edge("154", "25", weight=5000)  
G.add_edge("154", "31", weight=0)  
G.add_edge("154", "41", weight=0)  
G.add_edge("154", "44", weight=0)  
G.add_edge("154", "57", weight=0)  
G.add_edge("154", "59", weight=0)  
G.add_edge("154", "64", weight=0)  
G.add_edge("154", "66", weight=0)  
G.add_edge("154", "67", weight=0)  
G.add_edge("154", "70", weight=1000)  
G.add_edge("154", "79", weight=5000)  
G.add_edge("154", "80", weight=0)  
G.add_edge("154", "85", weight=1000)  
G.add_edge("154", "87", weight=0)  
G.add_edge("154", "95", weight=0)  
G.add_edge("154", "99", weight=0)  
G.add_edge("154", "104", weight=1000)  
G.add_edge("154", "107", weight=0)  
G.add_edge("154", "112", weight=0)  
G.add_edge("154", "113", weight=0)  
G.add_edge("154", "114", weight=0)  
G.add_edge("154", "116", weight=0)  
G.add_edge("154", "122", weight=0)  
G.add_edge("154", "123", weight=0)  
G.add_edge("154", "124", weight=0)  
G.add_edge("154", "125", weight=0)  
G.add_edge("154", "126", weight=0)  
G.add_edge("154", "127", weight=0)  
G.add_edge("154", "128", weight=0)  
G.add_edge("154", "129", weight=0)  
G.add_edge("154", "130", weight=0)  
G.add_edge("154", "139", weight=0)  
G.add_edge("154", "140", weight=0)  
G.add_edge("154", "142", weight=0)  
G.add_edge("154", "143", weight=0)  
G.add_edge("154", "144", weight=0)  
G.add_edge("154", "145", weight=0)  
G.add_edge("154", "146", weight=0)  
G.add_edge("154", "147", weight=0)  
G.add_edge("154", "148", weight=0)  
G.add_edge("154", "151", weight=0)  
G.add_edge("154", "152", weight=0)  
G.add_edge("154", "156", weight=0)  
G.add_edge("154", "160", weight=0)  
G.add_edge("154", "163", weight=0)  
G.add_edge("154", "164", weight=0)  
G.add_edge("154", "166", weight=0)  
G.add_edge("154", "170", weight=0)  
G.add_edge("154", "171", weight=0)  
G.add_edge("155", "0", weight=1)  
G.add_edge("155", "1", weight=1)  
G.add_edge("155", "36", weight=1)  
G.add_edge("155", "45", weight=1)  
G.add_edge("155", "46", weight=1)  
G.add_edge("155", "46", weight=1)  
G.add_edge("155", "55", weight=10)  
G.add_edge("155", "66", weight=10)  
G.add_edge("155", "67", weight=1)  
G.add_edge("155", "69", weight=1)  
G.add_edge("155", "70", weight=10)  
G.add_edge("155", "72", weight=1)  
G.add_edge("155", "74", weight=10)  
G.add_edge("155", "79", weight=10)  
G.add_edge("155", "80", weight=1)  
G.add_edge("155", "82", weight=1)  
G.add_edge("155", "84", weight=10)  
G.add_edge("155", "85", weight=1)  
G.add_edge("155", "100", weight=10)  
G.add_edge("155", "103", weight=1)  
G.add_edge("155", "107", weight=10)  
G.add_edge("155", "113", weight=10)  
G.add_edge("155", "117", weight=1)  
G.add_edge("155", "121", weight=10)  
G.add_edge("155", "127", weight=1)  
G.add_edge("155", "131", weight=10)  
G.add_edge("155", "134", weight=10)  
G.add_edge("155", "137", weight=1)  
G.add_edge("155", "138", weight=10)  
G.add_edge("155", "139", weight=10)  
G.add_edge("155", "142", weight=10)  
G.add_edge("155", "145", weight=10)  
G.add_edge("155", "148", weight=1)  
G.add_edge("155", "157", weight=1)  
G.add_edge("155", "158", weight=1)  
G.add_edge("155", "164", weight=10)  
G.add_edge("155", "173", weight=1)  
G.add_edge("155", "175", weight=1)  
G.add_edge("156", "4", weight=0)  
G.add_edge("156", "34", weight=0)  
G.add_edge("156", "39", weight=0)  
G.add_edge("156", "45", weight=0)  
G.add_edge("156", "48", weight=0)  
G.add_edge("156", "55", weight=0)  
G.add_edge("156", "59", weight=0)  
G.add_edge("156", "64", weight=0)  
G.add_edge("156", "67", weight=0)  
G.add_edge("156", "79", weight=0)  
G.add_edge("156", "82", weight=0)  
G.add_edge("156", "88", weight=0)  
G.add_edge("156", "95", weight=0)  
G.add_edge("156", "102", weight=0)  
G.add_edge("156", "104", weight=0)  
G.add_edge("156", "107", weight=0)  
G.add_edge("156", "108", weight=0)  
G.add_edge("156", "112", weight=0)  
G.add_edge("156", "113", weight=0)  
G.add_edge("156", "116", weight=0)  
G.add_edge("156", "120", weight=0)  
G.add_edge("156", "121", weight=0)  
G.add_edge("156", "122", weight=0)  
G.add_edge("156", "123", weight=0)  
G.add_edge("156", "128", weight=0)  
G.add_edge("156", "131", weight=5000)  
G.add_edge("156", "132", weight=0)  
G.add_edge("156", "136", weight=0)  
G.add_edge("156", "139", weight=0)  
G.add_edge("156", "140", weight=0)  
G.add_edge("156", "142", weight=0)  
G.add_edge("156", "145", weight=0)  
G.add_edge("156", "146", weight=0)  
G.add_edge("156", "147", weight=0)  
G.add_edge("156", "148", weight=0)  
G.add_edge("156", "149", weight=0)  
G.add_edge("156", "152", weight=0)  
G.add_edge("156", "154", weight=0)  
G.add_edge("156", "157", weight=0)  
G.add_edge("156", "158", weight=0)  
G.add_edge("156", "160", weight=0)  
G.add_edge("156", "163", weight=0)  
G.add_edge("156", "164", weight=0)  
G.add_edge("156", "166", weight=0)  
G.add_edge("156", "168", weight=0)  
G.add_edge("156", "170", weight=0)  
G.add_edge("156", "171", weight=0)  
G.add_edge("156", "174", weight=0)  
G.add_edge("156", "175", weight=0)  
G.add_edge("156", "176", weight=0)  
G.add_edge("157", "1", weight=0)  
G.add_edge("157", "8", weight=0)  
G.add_edge("157", "9", weight=0)  
G.add_edge("157", "10", weight=0)  
G.add_edge("157", "35", weight=0)  
G.add_edge("157", "42", weight=0)  
G.add_edge("157", "57", weight=0)  
G.add_edge("157", "66", weight=0)  
G.add_edge("157", "67", weight=0)  
G.add_edge("157", "80", weight=0)  
G.add_edge("157", "84", weight=0)  
G.add_edge("157", "85", weight=0)  
G.add_edge("157", "87", weight=0)  
G.add_edge("157", "102", weight=0)  
G.add_edge("157", "107", weight=0)  
G.add_edge("157", "111", weight=0)  
G.add_edge("157", "113", weight=0)  
G.add_edge("157", "116", weight=0)  
G.add_edge("157", "127", weight=0)  
G.add_edge("157", "128", weight=0)  
G.add_edge("157", "133", weight=0)  
G.add_edge("157", "135", weight=0)  
G.add_edge("157", "139", weight=0)  
G.add_edge("157", "142", weight=0)  
G.add_edge("157", "142", weight=0)  
G.add_edge("157", "145", weight=0)  
G.add_edge("157", "148", weight=0)  
G.add_edge("157", "149", weight=0)  
G.add_edge("157", "151", weight=0)  
G.add_edge("157", "152", weight=0)  
G.add_edge("157", "155", weight=0)  
G.add_edge("157", "156", weight=0)  
G.add_edge("157", "158", weight=0)  
G.add_edge("157", "160", weight=0)  
G.add_edge("157", "163", weight=0)  
G.add_edge("157", "164", weight=0)  
G.add_edge("157", "165", weight=0)  
G.add_edge("157", "166", weight=0)  
G.add_edge("157", "170", weight=0)  
G.add_edge("157", "172", weight=0)  
G.add_edge("157", "173", weight=0)  
G.add_edge("157", "177", weight=0)  
G.add_edge("158", "6", weight=0)  
G.add_edge("158", "9", weight=0)  
G.add_edge("158", "58", weight=0)  
G.add_edge("158", "79", weight=0)  
G.add_edge("158", "80", weight=0)  
G.add_edge("158", "83", weight=0)  
G.add_edge("158", "87", weight=0)  
G.add_edge("158", "102", weight=0)  
G.add_edge("158", "107", weight=0)  
G.add_edge("158", "122", weight=0)  
G.add_edge("158", "127", weight=0)  
G.add_edge("158", "132", weight=0)  
G.add_edge("158", "136", weight=0)  
G.add_edge("158", "139", weight=0)  
G.add_edge("158", "142", weight=0)  
G.add_edge("158", "146", weight=0)  
G.add_edge("158", "149", weight=0)  
G.add_edge("158", "151", weight=0)  
G.add_edge("158", "152", weight=0)  
G.add_edge("158", "155", weight=0)  
G.add_edge("158", "156", weight=0)  
G.add_edge("158", "157", weight=0)  
G.add_edge("158", "160", weight=0)  
G.add_edge("158", "166", weight=0)  
G.add_edge("158", "173", weight=0)  
G.add_edge("159", "0", weight=0)  
G.add_edge("159", "3", weight=0)  
G.add_edge("159", "7", weight=0)  
G.add_edge("159", "27", weight=0)  
G.add_edge("159", "39", weight=0)  
G.add_edge("159", "58", weight=0)  
G.add_edge("159", "60", weight=0)  
G.add_edge("159", "97", weight=0)  
G.add_edge("159", "100", weight=0)  
G.add_edge("159", "114", weight=0)  
G.add_edge("159", "115", weight=0)  
G.add_edge("159", "128", weight=0)  
G.add_edge("159", "141", weight=0)  
G.add_edge("159", "143", weight=0)  
G.add_edge("159", "162", weight=0)  
G.add_edge("159", "167", weight=0)  
G.add_edge("160", "6", weight=0)  
G.add_edge("160", "18", weight=0)  
G.add_edge("160", "59", weight=0)  
G.add_edge("160", "62", weight=0)  
G.add_edge("160", "63", weight=0)  
G.add_edge("160", "67", weight=0)  
G.add_edge("160", "70", weight=0)  
G.add_edge("160", "72", weight=0)  
G.add_edge("160", "79", weight=0)  
G.add_edge("160", "80", weight=0)  
G.add_edge("160", "83", weight=0)  
G.add_edge("160", "84", weight=0)  
G.add_edge("160", "84", weight=0)  
G.add_edge("160", "102", weight=0)  
G.add_edge("160", "107", weight=0)  
G.add_edge("160", "107", weight=0)  
G.add_edge("160", "112", weight=0)  
G.add_edge("160", "114", weight=0)  
G.add_edge("160", "116", weight=0)  
G.add_edge("160", "122", weight=0)  
G.add_edge("160", "123", weight=0)  
G.add_edge("160", "126", weight=0)  
G.add_edge("160", "128", weight=0)  
G.add_edge("160", "129", weight=0)  
G.add_edge("160", "132", weight=0)  
G.add_edge("160", "134", weight=0)  
G.add_edge("160", "139", weight=0)  
G.add_edge("160", "140", weight=0)  
G.add_edge("160", "142", weight=0)  
G.add_edge("160", "145", weight=0)  
G.add_edge("160", "146", weight=0)  
G.add_edge("160", "148", weight=0)  
G.add_edge("160", "149", weight=0)  
G.add_edge("160", "151", weight=0)  
G.add_edge("160", "154", weight=0)  
G.add_edge("160", "156", weight=0)  
G.add_edge("160", "157", weight=0)  
G.add_edge("160", "158", weight=0)  
G.add_edge("160", "163", weight=0)  
G.add_edge("160", "164", weight=0)  
G.add_edge("160", "165", weight=0)  
G.add_edge("160", "166", weight=0)  
G.add_edge("160", "171", weight=0)  
G.add_edge("160", "173", weight=0)  
G.add_edge("160", "174", weight=0)  
G.add_edge("160", "175", weight=0)  
G.add_edge("161", "0", weight=0)  
G.add_edge("161", "1", weight=1)  
G.add_edge("161", "2", weight=0)  
G.add_edge("161", "5", weight=1)  
G.add_edge("161", "6", weight=1)  
G.add_edge("161", "7", weight=1)  
G.add_edge("161", "9", weight=1)  
G.add_edge("161", "10", weight=1)  
G.add_edge("161", "25", weight=1)  
G.add_edge("161", "31", weight=0)  
G.add_edge("161", "33", weight=0)  
G.add_edge("161", "44", weight=1)  
G.add_edge("161", "45", weight=1)  
G.add_edge("161", "48", weight=1)  
G.add_edge("161", "49", weight=1)  
G.add_edge("161", "51", weight=1)  
G.add_edge("161", "55", weight=0)  
G.add_edge("161", "57", weight=1)  
G.add_edge("161", "59", weight=1)  
G.add_edge("161", "64", weight=1)  
G.add_edge("161", "71", weight=0)  
G.add_edge("161", "72", weight=1)  
G.add_edge("161", "74", weight=1)  
G.add_edge("161", "77", weight=0)  
G.add_edge("161", "78", weight=1)  
G.add_edge("161", "79", weight=1)  
G.add_edge("161", "81", weight=0)  
G.add_edge("161", "85", weight=1)  
G.add_edge("161", "86", weight=1)  
G.add_edge("161", "87", weight=1)  
G.add_edge("161", "90", weight=1)  
G.add_edge("161", "92", weight=0)  
G.add_edge("161", "95", weight=0)  
G.add_edge("161", "103", weight=0)  
G.add_edge("161", "106", weight=1)  
G.add_edge("161", "115", weight=0)  
G.add_edge("161", "132", weight=1)  
G.add_edge("161", "142", weight=1)  
G.add_edge("161", "146", weight=0)  
G.add_edge("161", "162", weight=1)  
G.add_edge("161", "174", weight=1)  
G.add_edge("162", "0", weight=0)  
G.add_edge("162", "3", weight=0)  
G.add_edge("162", "7", weight=0)  
G.add_edge("162", "27", weight=0)  
G.add_edge("162", "39", weight=0)  
G.add_edge("162", "97", weight=0)  
G.add_edge("162", "114", weight=0)  
G.add_edge("162", "146", weight=0)  
G.add_edge("162", "150", weight=0)  
G.add_edge("162", "159", weight=0)  
G.add_edge("162", "161", weight=0)  
G.add_edge("162", "165", weight=0)  
G.add_edge("163", "1", weight=1000)  
G.add_edge("163", "2", weight=1000)  
G.add_edge("163", "4", weight=1000)  
G.add_edge("163", "9", weight=1000)  
G.add_edge("163", "18", weight=1000)  
G.add_edge("163", "25", weight=1000)  
G.add_edge("163", "35", weight=1000)  
G.add_edge("163", "40", weight=1000)  
G.add_edge("163", "44", weight=1000)  
G.add_edge("163", "48", weight=1000)  
G.add_edge("163", "55", weight=1000)  
G.add_edge("163", "56", weight=1000)  
G.add_edge("163", "57", weight=1000)  
G.add_edge("163", "59", weight=1000)  
G.add_edge("163", "62", weight=1000)  
G.add_edge("163", "64", weight=1000)  
G.add_edge("163", "69", weight=1000)  
G.add_edge("163", "70", weight=1000)  
G.add_edge("163", "79", weight=1000)  
G.add_edge("163", "84", weight=1000)  
G.add_edge("163", "85", weight=1000)  
G.add_edge("163", "94", weight=1000)  
G.add_edge("163", "95", weight=1000)  
G.add_edge("163", "99", weight=1000)  
G.add_edge("163", "102", weight=1000)  
G.add_edge("163", "104", weight=1000)  
G.add_edge("163", "107", weight=1000)  
G.add_edge("163", "111", weight=1000)  
G.add_edge("163", "112", weight=1000)  
G.add_edge("163", "113", weight=1000)  
G.add_edge("163", "114", weight=1000)  
G.add_edge("163", "116", weight=1000)  
G.add_edge("163", "122", weight=1000)  
G.add_edge("163", "125", weight=1000)  
G.add_edge("163", "126", weight=1000)  
G.add_edge("163", "127", weight=1000)  
G.add_edge("163", "128", weight=1000)  
G.add_edge("163", "134", weight=1000)  
G.add_edge("163", "139", weight=1000)  
G.add_edge("163", "142", weight=1000)  
G.add_edge("163", "145", weight=1000)  
G.add_edge("163", "146", weight=1000)  
G.add_edge("163", "147", weight=1000)  
G.add_edge("163", "148", weight=1000)  
G.add_edge("163", "149", weight=1000)  
G.add_edge("163", "151", weight=1000)  
G.add_edge("163", "152", weight=1000)  
G.add_edge("163", "154", weight=1000)  
G.add_edge("163", "156", weight=1000)  
G.add_edge("163", "157", weight=1000)  
G.add_edge("163", "160", weight=1000)  
G.add_edge("163", "164", weight=1000)  
G.add_edge("163", "165", weight=1000)  
G.add_edge("163", "166", weight=1000)  
G.add_edge("163", "168", weight=1000)  
G.add_edge("163", "170", weight=1000)  
G.add_edge("163", "171", weight=1000)  
G.add_edge("163", "173", weight=1000)  
G.add_edge("163", "174", weight=1000)  
G.add_edge("163", "176", weight=1000)  
G.add_edge("164", "1", weight=990)  
G.add_edge("164", "2", weight=990)  
G.add_edge("164", "8", weight=990)  
G.add_edge("164", "9", weight=990)  
G.add_edge("164", "18", weight=990)  
G.add_edge("164", "41", weight=990)  
G.add_edge("164", "42", weight=990)  
G.add_edge("164", "44", weight=990)  
G.add_edge("164", "48", weight=0)  
G.add_edge("164", "53", weight=990)  
G.add_edge("164", "54", weight=990)  
G.add_edge("164", "55", weight=990)  
G.add_edge("164", "57", weight=990)  
G.add_edge("164", "60", weight=990)  
G.add_edge("164", "62", weight=990)  
G.add_edge("164", "63", weight=990)  
G.add_edge("164", "69", weight=990)  
G.add_edge("164", "70", weight=990)  
G.add_edge("164", "71", weight=990)  
G.add_edge("164", "74", weight=990)  
G.add_edge("164", "85", weight=990)  
G.add_edge("164", "87", weight=990)  
G.add_edge("164", "94", weight=990)  
G.add_edge("164", "99", weight=990)  
G.add_edge("164", "102", weight=990)  
G.add_edge("164", "103", weight=990)  
G.add_edge("164", "107", weight=990)  
G.add_edge("164", "112", weight=990)  
G.add_edge("164", "113", weight=990)  
G.add_edge("164", "114", weight=990)  
G.add_edge("164", "116", weight=990)  
G.add_edge("164", "122", weight=990)  
G.add_edge("164", "123", weight=0)  
G.add_edge("164", "126", weight=990)  
G.add_edge("164", "128", weight=990)  
G.add_edge("164", "130", weight=990)  
G.add_edge("164", "131", weight=990)  
G.add_edge("164", "132", weight=990)  
G.add_edge("164", "133", weight=990)  
G.add_edge("164", "134", weight=990)  
G.add_edge("164", "138", weight=990)  
G.add_edge("164", "139", weight=990)  
G.add_edge("164", "142", weight=990)  
G.add_edge("164", "145", weight=990)  
G.add_edge("164", "147", weight=990)  
G.add_edge("164", "148", weight=990)  
G.add_edge("164", "152", weight=990)  
G.add_edge("164", "154", weight=990)  
G.add_edge("164", "155", weight=990)  
G.add_edge("164", "156", weight=990)  
G.add_edge("164", "157", weight=990)  
G.add_edge("164", "160", weight=990)  
G.add_edge("164", "163", weight=990)  
G.add_edge("164", "165", weight=990)  
G.add_edge("164", "166", weight=990)  
G.add_edge("164", "168", weight=990)  
G.add_edge("164", "170", weight=990)  
G.add_edge("164", "171", weight=990)  
G.add_edge("164", "173", weight=990)  
G.add_edge("164", "174", weight=990)  
G.add_edge("164", "175", weight=0)  
G.add_edge("165", "1", weight=0)  
G.add_edge("165", "1", weight=0)  
G.add_edge("165", "5", weight=0)  
G.add_edge("165", "6", weight=0)  
G.add_edge("165", "7", weight=0)  
G.add_edge("165", "9", weight=0)  
G.add_edge("165", "10", weight=0)  
G.add_edge("165", "18", weight=0)  
G.add_edge("165", "26", weight=0)  
G.add_edge("165", "31", weight=0)  
G.add_edge("165", "35", weight=0)  
G.add_edge("165", "40", weight=0)  
G.add_edge("165", "42", weight=0)  
G.add_edge("165", "57", weight=0)  
G.add_edge("165", "59", weight=0)  
G.add_edge("165", "61", weight=0)  
G.add_edge("165", "62", weight=0)  
G.add_edge("165", "64", weight=0)  
G.add_edge("165", "67", weight=0)  
G.add_edge("165", "70", weight=0)  
G.add_edge("165", "71", weight=0)  
G.add_edge("165", "72", weight=0)  
G.add_edge("165", "77", weight=0)  
G.add_edge("165", "77", weight=0)  
G.add_edge("165", "79", weight=0)  
G.add_edge("165", "82", weight=0)  
G.add_edge("165", "85", weight=0)  
G.add_edge("165", "85", weight=0)  
G.add_edge("165", "87", weight=0)  
G.add_edge("165", "88", weight=0)  
G.add_edge("165", "89", weight=0)  
G.add_edge("165", "92", weight=0)  
G.add_edge("165", "95", weight=0)  
G.add_edge("165", "103", weight=0)  
G.add_edge("165", "104", weight=0)  
G.add_edge("165", "107", weight=0)  
G.add_edge("165", "111", weight=0)  
G.add_edge("165", "125", weight=0)  
G.add_edge("165", "126", weight=0)  
G.add_edge("165", "128", weight=0)  
G.add_edge("165", "139", weight=0)  
G.add_edge("165", "141", weight=0)  
G.add_edge("165", "142", weight=0)  
G.add_edge("165", "146", weight=0)  
G.add_edge("165", "157", weight=0)  
G.add_edge("165", "160", weight=0)  
G.add_edge("165", "162", weight=0)  
G.add_edge("165", "163", weight=0)  
G.add_edge("165", "164", weight=0)  
G.add_edge("165", "166", weight=0)  
G.add_edge("165", "168", weight=0)  
G.add_edge("165", "170", weight=0)  
G.add_edge("165", "171", weight=0)  
G.add_edge("165", "172", weight=0)  
G.add_edge("165", "173", weight=0)  
G.add_edge("165", "174", weight=0)  
G.add_edge("165", "175", weight=0)  
G.add_edge("165", "177", weight=0)  
G.add_edge("166", "1", weight=0)  
G.add_edge("166", "2", weight=0)  
G.add_edge("166", "4", weight=0)  
G.add_edge("166", "6", weight=0)  
G.add_edge("166", "9", weight=0)  
G.add_edge("166", "12", weight=0)  
G.add_edge("166", "14", weight=0)  
G.add_edge("166", "18", weight=0)  
G.add_edge("166", "24", weight=0)  
G.add_edge("166", "34", weight=0)  
G.add_edge("166", "35", weight=0)  
G.add_edge("166", "38", weight=0)  
G.add_edge("166", "40", weight=0)  
G.add_edge("166", "41", weight=0)  
G.add_edge("166", "42", weight=0)  
G.add_edge("166", "44", weight=0)  
G.add_edge("166", "45", weight=0)  
G.add_edge("166", "46", weight=0)  
G.add_edge("166", "47", weight=0)  
G.add_edge("166", "48", weight=0)  
G.add_edge("166", "49", weight=0)  
G.add_edge("166", "56", weight=0)  
G.add_edge("166", "57", weight=0)  
G.add_edge("166", "59", weight=0)  
G.add_edge("166", "60", weight=0)  
G.add_edge("166", "62", weight=0)  
G.add_edge("166", "63", weight=0)  
G.add_edge("166", "64", weight=0)  
G.add_edge("166", "65", weight=0)  
G.add_edge("166", "66", weight=0)  
G.add_edge("166", "69", weight=0)  
G.add_edge("166", "70", weight=0)  
G.add_edge("166", "79", weight=0)  
G.add_edge("166", "80", weight=0)  
G.add_edge("166", "82", weight=0)  
G.add_edge("166", "84", weight=0)  
G.add_edge("166", "85", weight=0)  
G.add_edge("166", "86", weight=0)  
G.add_edge("166", "87", weight=0)  
G.add_edge("166", "94", weight=0)  
G.add_edge("166", "95", weight=0)  
G.add_edge("166", "98", weight=0)  
G.add_edge("166", "100", weight=0)  
G.add_edge("166", "101", weight=0)  
G.add_edge("166", "103", weight=0)  
G.add_edge("166", "104", weight=0)  
G.add_edge("166", "107", weight=0)  
G.add_edge("166", "108", weight=0)  
G.add_edge("166", "111", weight=0)  
G.add_edge("166", "113", weight=0)  
G.add_edge("166", "114", weight=0)  
G.add_edge("166", "116", weight=0)  
G.add_edge("166", "118", weight=0)  
G.add_edge("166", "119", weight=0)  
G.add_edge("166", "122", weight=0)  
G.add_edge("166", "123", weight=0)  
G.add_edge("166", "124", weight=0)  
G.add_edge("166", "126", weight=0)  
G.add_edge("166", "127", weight=0)  
G.add_edge("166", "128", weight=0)  
G.add_edge("166", "129", weight=0)  
G.add_edge("166", "130", weight=0)  
G.add_edge("166", "131", weight=0)  
G.add_edge("166", "132", weight=0)  
G.add_edge("166", "133", weight=0)  
G.add_edge("166", "134", weight=0)  
G.add_edge("166", "135", weight=0)  
G.add_edge("166", "136", weight=0)  
G.add_edge("166", "138", weight=0)  
G.add_edge("166", "139", weight=0)  
G.add_edge("166", "142", weight=0)  
G.add_edge("166", "143", weight=0)  
G.add_edge("166", "144", weight=0)  
G.add_edge("166", "145", weight=0)  
G.add_edge("166", "146", weight=0)  
G.add_edge("166", "147", weight=0)  
G.add_edge("166", "148", weight=0)  
G.add_edge("166", "149", weight=0)  
G.add_edge("166", "151", weight=0)  
G.add_edge("166", "152", weight=0)  
G.add_edge("166", "153", weight=0)  
G.add_edge("166", "154", weight=0)  
G.add_edge("166", "156", weight=0)  
G.add_edge("166", "157", weight=0)  
G.add_edge("166", "158", weight=0)  
G.add_edge("166", "160", weight=0)  
G.add_edge("166", "163", weight=0)  
G.add_edge("166", "164", weight=0)  
G.add_edge("166", "165", weight=0)  
G.add_edge("166", "168", weight=0)  
G.add_edge("166", "170", weight=0)  
G.add_edge("166", "171", weight=0)  
G.add_edge("166", "172", weight=0)  
G.add_edge("166", "174", weight=0)  
G.add_edge("166", "174", weight=0)  
G.add_edge("166", "175", weight=0)  
G.add_edge("167", "3", weight=0)  
G.add_edge("167", "39", weight=0)  
G.add_edge("167", "97", weight=0)  
G.add_edge("167", "126", weight=0)  
G.add_edge("167", "141", weight=0)  
G.add_edge("167", "159", weight=0)  
G.add_edge("168", "1", weight=0)  
G.add_edge("168", "4", weight=0)  
G.add_edge("168", "6", weight=0)  
G.add_edge("168", "9", weight=0)  
G.add_edge("168", "10", weight=0)  
G.add_edge("168", "14", weight=0)  
G.add_edge("168", "15", weight=0)  
G.add_edge("168", "18", weight=0)  
G.add_edge("168", "19", weight=0)  
G.add_edge("168", "27", weight=0)  
G.add_edge("168", "32", weight=0)  
G.add_edge("168", "36", weight=0)  
G.add_edge("168", "39", weight=0)  
G.add_edge("168", "40", weight=0)  
G.add_edge("168", "41", weight=0)  
G.add_edge("168", "44", weight=0)  
G.add_edge("168", "45", weight=0)  
G.add_edge("168", "46", weight=0)  
G.add_edge("168", "47", weight=0)  
G.add_edge("168", "48", weight=0)  
G.add_edge("168", "49", weight=0)  
G.add_edge("168", "51", weight=0)  
G.add_edge("168", "53", weight=0)  
G.add_edge("168", "53", weight=0)  
G.add_edge("168", "56", weight=0)  
G.add_edge("168", "57", weight=0)  
G.add_edge("168", "59", weight=0)  
G.add_edge("168", "60", weight=0)  
G.add_edge("168", "62", weight=0)  
G.add_edge("168", "64", weight=0)  
G.add_edge("168", "66", weight=0)  
G.add_edge("168", "67", weight=0)  
G.add_edge("168", "68", weight=0)  
G.add_edge("168", "69", weight=0)  
G.add_edge("168", "70", weight=0)  
G.add_edge("168", "71", weight=0)  
G.add_edge("168", "74", weight=0)  
G.add_edge("168", "79", weight=0)  
G.add_edge("168", "85", weight=0)  
G.add_edge("168", "86", weight=0)  
G.add_edge("168", "87", weight=0)  
G.add_edge("168", "92", weight=0)  
G.add_edge("168", "95", weight=0)  
G.add_edge("168", "98", weight=0)  
G.add_edge("168", "100", weight=0)  
G.add_edge("168", "101", weight=0)  
G.add_edge("168", "103", weight=0)  
G.add_edge("168", "105", weight=0)  
G.add_edge("168", "107", weight=0)  
G.add_edge("168", "110", weight=0)  
G.add_edge("168", "111", weight=0)  
G.add_edge("168", "114", weight=0)  
G.add_edge("168", "118", weight=0)  
G.add_edge("168", "121", weight=0)  
G.add_edge("168", "122", weight=0)  
G.add_edge("168", "123", weight=0)  
G.add_edge("168", "125", weight=0)  
G.add_edge("168", "126", weight=0)  
G.add_edge("168", "127", weight=0)  
G.add_edge("168", "128", weight=0)  
G.add_edge("168", "130", weight=0)  
G.add_edge("168", "131", weight=0)  
G.add_edge("168", "133", weight=0)  
G.add_edge("168", "133", weight=0)  
G.add_edge("168", "135", weight=0)  
G.add_edge("168", "139", weight=0)  
G.add_edge("168", "142", weight=0)  
G.add_edge("168", "143", weight=0)  
G.add_edge("168", "144", weight=0)  
G.add_edge("168", "147", weight=0)  
G.add_edge("168", "156", weight=0)  
G.add_edge("168", "163", weight=0)  
G.add_edge("168", "164", weight=0)  
G.add_edge("168", "165", weight=0)  
G.add_edge("168", "166", weight=0)  
G.add_edge("168", "170", weight=0)  
G.add_edge("168", "171", weight=0)  
G.add_edge("168", "172", weight=0)  
G.add_edge("168", "174", weight=0)  
G.add_edge("168", "174", weight=0)  
G.add_edge("168", "175", weight=0)  
G.add_edge("169", "3", weight=0)  
G.add_edge("169", "39", weight=0)  
G.add_edge("169", "126", weight=0)  
G.add_edge("169", "128", weight=0)  
G.add_edge("169", "141", weight=0)  
G.add_edge("169", "150", weight=0)  
G.add_edge("170", "6", weight=0)  
G.add_edge("170", "8", weight=0)  
G.add_edge("170", "18", weight=0)  
G.add_edge("170", "39", weight=0)  
G.add_edge("170", "40", weight=0)  
G.add_edge("170", "44", weight=0)  
G.add_edge("170", "46", weight=5000)  
G.add_edge("170", "48", weight=0)  
G.add_edge("170", "52", weight=0)  
G.add_edge("170", "54", weight=0)  
G.add_edge("170", "57", weight=0)  
G.add_edge("170", "59", weight=0)  
G.add_edge("170", "60", weight=0)  
G.add_edge("170", "62", weight=0)  
G.add_edge("170", "63", weight=0)  
G.add_edge("170", "64", weight=0)  
G.add_edge("170", "67", weight=0)  
G.add_edge("170", "70", weight=0)  
G.add_edge("170", "79", weight=0)  
G.add_edge("170", "84", weight=0)  
G.add_edge("170", "85", weight=0)  
G.add_edge("170", "86", weight=0)  
G.add_edge("170", "87", weight=0)  
G.add_edge("170", "89", weight=0)  
G.add_edge("170", "92", weight=0)  
G.add_edge("170", "102", weight=5000)  
G.add_edge("170", "107", weight=0)  
G.add_edge("170", "108", weight=0)  
G.add_edge("170", "113", weight=5000)  
G.add_edge("170", "118", weight=0)  
G.add_edge("170", "122", weight=0)  
G.add_edge("170", "126", weight=5000)  
G.add_edge("170", "127", weight=0)  
G.add_edge("170", "128", weight=0)  
G.add_edge("170", "130", weight=0)  
G.add_edge("170", "131", weight=0)  
G.add_edge("170", "133", weight=0)  
G.add_edge("170", "134", weight=0)  
G.add_edge("170", "137", weight=0)  
G.add_edge("170", "138", weight=0)  
G.add_edge("170", "139", weight=0)  
G.add_edge("170", "140", weight=0)  
G.add_edge("170", "142", weight=5000)  
G.add_edge("170", "147", weight=0)  
G.add_edge("170", "154", weight=5000)  
G.add_edge("170", "156", weight=0)  
G.add_edge("170", "157", weight=0)  
G.add_edge("170", "163", weight=5000)  
G.add_edge("170", "164", weight=0)  
G.add_edge("170", "165", weight=5000)  
G.add_edge("170", "166", weight=0)  
G.add_edge("170", "168", weight=0)  
G.add_edge("170", "173", weight=5000)  
G.add_edge("170", "175", weight=0)  
G.add_edge("171", "1", weight=1000)  
G.add_edge("171", "6", weight=1000)  
G.add_edge("171", "8", weight=1000)  
G.add_edge("171", "9", weight=0)  
G.add_edge("171", "18", weight=0)  
G.add_edge("171", "31", weight=1000)  
G.add_edge("171", "40", weight=1000)  
G.add_edge("171", "41", weight=1000)  
G.add_edge("171", "44", weight=1000)  
G.add_edge("171", "45", weight=1000)  
G.add_edge("171", "46", weight=1000)  
G.add_edge("171", "48", weight=0)  
G.add_edge("171", "56", weight=0)  
G.add_edge("171", "60", weight=0)  
G.add_edge("171", "69", weight=0)  
G.add_edge("171", "70", weight=1000)  
G.add_edge("171", "79", weight=1000)  
G.add_edge("171", "83", weight=0)  
G.add_edge("171", "85", weight=0)  
G.add_edge("171", "94", weight=1000)  
G.add_edge("171", "95", weight=0)  
G.add_edge("171", "101", weight=0)  
G.add_edge("171", "102", weight=1000)  
G.add_edge("171", "107", weight=0)  
G.add_edge("171", "110", weight=1000)  
G.add_edge("171", "111", weight=1000)  
G.add_edge("171", "112", weight=1000)  
G.add_edge("171", "114", weight=1000)  
G.add_edge("171", "116", weight=0)  
G.add_edge("171", "117", weight=1000)  
G.add_edge("171", "121", weight=1000)  
G.add_edge("171", "122", weight=0)  
G.add_edge("171", "123", weight=1000)  
G.add_edge("171", "125", weight=1000)  
G.add_edge("171", "127", weight=1000)  
G.add_edge("171", "128", weight=0)  
G.add_edge("171", "130", weight=1000)  
G.add_edge("171", "131", weight=0)  
G.add_edge("171", "134", weight=0)  
G.add_edge("171", "136", weight=0)  
G.add_edge("171", "138", weight=0)  
G.add_edge("171", "139", weight=0)  
G.add_edge("171", "145", weight=0)  
G.add_edge("171", "147", weight=1000)  
G.add_edge("171", "148", weight=1000)  
G.add_edge("171", "149", weight=1000)  
G.add_edge("171", "154", weight=0)  
G.add_edge("171", "156", weight=0)  
G.add_edge("171", "160", weight=0)  
G.add_edge("171", "163", weight=1000)  
G.add_edge("171", "164", weight=1000)  
G.add_edge("171", "165", weight=0)  
G.add_edge("171", "166", weight=0)  
G.add_edge("171", "168", weight=0)  
G.add_edge("171", "172", weight=1000)  
G.add_edge("171", "173", weight=1000)  
G.add_edge("171", "175", weight=1000)  
G.add_edge("171", "176", weight=0)  
G.add_edge("172", "7", weight=998)  
G.add_edge("172", "17", weight=998)  
G.add_edge("172", "18", weight=998)  
G.add_edge("172", "48", weight=998)  
G.add_edge("172", "49", weight=998)  
G.add_edge("172", "50", weight=998)  
G.add_edge("172", "59", weight=998)  
G.add_edge("172", "62", weight=998)  
G.add_edge("172", "66", weight=998)  
G.add_edge("172", "69", weight=998)  
G.add_edge("172", "70", weight=998)  
G.add_edge("172", "72", weight=998)  
G.add_edge("172", "79", weight=998)  
G.add_edge("172", "84", weight=998)  
G.add_edge("172", "85", weight=998)  
G.add_edge("172", "87", weight=998)  
G.add_edge("172", "95", weight=998)  
G.add_edge("172", "100", weight=998)  
G.add_edge("172", "102", weight=998)  
G.add_edge("172", "103", weight=998)  
G.add_edge("172", "107", weight=998)  
G.add_edge("172", "108", weight=998)  
G.add_edge("172", "111", weight=998)  
G.add_edge("172", "112", weight=998)  
G.add_edge("172", "116", weight=998)  
G.add_edge("172", "122", weight=998)  
G.add_edge("172", "127", weight=998)  
G.add_edge("172", "128", weight=998)  
G.add_edge("172", "130", weight=998)  
G.add_edge("172", "131", weight=998)  
G.add_edge("172", "135", weight=998)  
G.add_edge("172", "139", weight=998)  
G.add_edge("172", "142", weight=998)  
G.add_edge("172", "145", weight=998)  
G.add_edge("172", "149", weight=998)  
G.add_edge("172", "157", weight=998)  
G.add_edge("172", "165", weight=998)  
G.add_edge("172", "166", weight=998)  
G.add_edge("172", "168", weight=998)  
G.add_edge("172", "171", weight=998)  
G.add_edge("172", "173", weight=998)  
G.add_edge("172", "175", weight=998)  
G.add_edge("173", "1", weight=0)  
G.add_edge("173", "3", weight=0)  
G.add_edge("173", "18", weight=1000)  
G.add_edge("173", "44", weight=1000)  
G.add_edge("173", "57", weight=1000)  
G.add_edge("173", "62", weight=1000)  
G.add_edge("173", "63", weight=1000)  
G.add_edge("173", "79", weight=1000)  
G.add_edge("173", "80", weight=1000)  
G.add_edge("173", "84", weight=1000)  
G.add_edge("173", "85", weight=1000)  
G.add_edge("173", "87", weight=1000)  
G.add_edge("173", "94", weight=1000)  
G.add_edge("173", "99", weight=1000)  
G.add_edge("173", "102", weight=1000)  
G.add_edge("173", "107", weight=1000)  
G.add_edge("173", "116", weight=1000)  
G.add_edge("173", "123", weight=0)  
G.add_edge("173", "128", weight=1000)  
G.add_edge("173", "133", weight=1000)  
G.add_edge("173", "136", weight=1000)  
G.add_edge("173", "137", weight=1000)  
G.add_edge("173", "139", weight=1000)  
G.add_edge("173", "140", weight=1000)  
G.add_edge("173", "142", weight=1000)  
G.add_edge("173", "145", weight=1000)  
G.add_edge("173", "148", weight=1000)  
G.add_edge("173", "149", weight=1000)  
G.add_edge("173", "151", weight=1000)  
G.add_edge("173", "155", weight=1000)  
G.add_edge("173", "157", weight=1000)  
G.add_edge("173", "158", weight=1000)  
G.add_edge("173", "160", weight=1000)  
G.add_edge("173", "163", weight=1000)  
G.add_edge("173", "164", weight=1000)  
G.add_edge("173", "165", weight=1000)  
G.add_edge("173", "170", weight=1000)  
G.add_edge("173", "171", weight=1000)  
G.add_edge("173", "172", weight=1000)  
G.add_edge("173", "174", weight=1000)  
G.add_edge("173", "177", weight=1000)  
G.add_edge("174", "0", weight=0)  
G.add_edge("174", "1", weight=0)  
G.add_edge("174", "2", weight=0)  
G.add_edge("174", "4", weight=0)  
G.add_edge("174", "5", weight=0)  
G.add_edge("174", "6", weight=0)  
G.add_edge("174", "6", weight=0)  
G.add_edge("174", "6", weight=0)  
G.add_edge("174", "9", weight=0)  
G.add_edge("174", "14", weight=0)  
G.add_edge("174", "21", weight=0)  
G.add_edge("174", "27", weight=0)  
G.add_edge("174", "30", weight=0)  
G.add_edge("174", "30", weight=0)  
G.add_edge("174", "31", weight=0)  
G.add_edge("174", "35", weight=0)  
G.add_edge("174", "35", weight=0)  
G.add_edge("174", "35", weight=0)  
G.add_edge("174", "38", weight=0)  
G.add_edge("174", "38", weight=0)  
G.add_edge("174", "39", weight=0)  
G.add_edge("174", "40", weight=0)  
G.add_edge("174", "42", weight=0)  
G.add_edge("174", "44", weight=0)  
G.add_edge("174", "47", weight=0)  
G.add_edge("174", "50", weight=0)  
G.add_edge("174", "50", weight=0)  
G.add_edge("174", "51", weight=0)  
G.add_edge("174", "52", weight=0)  
G.add_edge("174", "53", weight=0)  
G.add_edge("174", "57", weight=0)  
G.add_edge("174", "59", weight=0)  
G.add_edge("174", "60", weight=0)  
G.add_edge("174", "60", weight=0)  
G.add_edge("174", "60", weight=0)  
G.add_edge("174", "62", weight=0)  
G.add_edge("174", "62", weight=0)  
G.add_edge("174", "62", weight=0)  
G.add_edge("174", "62", weight=0)  
G.add_edge("174", "63", weight=0)  
G.add_edge("174", "64", weight=0)  
G.add_edge("174", "69", weight=0)  
G.add_edge("174", "70", weight=0)  
G.add_edge("174", "70", weight=0)  
G.add_edge("174", "70", weight=0)  
G.add_edge("174", "70", weight=0)  
G.add_edge("174", "70", weight=0)  
G.add_edge("174", "78", weight=0)  
G.add_edge("174", "82", weight=0)  
G.add_edge("174", "83", weight=0)  
G.add_edge("174", "85", weight=0)  
G.add_edge("174", "94", weight=0)  
G.add_edge("174", "94", weight=0)  
G.add_edge("174", "95", weight=0)  
G.add_edge("174", "97", weight=0)  
G.add_edge("174", "98", weight=0)  
G.add_edge("174", "99", weight=0)  
G.add_edge("174", "100", weight=0)  
G.add_edge("174", "101", weight=0)  
G.add_edge("174", "103", weight=0)  
G.add_edge("174", "103", weight=0)  
G.add_edge("174", "104", weight=0)  
G.add_edge("174", "105", weight=0)  
G.add_edge("174", "107", weight=0)  
G.add_edge("174", "109", weight=0)  
G.add_edge("174", "109", weight=0)  
G.add_edge("174", "111", weight=0)  
G.add_edge("174", "113", weight=0)  
G.add_edge("174", "113", weight=0)  
G.add_edge("174", "115", weight=0)  
G.add_edge("174", "118", weight=0)  
G.add_edge("174", "125", weight=0)  
G.add_edge("174", "127", weight=0)  
G.add_edge("174", "128", weight=0)  
G.add_edge("174", "130", weight=0)  
G.add_edge("174", "130", weight=0)  
G.add_edge("174", "131", weight=0)  
G.add_edge("174", "135", weight=0)  
G.add_edge("174", "137", weight=0)  
G.add_edge("174", "138", weight=0)  
G.add_edge("174", "139", weight=0)  
G.add_edge("174", "140", weight=0)  
G.add_edge("174", "142", weight=0)  
G.add_edge("174", "143", weight=0)  
G.add_edge("174", "148", weight=0)  
G.add_edge("174", "151", weight=0)  
G.add_edge("174", "156", weight=0)  
G.add_edge("174", "160", weight=0)  
G.add_edge("174", "161", weight=0)  
G.add_edge("174", "163", weight=0)  
G.add_edge("174", "164", weight=0)  
G.add_edge("174", "165", weight=0)  
G.add_edge("174", "166", weight=0)  
G.add_edge("174", "166", weight=0)  
G.add_edge("174", "168", weight=0)  
G.add_edge("174", "168", weight=0)  
G.add_edge("174", "173", weight=0)  
G.add_edge("174", "175", weight=0)  
G.add_edge("175", "1", weight=0)  
G.add_edge("175", "2", weight=0)  
G.add_edge("175", "4", weight=0)  
G.add_edge("175", "5", weight=0)  
G.add_edge("175", "6", weight=0)  
G.add_edge("175", "7", weight=0)  
G.add_edge("175", "8", weight=0)  
G.add_edge("175", "9", weight=0)  
G.add_edge("175", "13", weight=0)  
G.add_edge("175", "21", weight=0)  
G.add_edge("175", "22", weight=0)  
G.add_edge("175", "25", weight=0)  
G.add_edge("175", "26", weight=0)  
G.add_edge("175", "31", weight=0)  
G.add_edge("175", "34", weight=0)  
G.add_edge("175", "35", weight=0)  
G.add_edge("175", "39", weight=0)  
G.add_edge("175", "40", weight=0)  
G.add_edge("175", "41", weight=0)  
G.add_edge("175", "44", weight=0)  
G.add_edge("175", "46", weight=0)  
G.add_edge("175", "47", weight=0)  
G.add_edge("175", "48", weight=0)  
G.add_edge("175", "49", weight=0)  
G.add_edge("175", "51", weight=0)  
G.add_edge("175", "53", weight=0)  
G.add_edge("175", "55", weight=0)  
G.add_edge("175", "57", weight=0)  
G.add_edge("175", "59", weight=0)  
G.add_edge("175", "62", weight=0)  
G.add_edge("175", "64", weight=0)  
G.add_edge("175", "66", weight=0)  
G.add_edge("175", "70", weight=0)  
G.add_edge("175", "71", weight=0)  
G.add_edge("175", "74", weight=0)  
G.add_edge("175", "78", weight=0)  
G.add_edge("175", "79", weight=0)  
G.add_edge("175", "82", weight=0)  
G.add_edge("175", "84", weight=25000)  
G.add_edge("175", "85", weight=0)  
G.add_edge("175", "87", weight=0)  
G.add_edge("175", "95", weight=0)  
G.add_edge("175", "97", weight=25000)  
G.add_edge("175", "102", weight=25000)  
G.add_edge("175", "104", weight=0)  
G.add_edge("175", "107", weight=0)  
G.add_edge("175", "110", weight=0)  
G.add_edge("175", "111", weight=0)  
G.add_edge("175", "113", weight=0)  
G.add_edge("175", "118", weight=0)  
G.add_edge("175", "122", weight=0)  
G.add_edge("175", "123", weight=0)  
G.add_edge("175", "124", weight=0)  
G.add_edge("175", "125", weight=0)  
G.add_edge("175", "126", weight=0)  
G.add_edge("175", "127", weight=0)  
G.add_edge("175", "128", weight=0)  
G.add_edge("175", "130", weight=0)  
G.add_edge("175", "131", weight=0)  
G.add_edge("175", "132", weight=0)  
G.add_edge("175", "133", weight=0)  
G.add_edge("175", "134", weight=25000)  
G.add_edge("175", "136", weight=0)  
G.add_edge("175", "137", weight=0)  
G.add_edge("175", "138", weight=25000)  
G.add_edge("175", "139", weight=0)  
G.add_edge("175", "140", weight=25000)  
G.add_edge("175", "142", weight=25000)  
G.add_edge("175", "144", weight=0)  
G.add_edge("175", "147", weight=0)  
G.add_edge("175", "149", weight=25000)  
G.add_edge("175", "155", weight=0)  
G.add_edge("175", "156", weight=0)  
G.add_edge("175", "160", weight=25000)  
G.add_edge("175", "164", weight=0)  
G.add_edge("175", "165", weight=0)  
G.add_edge("175", "166", weight=0)  
G.add_edge("175", "168", weight=0)  
G.add_edge("175", "170", weight=0)  
G.add_edge("175", "171", weight=25000)  
G.add_edge("175", "172", weight=25000)  
G.add_edge("175", "174", weight=0)  
G.add_edge("176", "9", weight=0)  
G.add_edge("176", "35", weight=0)  
G.add_edge("176", "35", weight=0)  
G.add_edge("176", "44", weight=0)  
G.add_edge("176", "57", weight=0)  
G.add_edge("176", "70", weight=0)  
G.add_edge("176", "74", weight=0)  
G.add_edge("176", "85", weight=0)  
G.add_edge("176", "89", weight=0)  
G.add_edge("176", "97", weight=0)  
G.add_edge("176", "113", weight=0)  
G.add_edge("176", "115", weight=0)  
G.add_edge("176", "126", weight=0)  
G.add_edge("176", "147", weight=0)  
G.add_edge("176", "156", weight=0)  
G.add_edge("176", "163", weight=0)  
G.add_edge("176", "171", weight=0)  
G.add_edge("177", "80", weight=0)  
G.add_edge("177", "87", weight=0)  
G.add_edge("177", "116", weight=0)  
G.add_edge("177", "136", weight=0)  
G.add_edge("177", "139", weight=0)  
G.add_edge("177", "142", weight=0)  
G.add_edge("177", "144", weight=0)  
G.add_edge("177", "157", weight=0)  
G.add_edge("177", "165", weight=0)  
G.add_edge("177", "173", weight=0)

# %%
import networkx as nx

subax1 = plt.subplot(121)

nx.draw(G, with_labels=True, font_weight='bold')

# %%
edges=sorted(G.edges(data=True), key=lambda t: t[0])

# %%
import random
final_edges = []
for e in edges:
    fee = e[2]
    final_edges.append([e[0],e[1],fee])
    final_edges.append([e[1],e[0],fee])
ffe = sorted(final_edges, key=lambda t: t[0])
for e in ffe:
    print(str(e[0])+" "+str(e[1])+" "+str(e[2]['weight']))
# Out:
# 0 1 9
# 0 4 5
# 0 5 9
# 1 0 9
# 1 2 6
# 1 6 3
# 2 1 6
# 2 3 9
# 2 7 4
# 3 2 9
# 3 4 9
# 3 8 6
# 4 0 5
# 4 3 9
# 4 9 4
# 5 0 9
# 5 7 7
# 5 8 8
# 6 1 3
# 6 8 3
# 6 9 6
# 7 2 4
# 7 5 7
# 7 9 4
# 8 3 6
# 8 5 8
# 8 6 3
# 9 4 4
# 9 6 6
# 9 7 4

# %%
nx.shortest_path(G,source="42",target="134", weight='weight')
# Out:
# ['42', '69', '134']

# %%
import matplotlib.pyplot as plt


pos = nx.circular_layout(G)
nx.draw(G,pos)
# draw path in red
path = nx.shortest_path(G,source="82",target="24", weight='weight')
path_edges = list(zip(path,path[1:]))
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edges(G,pos,edgelist=path_edges,edge_color='r',width=1)
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
nx.draw_networkx_labels(G, pos=pos)
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 14>()
#      12 nx.draw_networkx_labels(G, pos=pos)
#      13 plt.axis('equal')
# ---> 14 plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
# ...

# %%
import json
f = open('vis')
data = json.load(f)

import numpy as np

plt.plot([x[0] for x in data], [x[1] for x in data])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import json
# ----> 2 f = open('vis')
#       3 data = json.load(f)
#       5 import matplotlib.pyplot as plt
#
# FileNotFoundError: [Errno 2] No such file or directory: 'vis'

# %%
import json
f = open('vis')
data = json.load(f)

import matplotlib.pyplot as plt
import numpy as np

plt.plot([x[0] for x in data], [x[1] for x in data])
plt.plot([x[0] for x in data], [x[2] for x in data])
plt.plot([x[0] for x in data], [x[3] for x in data])
plt.plot([x[0] for x in data], [x[4] for x in data])
plt.plot([x[0] for x in data], [x[5] for x in data])
plt.plot([x[0] for x in data], [x[6] for x in data])
plt.plot([x[0] for x in data], [x[7] for x in data])
plt.plot([x[0] for x in data], [x[8] for x in data])
plt.plot([x[0] for x in data], [x[9] for x in data])



plt.show()

# %%
import json
f = open('vis')
data = json.load(f)

import matplotlib.pyplot as plt
import numpy as np

plt.plot([x[0] for x in data], [x[1] for x in data])
plt.plot([x[0] for x in data], [x[2] for x in data])
plt.plot([x[0] for x in data], [x[3] for x in data])
plt.plot([x[0] for x in data], [x[4] for x in data])
plt.plot([x[0] for x in data], [x[5] for x in data])
plt.plot([x[0] for x in data], [x[6] for x in data])
plt.plot([x[0] for x in data], [x[7] for x in data])
plt.plot([x[0] for x in data], [x[8] for x in data])
plt.plot([x[0] for x in data], [x[9] for x in data])



plt.show()

# %%
import json
f = open('vis')
data = json.load(f)

import matplotlib.pyplot as plt
import numpy as np

plt.plot([x[0] for x in data], [x[1] for x in data])
plt.plot([x[0] for x in data], [x[2] for x in data])
plt.plot([x[0] for x in data], [x[3] for x in data])
plt.plot([x[0] for x in data], [x[4] for x in data])
plt.plot([x[0] for x in data], [x[5] for x in data])
plt.plot([x[0] for x in data], [x[6] for x in data])
plt.plot([x[0] for x in data], [x[7] for x in data])
plt.plot([x[0] for x in data], [x[8] for x in data])
plt.plot([x[0] for x in data], [x[9] for x in data])



plt.show()

# %%
import json
f = open('vis')
data = json.load(f)

import matplotlib.pyplot as plt
import numpy as np

plt.plot([x[0] for x in data], [x[1] for x in data])
plt.show()

# %%
import json
f = open('vis')
data = json.load(f)

import matplotlib.pyplot as plt
import numpy as np

plt.plot([x[0] for x in data], [x[1] for x in data])
plt.show()
